# %% [markdown]
# ```python
# import pandas as pd
#
# df = pd.DataFrame(columns=['model', 'dataset', 'mode', 'filtered', 'fold',
#                            'precision', 'recall', 'f1', 'acc'])
#
#
#
# df.to_pickle("cv-results.pkl")
# ```

# %%
# OLD 1 epoch 
import pandas as pd

results = pd.read_pickle('cv-results.pkl')
results.sort_values(['dataset', 'mode', 'fold'])
# Out:
#     model          dataset       mode filtered fold  precision    recall  \
# 1   mBERT  DutchPolicyDocs  forgiving    False    1   0.951220  0.853731
# 9   mBERT  DutchPolicyDocs  forgiving    False    2   0.954038  0.839803
# 17  mBERT  DutchPolicyDocs  forgiving    False    3   0.955531  0.863614
# 0   mBERT  DutchPolicyDocs     strict    False    1   0.687361  0.671117
# 8   mBERT  DutchPolicyDocs     strict    False    2   0.673428  0.652896
# 16  mBERT  DutchPolicyDocs     strict    False    3   0.681793  0.674905
# 7   mBERT              GWN  forgiving     True    1   0.928671  0.696260
# 15  mBERT              GWN  forgiving     True    2   0.951161  0.685844
# 23  mBERT              GWN  forgiving     True    3   0.962745  0.683606
# 6   mBERT              GWN     strict     True    1   0.719347  0.593918
# 14  mBERT              GWN     strict     True    2   0.722437  0.575058
# 22  mBERT              GWN     strict     True    3   0.725980  0.570054
# 5   mBERT              LGL  forgiving    False    1   0.809337  0.751548
# 13  mBERT              LGL  forgiving    False    2   0.835674  0.746550
# 21  mBERT              LGL  forgiving    False    3   0.840779  0.771676
# 4   mBERT              LGL     strict    False    1   0.633386  0.634631
# 12  mBERT              LGL     strict    False    2   0.618178  0.605542
# 20  mBERT              LGL     strict    False    3   0.644558  0.643671
# 3   mBERT          TR-News  forgiving    False    1   0.903328  0.800562
# 11  mBERT          TR-News  forgiving    False    2   0.934084  0.806384
# 19  mBERT          TR-News  forgiving    False    3   0.939690  0.805168
# 2   mBERT          TR-News     strict    False    1   0.744849  0.713202
# 10  mBERT          TR-News     strict    False    2   0.758039  0.715478
# 18  mBERT          TR-News     strict    False    3   0.769356  0.716237
#
#           f1       acc
# 1   0.899843  0.928739
# 9   0.893283  0.924950
# 17  0.907250  0.945878
# 0   0.679142  0.671117
# 8   0.663003  0.652896
# 16  0.678332  0.674905
# 7   0.795845  0.766744
# 15  0.797002  0.757121
# 23  0.799512  0.755966
# 6   0.650643  0.593918
# 14  0.640377  0.575058
# 22  0.638637  0.570054
# 5   0.779373  0.810928
# 13  0.788602  0.818593
# 21  0.804747  0.839623
# 4   0.634007  0.634631
# 12  0.611795  0.605542
# 20  0.644114  0.643671
# 3   0.848846  0.864947
# 11  0.865549  0.881639
# 19  0.867243  0.874810
# 2   0.728682  0.713202
# 10  0.736144  0.715478
# 18  0.741847  0.716237

# %%
# OLD 1 epoch
results.groupby(['mode', 'dataset']).mean()
# Out:
#                            precision    recall        f1       acc
# mode      dataset
# forgiving DutchPolicyDocs   0.953596  0.852383  0.900125  0.933189
#           GWN               0.947526  0.688570  0.797453  0.759944
#           LGL               0.828597  0.756591  0.790907  0.823048
#           TR-News           0.925701  0.804038  0.860546  0.873799
# strict    DutchPolicyDocs   0.680861  0.666306  0.673492  0.666306
#           GWN               0.722588  0.579677  0.643219  0.579677
#           LGL               0.632041  0.627948  0.629972  0.627948
#           TR-News           0.757415  0.714972  0.735558  0.714972

# %%
 import pandas as pd

results = pd.read_pickle('cv-results.pkl')
# results.sort_values(['dataset', 'mode', 'fold'])

# %%
results.groupby(['mode', 'dataset']).mean()
# Out:
#                            precision    recall        f1       acc
# mode      dataset
# forgiving DutchPolicyDocs   0.952975  0.861429  0.904715  0.952841
#           GWN               0.958260  0.675238  0.792208  0.737567
#           LGL               0.851111  0.732286  0.787198  0.790212
#           TR-News           0.931248  0.795149  0.857818  0.866464
# strict    DutchPolicyDocs   0.717687  0.717698  0.717537  0.717698
#           GWN               0.763907  0.587991  0.664480  0.587991
#           LGL               0.665485  0.617807  0.640715  0.617807
#           TR-News           0.763163  0.710015  0.735604  0.710015
