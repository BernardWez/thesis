# %%
# import pandas as pd

# df = pd.DataFrame(columns=['model', 'dataset', 'mode', 'filtered', 'fold', 
#                            'precision', 'recall', 'f1', 'acc'])



# df.to_pickle("cv-results.pkl")

# %%
import pandas as pd

results = pd.read_pickle('cv-results.pkl')
results
# Out:
#    model          dataset       mode filtered fold  precision    recall  \
# 0  mBERT  DutchPolicyDocs     strict    False    1   0.678427  0.634855
# 1  mBERT  DutchPolicyDocs  forgiving    False    1   0.957779  0.822925
# 2  mBERT  DutchPolicyDocs     strict    False    2   0.673428  0.652896
# 3  mBERT  DutchPolicyDocs  forgiving    False    2   0.954038  0.839803
# 4  mBERT  DutchPolicyDocs     strict    False    3   0.681793  0.674905
# 5  mBERT  DutchPolicyDocs  forgiving    False    3   0.955531  0.863614
#
#          f1       acc
# 0  0.655918  0.634855
# 1  0.885246  0.896266
# 2  0.663003  0.652896
# 3  0.893283  0.924950
# 4  0.678332  0.674905
# 5  0.907250  0.945878
