# %% [markdown]
# ### Show results of all models (mBERT & LaBSE w/o cross-validation)

# %%
import pandas as pd

results = pd.read_pickle('1. results.pkl')
results
# Out:
#                 model          dataset       mode filtered  precision  \
# 0   flair/ner-english  DutchPolicyDocs     strict    False   0.738226
# 1   flair/ner-english  DutchPolicyDocs  forgiving    False   0.891566
# 2   flair/ner-english          TR-News     strict    False   0.885305
# 3   flair/ner-english          TR-News  forgiving    False   0.924731
# 4   flair/ner-english              LGL     strict    False   0.787641
# ..                ...              ...        ...      ...        ...
# 76    en_core_web_trf          TR-News  forgiving    False   0.978109
# 77    en_core_web_trf              LGL     strict    False   0.852139
# 78    en_core_web_trf              LGL  forgiving    False   0.958082
# 79    en_core_web_trf              GWN     strict     True   0.864948
# 80    en_core_web_trf              GWN  forgiving     True   0.977901
#
#       recall        f1       acc
# 0   0.243190  0.365857  0.243190
# 1   0.292806  0.440834  0.293704
# ...

# %% [markdown]
# ### Show LaBSE cross-validation results

# %%
cv_results_LaBSE = pd.read_pickle('2. cv-results-LaBSE.pkl')
cv_results_LaBSE
# Out:
#     model          dataset       mode filtered fold  precision    recall  \
# 0   LaBSE  DutchPolicyDocs     strict    False    1   0.686130  0.722894
# 1   LaBSE  DutchPolicyDocs  forgiving    False    1   0.955822  0.914033
# 2   LaBSE          TR-News     strict    False    1   0.773494  0.730653
# 3   LaBSE          TR-News  forgiving    False    1   0.940562  0.814892
# 4   LaBSE              LGL     strict    False    1   0.659300  0.633255
# 5   LaBSE              LGL  forgiving    False    1   0.842030  0.749681
# 6   LaBSE              GWN     strict     True    1   0.770082  0.616243
# 7   LaBSE              GWN  forgiving     True    1   0.962001  0.704970
# 8   LaBSE  DutchPolicyDocs     strict    False    2   0.703980  0.714775
# 9   LaBSE  DutchPolicyDocs  forgiving    False    2   0.956823  0.881486
# 10  LaBSE          TR-News     strict    False    2   0.768244  0.726859
# 11  LaBSE          TR-News  forgiving    False    2   0.941460  0.814712
# ...

# %% [markdown]
# ### Show mBERT cross-validation results

# %%
cv_results_mBERT = pd.read_pickle('3. cv-results-mBERT.pkl')
cv_results_mBERT
# Out:
#     model          dataset       mode filtered fold  precision    recall  \
# 0   mBERT  DutchPolicyDocs     strict    False    1   0.717702  0.698539
# 1   mBERT  DutchPolicyDocs  forgiving    False    1   0.955885  0.838673
# 2   mBERT          TR-News     strict    False    1   0.751408  0.708649
# 3   mBERT          TR-News  forgiving    False    1   0.921158  0.795139
# 4   mBERT              LGL     strict    False    1   0.650578  0.619890
# 5   mBERT              LGL  forgiving    False    1   0.842616  0.741110
# 6   mBERT              GWN     strict     True    1   0.763404  0.597383
# 7   mBERT              GWN  forgiving     True    1   0.950320  0.680282
# 8   mBERT  DutchPolicyDocs     strict    False    2   0.710419  0.691322
# 9   mBERT  DutchPolicyDocs  forgiving    False    2   0.957545  0.844368
# 10  mBERT          TR-News     strict    False    2   0.751608  0.709408
# 11  mBERT          TR-News  forgiving    False    2   0.928457  0.798755
# ...
