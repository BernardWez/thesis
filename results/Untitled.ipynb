# %%
import pandas as pd

# %%
df = pd.DataFrame(
    columns=['model','dataset','mode','filtered', 'precision', 'recall','f1','acc'])

# %%
df
# Out:
# Empty DataFrame
# Columns: [model, dataset, mode, filtered, precision, recall, f1, acc]
# Index: []

# %%
df.to_pickle("./results.pkl")

# %%
tmp = pd.read_pickle('results.pkl')
tmp
# Out:
#                       model          dataset       mode filtered  precision  \
# 0         flair/ner-english  DutchPolicyDocs     strict    False   0.549559
# 1         flair/ner-english  DutchPolicyDocs  forgiving    False   0.648872
# 2         flair/ner-english          TR-News     strict    False   0.886099
# 3         flair/ner-english          TR-News  forgiving    False   0.913004
# 4         flair/ner-english              LGL     strict    False   0.797386
# 5         flair/ner-english              LGL  forgiving    False   0.857876
# 6         flair/ner-english              GWN     strict     True   0.915563
# 7         flair/ner-english              GWN  forgiving     True   0.931015
# 8           flair/ner-multi  DutchPolicyDocs     strict    False   0.623575
# 9           flair/ner-multi  DutchPolicyDocs  forgiving    False   0.689101
# 10          flair/ner-multi          TR-News     strict    False   0.863517
# ...
