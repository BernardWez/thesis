# %%
import sys

# Insert utils folder into path
sys.path.insert(1, '../utils')

# %% [markdown]
# ## Load the default spacy model

# %%
import spacy

# Only enable the ner tagger
ner_pipeline = spacy.load("en_core_web_lg", disable=["tok2vec", "tagger", "parser", "attribute_ruler", "lemmatizer"])

# %% [markdown]
# ## DutchPolicyDocs

# %% [markdown]
# ### Loading the dataset

# %%
file_path = '../../../data/DutchPolicyDocs/DutchPolicyDocs.json' 

import loading_functions

toponym_data = loading_functions.prepare_data(file_path, filtered=False, split=False)

# %% [markdown]
# ### Make Predictions

# %%
import spaCy_predictions

processed_results = spaCy_predictions.make_predictions(ner_pipeline, toponym_data)
# Out:
# 1044it [00:02, 388.10it/s]

# %% [markdown]
# ### Evaluation DPD

# %%
import evaluate

# All toponyms
fps, fns = evaluate.evaluate(toponym_data, processed_results)
# Out:
# fp: 599 | tp: 467 | fn: 2430
# precision: 0.438 | recall: 0.161 | f-score: 0.236

# %%
fps
# Out:
# ['Alkmaar-Noord',
#  'Alkmaar',
#  'Amsterdam',
#  'Noord',
#  'Alkmaar',
#  'De stad maakt',
#  'Alkmaar',
#  'Alkmaar',
#  'De gemeente maakt',
#  'Alkmaar',
#  'Noord',
#  'Alkmaar',
#  'Het ziekenhuis',
#  'de Alkmaarderhout',
#  'Kerkelanden',
#  'de 19e',
#  'Het dorp heeft',
#  'Baarle',
#  'Baarle',
#  'De gemeente kent',
#  'Tilburg',
#  'Tilburg en Turnhout',
#  'De provincie en de beide',
#  'Eikelenbosch',
#  'de verte',
#  'Voor Bergen',
#  'de buurt van de rivier',
#  'Bergen',
#  'aan de vele dagelijkse',
#  'Nieuw Bergen',
#  'de lat hoog',
#  'Nieuw Bergen',
#  'Nieuw Bergen',
#  'Bladel de komende',
#  'binnen de gemeente',
#  'de Verordening ruimte en de beleidsregel',
#  'De tijden dat de overheid alleen de inrichting van Nederland',
#  'De stad Brielle',
#  'Zuid',
#  'Utrecht',
#  'Unesco',
#  'Utrecht',
#  'de stad',
#  'de Amerongsewetering en de Rijndijk',
#  'de Achterdijk',
#  'de Amerongerwetering',
#  'Kenmerkend',
#  'Koningsdag',
#  'Julianadorp',
#  'Holland',
#  'De provincie',
#  'de buurt van de voorzieningen van het',
#  'de Duinzoom',
#  'Holland',
#  'Den Helder',
#  'Julianadorp',
#  'Julianapop',
#  'de Duinzoom ligt',
#  'de Koegraspolder',
#  'bij de',
#  'Europa en wordt',
#  'Tegelijk',
#  'Deventer ligt',
#  'de provincie Overijssel',
#  'Deventer',
#  'Deventer Amsterdam',
#  'het deel rond',
#  'Indien',
#  'Park Braband',
#  'De Hoven een wijk',
#  'Rielerweg-oost en de Rivierenwijk-Deltabuurt',
#  'Park Braband',
#  'Het Deventer Ziekenhuis ligt',
#  'Woonzorgcentrum Park Braband',
#  'De oost-west',
#  'het Horapark en de Kenniscampus',
#  'Verschil',
#  'Ede en Amersfoort',
#  'Marktplein',
#  'Ede waar de stad',
#  'het Proosdijpark ver de stad',
#  'Kernhem',
#  'De gemeente',
#  'Aan beide',
#  'Kempisch',
#  'Het dorp heeft',
#  'de bossen liggen belangrijke',
#  'Kleinmeer',
#  'Het dorp kent',
#  'Brainport Eindhoven',
#  'Amsterdam',
#  'Brainport Eindhoven',
#  'Brainport Eindhoven',
#  'Europa',
#  'Strijp-S',
#  'De Hurk',
#  'Eindhoven',
#  'Eindhoven',
#  'Amsterdam',
#  'Rotterdam',
#  'Eindhoven het hoogst',
#  'Brainport Park en',
#  'Eindhoven',
#  'Nederland',
#  'na Rotterdam',
#  'Eind',
#  'Tongelre',
#  'Brainport Park',
#  'Tilburg',
#  'Tongelre',
#  'Eindhoven',
#  'de buurt van',
#  'Apeldoorn',
#  'Zwolle',
#  'de Zuiderzeestraatweg',
#  'Oost',
#  'Hieraan',
#  'Nunspeet',
#  'Nunspeet kan gebruik gemaakt',
#  'Utrecht',
#  'Zwolle',
#  'Oost-Nederland',
#  'Nunspeet',
#  'Zwolle',
#  'Zwolle',
#  'Zwolle',
#  'Nunspeet maar',
#  'de kop van Noord-Holland',
#  'Groeneveld',
#  'de Zwaluwenburg',
#  'Eind',
#  'Dynamisch',
#  'Milsbeek en Plasmolen',
#  'de Kroonbeek',
#  'De gemeente heeft',
#  'Ovenberg',
#  'De haven',
#  'bij de monding van de Niers',
#  'Spiekerbeek',
#  'de St. Jansberg',
#  'Limburg',
#  'De stad heeft',
#  'het Reichswald en de rivier de Maas',
#  'Noord-Limburg en Midden-Limburg',
#  'Nederland',
#  'de Randstad',
#  'Europa naar Gennep',
#  'Noord',
#  'Bergen',
#  'Oslo',
#  'Groningen',
#  'Next City',
#  'De stad',
#  'Amsterdam',
#  'Utrecht',
#  'Katwijk',
#  'Suikerfabriekterrein',
#  'de Eemsdelta en Delfzijl',
#  'Delfzijl en de',
#  'Roden',
#  'De rivier',
#  'Nijverdal heeft een belangrijke',
#  'Daarlerveen',
#  'het Blokkenpark',
#  'Daarlerveen heeft',
#  'Hellendoorn',
#  'Overijssel heeft de',
#  'de Haarlemmermeer',
#  'Twente',
#  'De gemeente',
#  'Zwolle',
#  'Zwolle en Wierden bestaat nog',
#  'Zwolle en Wierden te optimaliseren',
#  'het Nationaal Park',
#  'Nijverdal',
#  'de Joncheerelaan',
#  'de N35 en de spoorlijn',
#  'Kortom',
#  'Amsterdam',
#  'Haarlem en Leiden',
#  'de buurt van Haarlem',
#  'de omgeving van',
#  'Julianapark',
#  'Haarlem',
#  'Leiden',
#  'Holland',
#  'Holland',
#  'Vogelenzang',
#  'Hollands Midden',
#  'Hillegom een',
#  'Haarlem',
#  'Amsterdam',
#  'Holland',
#  'Noord-Holland',
#  'Amsterdam',
#  'Ook Schiphol',
#  'Haarlem',
#  'Leiden',
#  'Schiphol en de Metropoolregio Amsterdam',
#  'de Weerlaan',
#  'Pastoorslaan',
#  'Antwerpen',
#  'het eiland',
#  'de Hoeksche Waard',
#  'het eiland liggen de oude',
#  'de Hoeksche Waard',
#  'Teylingen',
#  'Leiden',
#  'Nederland',
#  'Plesmanlaan - Haagse Schouwweg',
#  'Hieraan',
#  'Voorschoterweg en Vliet',
#  'Braassem',
#  'van Nederland',
#  'De stad heeft',
#  'Park Merenwijk',
#  'Stevenspark en de groene Oostvlietpolder',
#  'Utrecht',
#  'Rijnsburg',
#  'de omgeving',
#  'het Kooiplein en de Slaaghwijk',
#  'Plesmanlaan',
#  'Aan de westzijde',
#  'Churchillaan',
#  'de stad gebeurt dit',
#  'Nederland',
#  'Leiden Zuidwest',
#  'de wijze waarop Leusden',
#  'het de',
#  'de Eem',
#  'Achterveld kennen een',
#  'de Zuidhoek',
#  'Amersfoort richting',
#  'Amersfoort',
#  'Princenhof en Ruigeveld',
#  'de Heiligenbergenbeek en de',
#  'Noordenveld',
#  'Eelderdiep',
#  'van Peize naar Groningen',
#  'het Leekstermeer',
#  'de richting Roderwolde',
#  'Bitse',
#  'de Zulther Bitse',
#  'de Zulther Bitse',
#  'Aan het Westeinde liggen',
#  'Peizermade',
#  'de richting van de brug',
#  'Weering',
#  'de richting van Peize',
#  'Peize',
#  'Brunlaan',
#  'Hunebedden',
#  'het Noordsche Veld',
#  'Westervelde',
#  'Peize',
#  'Roden',
#  'Westervelde',
#  'Het dorp ligt',
#  'het Drents Plateau op de kop van de rug van Zeijen',
#  'het Oostervoortse Diep',
#  'Uitzondering',
#  'de provinciale weg N372',
#  'Tenslotte',
#  'de 21e',
#  'Eelderdiep',
#  'De route naar Groningen',
#  'Groningen',
#  'Het dorp ligt',
#  'het Bitseveld',
#  'Roderveld',
#  "de jaren '",
#  'de richting van Noordend',
#  'de Hoofdweg',
#  'het Norgerescomplex dat',
#  'Westervelde',
#  'Westervelde',
#  'Omgevingsvisie',
#  'Bergen',
#  'Daar',
#  'Amsterdam',
#  'het Vuurtorenplein',
#  'het Sint Jeroensplein',
#  'De Coepelduynen en',
#  'Het Langeveld',
#  'de Vinkeveldpolder',
#  'binnen Europa',
#  'de Leidse',
#  'Rotterdam',
#  'Nederland',
#  'de winkels van de hele',
#  'Amsterdam',
#  'de Randstad',
#  'Nederland',
#  'Tussen Zandvoort en',
#  'Katwijk',
#  'Het Langeveld',
#  'de Vinkeveldpolder',
#  'Aan de zuid-',
#  'het Palaceplein',
#  'het Vuurtorenplein',
#  'Nunspeet',
#  'de buurt van',
#  'Apeldoorn',
#  'Harderwijk',
#  'Zwolle',
#  'de Zuiderzeestraatweg',
#  'De gemeente',
#  'Nunspeet wordt gezien',
#  'nu de grootste kern van de gemeente',
#  'Nederland',
#  'Hierop',
#  'Winschoten',
#  'Beerta',
#  'Blauwestad',
#  'Duitsland',
#  'Arriva',
#  'Blauwestad',
#  'de Kamp nog',
#  'Het dorp ligt',
#  'Het dorp heeft',
#  'het Midwolderbos',
#  'Bremen',
#  'Groningen',
#  'het Ambonezenbosje bestaat de mogelijkheid',
#  'Groningen',
#  'Duitsland',
#  'het Actieprogramma Versterking binnenstad',
#  'een klein',
#  'de Reevesluis en de',
#  'Oldebroek-West',
#  'de bossen',
#  'Apeldoorn en Arnhem',
#  'Omgevingsvisie',
#  'Opsterland',
#  'De gemeente Opsterland',
#  'Heerenveen',
#  'Ooststellingwerf',
#  'Opsterland',
#  'Nederland',
#  'de meeste gevallen nog',
#  'Lippenhuizen',
#  'Habitatrichtlijn',
#  'Het Terwispeler Grootschar',
#  'de omgeving van dit',
#  'het bijzonder',
#  'de Turfroute',
#  'De gemeente Westvoorne',
#  'Westvoorne',
#  'Nederland',
#  'Oostvoorne en Rockanje',
#  'de Centrumvisie',
#  'naar Brielle',
#  'het bijzonder vanaf de N57',
#  'de Westvoorneweg',
#  'van Rotterdam',
#  'Oostvoorne en Rockanje',
#  'Oostvoorne en één',
#  'Oostvoorne kan - als daar',
#  'de Rijnmond',
#  'Polder Drenkeling naar de duinen',
#  'Brielle',
#  'Oostvoorne is dit de kerk',
#  'Overbosch',
#  'Midden-Delfland en de aanleg van de Blankenburgverbinding',
#  'de richting Meppel',
#  'Westvoorne deel uit van de',
#  'Oost-Nederland',
#  'Rondweg West',
#  'Rondweg Zuid',
#  'OV-)infrastructuur',
#  'Amsterdam',
#  'Eindhoven',
#  'Zwolle',
#  'Zwolle',
#  'Kranenburg',
#  'Zwolle',
#  'de Diezerpoort',
#  'de Spoorzone',
#  'Zwolle',
#  'Hanzeplein',
#  'Lurelui',
#  'Isala Ziekenhuis',
#  'de Vrolijkheid en Marslanden',
#  'het Vechtdal',
#  'Oosterenk',
#  'de gemeente',
#  'Zwolle',
#  'Zwolle',
#  'Kamperpoort',
#  'de Marslanden ligt',
#  'de Spoorzone',
#  'Zwolle',
#  'Zwolle',
#  'Nederland',
#  'Oost Nederland',
#  'Zwolle',
#  'Zwolle',
#  'Utrecht',
#  'Groningen',
#  'Duitsland',
#  'Zwolle sta je ook',
#  'Zwolle',
#  'Amsterdam',
#  'Utrecht',
#  'Enschede',
#  'Zwolle',
#  'de Spoorzone',
#  'de Binnenstad en zal',
#  'de Spoorzone',
#  'Zwolle Zuid',
#  'Zwolle',
#  'het Kerspelbos en de Wijthemerplas',
#  'Harculo',
#  'Zwolle',
#  'de Molenpolder en',
#  'Park15 gelegen',
#  'Overbetuwe',
#  'Kempisch',
#  'van Eindhoven',
#  'Noord-Brabant',
#  'Hooge Mierde',
#  'het Dorpsplein',
#  'de kaart',
#  'De kaart',
#  'de Grienden',
#  'Europa',
#  'Alblasserwaard',
#  'Populierenlaan',
#  'het Reijerpark',
#  'bij',
#  'Maastricht',
#  'Vossenberg West',
#  'Heuvelland',
#  'het Maasdal',
#  'Maastricht',
#  'Maastricht',
#  'Hasselt',
#  'Aachen',
#  'Düsseldorf',
#  'het Academisch ziekenhuis',
#  'Zuid',
#  'het Technocollege',
#  'Academisch Ziekenhuis en de Universiteit',
#  'van Maastricht',
#  'Zuid-Limburg',
#  'Zuid-Limburg',
#  'Zuid',
#  'Zuid',
#  'Zuid',
#  'de Sportzone Limburg',
#  'Duitsland',
#  'Stuttgart',
#  'specifiek het',
#  'Zuid-Limburg',
#  'Zwolle',
#  'Zwolle',
#  'Utrecht',
#  'Groningen',
#  'Bovendien',
#  'Bestaande',
#  'Europa',
#  'de mondiale economie van vandaag',
#  'de Piushaven',
#  'Koningshoeven',
#  'Noord',
#  'Tilburg',
#  'Tilburg-Zuid',
#  'De gemeente',
#  'Haaren',
#  'Hilvarenbeek',
#  'Tilburg het',
#  'Tilburg bekijken',
#  'de Noordwest-Europese Delta',
#  'Nederland',
#  'Zwijsenplein',
#  'ROC',
#  'Tilburg',
#  'Nationaal Park',
#  'Rotterdam',
#  'Nederland',
#  'Aeroparc',
#  'Tilburg-West',
#  'het Wilhelminapark',
#  'Uden',
#  'Uden de eerste',
#  'het Oer-IJ',
#  'het Erfgoedpark',
#  'Het Oude Dorp',
#  'Uitgeest-Noord',
#  'de Metropoolregio',
#  'Haarlem',
#  'Alkmaar',
#  'Voerendaal',
#  'Kunrade',
#  "de plateau's",
#  'Simpelveld',
#  'Aan het',
#  'Valkenburg en Maastricht',
#  'Ubachsberg',
#  'Voerendaal-Kunrade',
#  'Heerlen',
#  'Simpelveld en Gulpen',
#  'Heerlen',
#  'Simpelveld en Gulpen',
#  'Kunrade',
#  'Voerendaal-Kunrade',
#  'de Heuvellanddorpen Klimmen',
#  'Ubachsberg',
#  'Simpelveld en Gulpen',
#  'Deventer en Zutphen liggen',
#  'Deventer en Zutphen',
#  'de buurt',
#  'Apeldoorn en',
#  'de Purmer',
#  'Uitdam',
#  'Waterland',
#  'de Purmer',
#  'Bereikbaarheid',
#  'de gemeente lopen']

# %%
fns
# Out:
# ['Alkmaar',
#  'Alkmaar',
#  'Alkmaar',
#  'Noordhollandsch Kanaal',
#  'het IJ',
#  'Amstel',
#  'Maas',
#  'Alkmaar',
#  'Alkmaar',
#  'Metropoolregio Amsterdam',
#  'Metropoolregio Amsterdam',
#  'Grootschermer',
#  'De Rijp',
#  'Alkmaar-Noord',
#  'winkelcentrum De Mare',
#  'Provincie Noord-Holland',
#  'Noordhollandsch Kanaal',
#  'Alkmaar',
#  'Alkmaar',
#  'Regio Alkmaar',
#  'Alkmaar',
#  'Alkmaar',
#  'Noord-Holland',
#  'Metropoolregio Amsterdam',
#  'Noord-Holland-Noord',
#  'Regio Alkmaar',
#  'Alkmaar',
#  'Alkmaar',
#  'Metropoolregio Amsterdam',
#  'Zaancorridor',
#  'gemeente Alkmaar',
#  'Noordhollandsch Kanaal',
#  'Alkmaar',
#  'Alkmaar',
#  'Alkmaar',
#  'Overloopwijken',
#  'Alkmaar Noord',
#  'Alkmaar Noord',
#  'Alkmaarderhout',
#  'Stompetoren',
#  'Overijssel',
#  'Almelo',
#  'Almelo',
#  'Almelo',
#  'Loolee',
#  'Bornsebeek',
#  'Almelose en Exoosche Aa',
#  'Regge',
#  'Lateraal kanaal',
#  'Doorbraak',
#  'kanaal Almelo - de Haandrik',
#  'Bornerbroek',
#  'Bornerbroek',
#  'Turfkade',
#  'Dollegoor',
#  'Bornsestraat',
#  'Turfkade',
#  'Ossenkoppelerhoek',
#  'Schelfhorst',
#  'Windmolenbroek',
#  'Ossenkoppelerhoek',
#  'Borne',
#  'Bornerbroek',
#  'Baarle',
#  'gemeente Baarle-Nassau',
#  'Baarle-Hertog',
#  'Baarle-Nassau',
#  'Baarle-Hertog',
#  'Baarle',
#  'Noord- en Zuid-Holland',
#  'Tilburg',
#  'Turnhout',
#  'Baarle-Nassau',
#  'Molenstraat-Kapelstraat',
#  'gemeente Baarle-Hertog',
#  'Baarle-Nassau',
#  'Loveren',
#  'Boschoven',
#  'Nijhoven',
#  'Schaluinen',
#  'Tommel',
#  'Gorpeind',
#  'Heesboom',
#  'Liefkenshoek',
#  'Veldbraak',
#  'Heikant',
#  'Driehuizen',
#  'Baarle',
#  'Kernhem',
#  'Kernhem-Noord',
#  'Doesburgereng',
#  'Ederveen',
#  'Baarle',
#  'Baarle',
#  'Boschoven',
#  'Klein Bedaf',
#  'Driehuizen',
#  'Voske',
#  'Heikant',
#  'Keizershoek',
#  'Nijhoven',
#  'Veldbraak',
#  'Liefkenshoek',
#  'Schaluinen',
#  'Bergen',
#  'gemeente Bergen',
#  'Maas',
#  'Aff erden',
#  'Well',
#  'Wellerlooi',
#  'Maas',
#  'Nieuw Bergen',
#  'Boxmeer',
#  'Gennep',
#  'Goch',
#  'Venlo',
#  'Kevelaer',
#  'IJssel',
#  'Berlijn',
#  'randstad',
#  'Aff erden',
#  'Nieuw Bergen',
#  'Well',
#  'Wellerlooi',
#  'Nieuw Bergen',
#  'Nationaal Park De Maasduinen',
#  'Nationaal Park De Maasduinen',
#  'Reindersmeer',
#  'gemeente Bergen',
#  'gemeente Bergen',
#  'Nieuw Bergen',
#  'Aff erden',
#  'Well',
#  'Wellerlooi',
#  'Aff erden',
#  'Nieuw Bergen',
#  'gemeente Bladel',
#  'gemeente Bladel',
#  'gemeente Bladel',
#  'Reusel-de Mierden',
#  'Provincie Noord Brabant',
#  'Nederland',
#  'Brielle',
#  'Voorne-Putten',
#  'Brielle',
#  'regio Utrecht',
#  'Werkhoven',
#  'Beverweerd',
#  'Sterkenburg',
#  'gemeente Utrechtse Heuvelrug',
#  'Sterkenburg',
#  'Cotherweg',
#  'Goyerdijk',
#  'Achterkade',
#  'Langbroekerdijk',
#  'Kromme Rijn',
#  'Cotherweg',
#  'Cothen',
#  'Overlangbroek',
#  'provincie Utrecht',
#  'Wijk bij Duurstede',
#  'Amerongsewetering',
#  'Rijndijk',
#  'Langbroek',
#  'Doorn',
#  'Achterdijk',
#  'Wijk bij Duurstede',
#  'Rijndijk',
#  'Amerongerwetering',
#  'Julianadorp',
#  'Zanddijk',
#  'Koegras',
#  'Julianadorp',
#  'Julianadorp',
#  'Noorwegen',
#  'Spanje',
#  'Den Helder',
#  'Julianadorp',
#  'Loopuytpark',
#  'Julianadorp',
#  'De Riepel',
#  'Julianadorp',
#  'Den Helder',
#  'Schagen',
#  'Middelzand',
#  'Kruiszwin',
#  'Doorzwin',
#  'Bloemkoolstedenbouw',
#  'Vogelzand',
#  'Julianadorp',
#  'Noorderhaven',
#  'Noorderhaven',
#  'Provincie Noord-Holland',
#  'Den Helder',
#  'Schagen',
#  'Den Helder',
#  'Julianadorp',
#  'Provincie Noord-Holland',
#  'Den Helder',
#  'Alkmaar',
#  'Randstad',
#  'Julianadorp',
#  'Den Helder Zuid',
#  'Julianadorp',
#  'Julianadorp',
#  'Den Helder',
#  'Julianadorp',
#  'Callantsoog',
#  "'t Zand",
#  'Julianadorp',
#  'Schagen',
#  'Noordelijke Randstad',
#  'Loopuytpark',
#  'Julianadorp',
#  'Den Helder',
#  'Julianadorp',
#  'Loopuytpark',
#  'De (nieuwe) Riepel',
#  'Julianadorp',
#  'Willem-Alexanderhof',
#  'Loopuytpark',
#  'Julianadorp',
#  'Vogelzand',
#  'Duinzoom',
#  'gemeente Den Helder',
#  'Den Helder',
#  'Den Helder',
#  'Den Helder',
#  'Den Helder',
#  'Den Helder',
#  'Provincie Noord-Holland',
#  'Den Helder,',
#  'Julianadorp',
#  'Julianadorp',
#  'Den Helder',
#  'de Riepel',
#  'Julianadorp',
#  'Julianadorp',
#  'Julianadorp aan Zee',
#  'Julianadorp',
#  'Duinzoom',
#  'Julianadorp',
#  'Koegraspolder',
#  'gemeente Den Helder',
#  'gemeente Schagen',
#  'Europa',
#  'Deventer',
#  'IJssel',
#  'Wilhelminabrug',
#  'de Brink',
#  'Deventer',
#  'Deventer',
#  'IJsseldijk',
#  'Handelspark de Weteringen',
#  'Deventer',
#  'Deventer',
#  'provincie Overijssel',
#  'Deventer',
#  'Brinkgreven',
#  'Deventer',
#  'Deventer',
#  'Deventer',
#  'Deventer',
#  'Randstad',
#  'Amsterdam',
#  'Deventer',
#  'Deventer',
#  'Deventer',
#  'IJssel',
#  'IJssel',
#  'IJssel',
#  'Worp',
#  'IJssel',
#  'Zandpoort',
#  'Sluiskwartier',
#  'Handelskade',
#  'Buitengracht',
#  'Lange Bisschopsstraat',
#  'Proosdijpassage',
#  'Broederenplein',
#  'Smedenstraat',
#  'Sijzenbaanplein',
#  'Gibsonstraat',
#  'Grote Kerkhof',
#  'Deventer',
#  'Broederenplein',
#  'Broederen',
#  'Grote Kerkhof',
#  'Overstraten',
#  'Nieuwstraat',
#  'Schalkhaar',
#  'Schalkhaar',
#  'Rielerenk',
#  'Park Braband',
#  'Westenberg-Buiten',
#  'Park Braband',
#  'Bathmen',
#  'Schoolstraat',
#  'Molenstraat',
#  'Kerkplein',
#  'Brink',
#  'Gorsselseweg',
#  'Deventerweg',
#  'Dorpsstraat',
#  'Bathmen',
#  'Bathmen',
#  'Koekendijk',
#  'Schipbeeksweg',
#  'Gorsselseweg',
#  'Deventerweg',
#  'Brummen',
#  'Epe',
#  'Van Zandweerd-zuid',
#  'Driebergen',
#  'Voorstad',
#  'Bekkumer',
#  'Rivierenwijk-West',
#  'IJssel',
#  'De Hoven',
#  'Zwolseweg',
#  'Hanzetracé',
#  'Schrijversbuurt',
#  'Landsherenkwartier',
#  'Oranjekwartier',
#  'Rollecatekwartier',
#  'Rielerweg-oost',
#  'Rivierenwijk-Deltabuurt',
#  'Park Braband',
#  'Westenbergkazerne',
#  'Haarhuus',
#  'Bathmense Enk',
#  'Deventerweg',
#  'Woertmansweg',
#  'Deventerweg',
#  'Deventerweg',
#  'Randstad',
#  'Ruhrgebied',
#  'Ede',
#  'Duitsland',
#  'Nijkerk',
#  'Ede',
#  'Wageningen',
#  'Wageningen',
#  'Barneveld',
#  'Stationsweg',
#  'Ede',
#  'Rijn',
#  'Wageningen',
#  'Barneveld',
#  'Harderwijk',
#  'Amersfoort',
#  'Keesomstraat',
#  'Lorentzstraat',
#  'Horapark',
#  'ziekenhuis de Gelderse Vallei',
#  'Kenniscampus',
#  'Ede',
#  'Ede',
#  'Veluwe',
#  'Ede',
#  'Wageningen',
#  'Ede',
#  'Amersfoort',
#  'Oude Kerkplein',
#  'Kernhem-Noord',
#  'Ede',
#  'gemeente Eersel',
#  'Eersel',
#  'Brainport',
#  'Finsterwolde',
#  'Terspegelt',
#  'Vessemseweg',
#  'Vessem',
#  'Wintelre',
#  'Groot- en Kleinmeer',
#  'Brainport Eindhoven',
#  'Eindhoven',
#  'gemeenten Amsterdam',
#  'Den Haag',
#  'Nederland',
#  'Brainport Eindhoven',
#  'Brainport Eindhoven',
#  'Eindhoven',
#  'Eindhoven',
#  'High Tech Campus Eindhoven',
#  'Ruhrgebied',
#  'Weert',
#  'Brainport regio',
#  'Eindhoven',
#  'Eindhoven',
#  'Eindhoven',
#  'Eindhoven',
#  'Eindhoven',
#  'Tilburg',
#  'Geldrop',
#  'Eindhoven',
#  'Eindhoven',
#  'Eindhoven',
#  'Ruhrgebied',
#  'Nederland',
#  'Rotterdam',
#  'Eindhoven Airport',
#  'Woensel',
#  'Stratum',
#  'Gender',
#  'Helmond',
#  'Dommel',
#  'Gender',
#  'Strijp',
#  'Tongelre',
#  'Gestel',
#  'Woensel',
#  'Stratum',
#  'Zuiderzeestraatweg',
#  'Veluwe',
#  'Vierhouten',
#  'Oostendorp',
#  'Flevoland',
#  'gemeenten Nunspeet',
#  'Harderwijk',
#  'Nunspeet',
#  'Randstad',
#  'Elburg',
#  'Elburg',
#  'Dronten',
#  'Harderwijk',
#  'Apeldoorn',
#  'Elburg',
#  'Harderwijk',
#  'Oldebroek',
#  'Elburg',
#  'Zwolle',
#  'Nunspeet',
#  'Elburg',
#  'Nunspeet',
#  'Kampen',
#  'Nunspeet',
#  'Noord-Holland',
#  'Oldebroek',
#  'Maas',
#  'het Duits lijntje',
#  'Boxtel',
#  'Plasmolen',
#  'Milsbeek',
#  'Hekkens',
#  'Smele',
#  'Spiekerbeek',
#  'Gennep',
#  'Gennep',
#  'bedrijventerrein Moutstraat',
#  'bedrijventerrein De Heij',
#  'Milsbeek',
#  'bedrijventerreinen Ovenberg',
#  'Milsbeek',
#  'Heijen',
#  'Maasdal',
#  'Maas',
#  'Milsbeek',
#  'Niers',
#  'Gennep',
#  'Bloemenstraat',
#  'Langstraat',
#  'Milsbeek',
#  'Reichswald',
#  'Oude Baan',
#  'Kroonbeek',
#  'de St Jansberg',
#  'Maas',
#  'Zwarteweg',
#  'Midden-Limburg',
#  'gemeente Gennep',
#  'Noord-Limburg',
#  'oost- Europa',
#  'gemeente Aa en Hunze',
#  'Aa en Hunze',
#  'Groningen',
#  'gemeente Ten Boer',
#  'gemeente Groningen',
#  'Noord-Nederland',
#  'Groningen',
#  'Groningen',
#  'Oslo',
#  'Groningen',
#  'Groningen',
#  'Diepenring',
#  'Groningen',
#  'Amsterdam',
#  'Utrecht',
#  'Teylingen',
#  'Noordwijk',
#  'Lisse',
#  'Katwijk',
#  'Hillegom',
#  'Greenport Duin- en Bollenstreek',
#  'Groningen',
#  'Randstad',
#  'Onlanden',
#  'Meerstad',
#  'Hunzedal',
#  'gemeente Groningen',
#  'Groningen',
#  'Sallandse Heuvelrug',
#  'Oost- Nederland',
#  'het Nationaal Park De Sallandse Heuvelrug',
#  'Paarse Poort',
#  'De Sallandse Heuvelrug',
#  'Paarse Poort',
#  'Paarse Poort',
#  'Schuilenburg',
#  'Regge',
#  'Regge',
#  'Rijksweg 35',
#  'Nijverdal',
#  'Ten Cate-terrein',
#  'Regge',
#  'Zwolle',
#  'Nijverdal',
#  'Ten Cate-terrein',
#  'Almelo',
#  'Twentsche Weg',
#  'PC Stamstraat',
#  'Regge',
#  'Daarle',
#  'Regge',
#  'Daarlerveen',
#  'gemeente Hellendoorn',
#  'Regge',
#  'Nijverdal',
#  'Sallandse Heuvelrug',
#  'Sallandse Heuvelrug',
#  'Reggedal',
#  'Wierdense Veld',
#  'Hellendoorn',
#  'Sallandse Heuvelrug',
#  'Overijssel',
#  'Hellendoorn',
#  'Raalte',
#  'Nijverdal',
#  'Zwolle',
#  'Hanzelijn',
#  'Nijverdal',
#  'Nijverdal',
#  'Mariënheem',
#  'Nijverdal',
#  'Zwolle',
#  'Reggeweg',
#  'Ninaberlaan',
#  'Joncheerelaan',
#  'Hellendoorn',
#  'Nijverdal',
#  'Regge',
#  'Sallandse Heuvelrug',
#  'N35',
#  'Grotestraat',
#  'N35',
#  'Nijverdal',
#  'Hillegom',
#  'Hillegom',
#  'Den Haag',
#  'Hillegom',
#  'Elsbroek',
#  'Schiphol',
#  'Cerespark',
#  'De Vosse',
#  'Beltpark',
#  'Burgemeester van Nispenpark',
#  'Heemtuin',
#  'Wilhelminapark',
#  'Julianapark',
#  'MRA',
#  'De Zilk',
#  'Randstad',
#  'Schiphol',
#  'Hillegom',
#  'Haarlem',
#  'Noord-Holland',
#  'Holland',
#  'Hillegom',
#  'Hillegom',
#  'landgoed Vogelenzang',
#  'Kennemerland-Zuid',
#  'Elsbroekerpolder',
#  'Lisse',
#  'Teylingen',
#  'Hillegom',
#  'Holland Rijnland',
#  'regio Hollands Midden',
#  'Hillegom',
#  'Zuid- en Noord-Holland',
#  'Hillegom',
#  'Leiden',
#  'Park Vogelenzang',
#  'Oosteinderpolder',
#  'Hillegom',
#  'Randstad',
#  'Leiden',
#  'Hillegom',
#  'Schiphol',
#  'Amsterdam',
#  'MRA',
#  'Hoeksche Waard',
#  'Randstad',
#  'Hoeksche Waard',
#  'Hoeksche Waard',
#  'Hoeksche Waard',
#  'Biesbosch',
#  'Haringvliet',
#  'Rotterdam',
#  'Drechtsteden',
#  'Hoeksche Waard',
#  'Hoeksche Waard',
#  'West-Brabant',
#  'Rotterdam',
#  'Dordrecht',
#  'Polder het Munnikenland van Westmaas',
#  'Sint Antho-niepolder',
#  'Hoeksche Waard',
#  'Leiden',
#  'Oegstgeest',
#  'Voorschoten',
#  'Zoeterwoude',
#  'Randstad',
#  'Leiden',
#  'Leiden',
#  'Randstad',
#  'Leiden',
#  'Willem de Zwijgerlaan',
#  'Leiden Zuidwest',
#  'Lammenschansdriehoek',
#  'Werninkterrein',
#  'bedrijventerrein De Waard',
#  'Willem de Zwijgerlaan',
#  'Rooseveltstraat',
#  'Plesmanlaan',
#  'Haagse Schouwweg',
#  'Leiden',
#  'Randstad',
#  'Voorschoten',
#  'Zoeterwoude',
#  'Rijndijk',
#  'Leiden',
#  'Polderpark Cronesteijn',
#  'Stevenspark',
#  'Oostvlietpolder',
#  'Leiden',
#  'Park Merenwijk',
#  'Leiden',
#  'Oude en de Nieuwe Rijn',
#  'Oude Rijn',
#  'Leiden',
#  'Kagerplassen',
#  'Braassemermeer',
#  'Katwijk',
#  'Hoven',
#  'Verbeekstraat',
#  'Purmerend',
#  'Leusden',
#  'Oss',
#  'Lelystad',
#  'Leusden',
#  'Leusden',
#  'Veluwe',
#  'Gelderse Vallei',
#  'Gelderse Vallei',
#  'Utrechtse Heuvelrug',
#  'Achterveld',
#  'Jan van Arkelweg',
#  'Hessenweg',
#  'Hamersveldseweg',
#  'Burgemeester de Beaufortweg',
#  'Achterveld',
#  'Biezenkamp',
#  'Hessenweg',
#  'Hamershof',
#  'Achterveld',
#  'Zuidhoek',
#  'Noorderinslag',
#  'Amersfoort',
#  'Leusden Zuid',
#  'Achterveld',
#  'Randweg',
#  'Groene Zoom',
#  'Leusden',
#  'Buitenplaats/Plantage',
#  'Princenhof',
#  'Buitenplaats/Plantage',
#  'Heiligenberg',
#  'Groene Zoomgebied/Centraal',
#  'Groene Zoom',
#  'A28',
#  'Lockhorst',
#  'PON lijn',
#  'Heiligenbergenbeek',
#  'Centraal Station Maastricht',
#  'gemeente Noordenveld',
#  'Veenhuizen',
#  'Hooiweg',
#  'Onlanden',
#  'Peize',
#  'Peizerdiep',
#  'Eelderdiep',
#  'Groningen',
#  'Groningen',
#  'Rowolderdijk',
#  'Peize',
#  'Foxwolde',
#  'Roden',
#  'Roderwolde',
#  'Roden',
#  'Roderwolderweg',
#  'Roderwolderweg 25',
#  'Roderwolderweg',
#  'Roderwolderweg',
#  'De Groeve',
#  'Roderwolderweg',
#  'Roonder Bitse',
#  'Haarveen',
#  'Roden',
#  'Foxwolde',
#  'Foxwolde',
#  'Roden',
#  'Zulther Bitse',
#  'Zulther',
#  'Leutingewolde',
#  'Leutingewolde',
#  'Zulther Bitse',
#  'Leutingewolde',
#  'Tak van de Kortlings',
#  'Gouwe',
#  'Middenweg-Oosteinde',
#  'Oostereinderlaan',
#  'Westeinde',
#  'Zulther Bitse',
#  'Westeinde',
#  'Hamersweg',
#  'Langmadijk',
#  'Groningerweg',
#  'Eelderdiep',
#  'Peizerwold',
#  'Peize',
#  'Peizerwold',
#  'Groningerweg',
#  'Peize',
#  'Oosterweg',
#  'Es- en Oosterweg',
#  'Groningerweg',
#  'Marum',
#  'Drachten',
#  'Peize',
#  'Leek',
#  'Groningerweg',
#  'Woudrustlaan',
#  'Esen Oosterweg',
#  'Groningerweg',
#  'Peizerwold',
#  'De Onlanden',
#  'Wolddijk',
#  'Zanddijk- Brunlaan',
#  'Steenbergen',
#  'Westervelde',
#  'Noordsche Veld',
#  'Steenbergen',
#  'Eén',
#  'Langelo',
#  'Lieveren',
#  'Peest',
#  'Norg',
#  'Peize',
#  'Roden',
#  'Klunderveen',
#  'Peize',
#  'Grote Veld',
#  'Altena',
#  'Een',
#  'Steenbergerloop',
#  'Groote Diep',
#  'Lieveren',
#  'Drents Plateau',
#  'Zeijen',
#  'Lieversche Diepje',
#  'Oostervoortse Diep',
#  'Kleine Diepje',
#  'Lieveren',
#  'Nietap',
#  'Drents Plateau',
#  'Tolbert',
#  'Midwolde',
#  'Paulus Potterstraat',
#  'N372',
#  'Roden',
#  'Roden',
#  'Nieuw-Roden',
#  'Roderweg',
#  'Steenbergerloop',
#  'Nieuw-Roden',
#  'Langewijk',
#  'Norg',
#  'Oostervoortsche',
#  'Groote Diep',
#  'Een',
#  'Donderen',
#  'Oosteind',
#  'Peesterbrink',
#  'Westeind',
#  'Van Esschenbrink',
#  'Asserstraat',
#  'Donderseweg',
#  'Eenerstraat',
#  'Esweg',
#  'Grootveenweg',
#  'Langeloërweg',
#  'Peesterstraat',
#  'Peize',
#  'Peize',
#  'Peizer- en Eelderdiep',
#  'Groningen',
#  'Vries',
#  'Eelde-Paterswolde',
#  'Roden',
#  'Groningen',
#  'Schipdijk/Schipsloot',
#  'Peizerdiep',
#  'De Lange Streeken',
#  'Peize',
#  'Roden',
#  'Nieuw-Roden',
#  'Groningen',
#  'Hoofdweg',
#  'Steenbergeresch',
#  'Noordend',
#  'Markeweg',
#  'Westervelde',
#  'Norgerescomplex',
#  'Oude Vissersdorp',
#  'De Zuid',
#  'Zuidvelde',
#  'Schoolstraat',
#  'Reeweg',
#  'Asserstraat',
#  'gemeente Noordwijkerhout',
#  'Noordwijk',
#  'Noordwijk',
#  'Noordwijk',
#  'Noordwijk',
#  'Bergen aan zee',
#  'Wijk aan Zee',
#  'IJmuiden',
#  'Koningin Wilhelmina Boulevard',
#  'Noordwijk',
#  'Knokke',
#  'Oostende',
#  'Hillegom',
#  'Lisse',
#  'Noordwijkerhout',
#  'Noordwijk',
#  'Nederland',
#  'Noordwijk',
#  'metropoolregio Amsterdam',
#  'Koningin Wilhelmina Boulevard',
#  'Noordwijk',
#  'Knokke',
#  'Oostende',
#  'Koningin Wilhelmina Boulevard',
#  'De Muze',
#  'Vuurtorenplein',
#  'Hoofdstraat',
#  'Kerkstraat',
#  'Sint Jeroensplein',
#  'Coepelduynen',
#  'Noordwijk',
#  'Katwijk',
#  'Greenport Duin- en Bollenstreek',
#  'Het Langeveld',
#  'Vinkeveldpolder',
#  'Teylingen',
#  'Noordzijderpolder',
#  'Sassenheim',
#  'Voorhout',
#  'Offem Zuid',
#  'Hillegom',
#  'Lisse',
#  'Noordwijkerhout',
#  'Teylingen',
#  'Duitsland',
#  'Engeland',
#  'Europa',
#  'Klei Oost',
#  "bedrijventerrein 't Heen",
#  'Offem-Zuid',
#  'Noordwijk',
#  'Brainport',
#  'Rotterdam',
#  'gemeente Amsterdam',
#  'Nederland',
#  'Duitsland',
#  'Verenigd Koninkrijk',
#  'Verenigde Staten',
#  'Frankrijk',
#  'Zandvoort',
#  'Noordwijk aan Zee',
#  'Hillegom',
#  'Greenport Duin- en Bollenstreek',
#  'Het Langeveld',
#  'De Grent',
#  'Huis ter Duinstraat',
#  'oude Hoofdstraat',
#  'Palaceplein',
#  'Vuurtorenplein',
#  'Veluwe',
#  'Vierhouten',
#  'Veluwe',
#  'Nederland',
#  'Nunspeet',
#  'Veluwe',
#  'gemeente Nunspeet',
#  'Nunspeet',
#  'Nunspeet',
#  'gemeente Nunspeet',
#  'Renteloos Voorschotbos',
#  'Belvederebos',
#  'Elspeetsche en Westerheidsche heide',
#  'Schotkamp',
#  'Brabant',
#  'Brabant',
#  'Dollard',
#  'Winschoten',
#  'gemeente Oldambt',
#  'Wiede Leegte',
#  'A7',
#  'gemeente Oldambt',
#  'Winschoten',
#  'Winschoten',
#  'Bad Nieuweschans',
#  'Blauwestad',
#  'Blauwestad',
#  'Havenkwartier',
#  'Oldambtmeer',
#  'Blauwestad',
#  'Wiegersweg',
#  'Hoofdweg',
#  'Termunterzijldiep',
#  'Hoofdstraat',
#  'Kamp',
#  'Hoofdstraat',
#  'West',
#  'Nieuwolda',
#  'Scheemda',
#  'A7',
#  'N362',
#  'Winschoterdiep',
#  'Hondhalstermeer',
#  'Reiderwolde',
#  'Tjamme',
#  'Midwolderbos',
#  'A7',
#  'Randstad',
#  'Ruhrgebied',
#  'Scheemda',
#  'Bad Nieuweschans',
#  'Groningen',
#  'Groningen',
#  'Duitsland',
#  'Bremen',
#  'Duitsland',
#  'Westerwoldse Aa',
#  'Oldambt',
#  'Oldambtmeer',
#  'Ambonezenbosje',
#  'Winschoten',
#  'Groningen',
#  'Groningen',
#  'regio Oost- Groningen',
#  'Oost- Groningen',
#  'Duitsland',
#  'Winschoten',
#  'Winschoten',
#  'Reevediep',
#  'Reevesluis',
#  'Zuiderzeestraatweg',
#  'Spronksweg',
#  'Stationsweg',
#  'Van Asseltsweg',
#  'Lambertusplein',
#  'Oldebroek',
#  'Oldebroek',
#  'Oldebroek-West',
#  'Wezep',
#  'Oldebroek',
#  'Wezep',
#  'Apeldoorn',
#  'Arnhem',
#  'Nunspeet',
#  'De Friese Wouden',
#  'gemeente Opsterland',
#  'Opsterland',
#  'Opsterland',
#  'Heerenveen',
#  'Drachten',
#  'regio Zuidoost Fryslân',
#  'regio Friese Wouden',
#  ...]

# %% [markdown]
# ## TR-News

# %% [markdown]
# ### Loading the dataset

# %%
# Get file path TR-News dataset
file_path = '../../../data/TR-News/TR-News.xml'

import loading_functions

data_all_toponyms = loading_functions.prepare_data(file_path, filtered=False, split=True)

data_filtered_toponyms = loading_functions.prepare_data(file_path, filtered=True, split=True)

# %% [markdown]
# ### Make Predictions

# %%
import spaCy_predictions

processed_results = spaCy_predictions.make_predictions(ner_pipeline, data_all_toponyms)
# Out:
# 174it [00:01, 102.84it/s]

# %% [markdown]
# ### Evaluation TR-News

# %%
import evaluate

# All toponyms
fps, fns = evaluate.evaluate(data_all_toponyms, processed_results)
# Out:
# fp: 190 | tp: 807 | fn: 485
# precision: 0.809 | recall: 0.625 | f-score: 0.705

# %%
fps
# Out:
# ['Hawaii U.N.',
#  'North Carolina',
#  'West Virginia',
#  'West Virginia',
#  'West Virginia',
#  'North Carolina',
#  'the South Regional Jail',
#  'West Virginia',
#  'West Virginia',
#  'West Virginia',
#  'New York',
#  'New York',
#  'the United States',
#  'the United States',
#  'the United States',
#  'Atlantic',
#  'West Chester',
#  'the United States',
#  'Southern District',
#  'New York',
#  'South Carolina',
#  'South Carolina',
#  'New Milford',
#  'Eastside',
#  'London City',
#  'London City',
#  "San Francisco's",
#  'Central Anatolia',
#  'the South Pacific',
#  'Navhal',
#  'Air Berlin',
#  'the Central Coast',
#  'West Coast',
#  'Montreal',
#  'Palma',
#  'Little Portugal',
#  'Phoenix',
#  'Phoenix',
#  'Karak',
#  'the United States',
#  'New York',
#  'Giza',
#  'the Saint Peter and Saint Paul Coptic Orthodox Church',
#  'Costa Rica',
#  'Costa Rica',
#  'Costa Rica',
#  'Costa Rica',
#  'Costa Rica',
#  'Southern California',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Red Deer',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'New Zealand',
#  'the United States',
#  "Western Canada's",
#  'Pacific',
#  'New Zealand',
#  'West',
#  'New South Wales',
#  'Western Australia',
#  'North America',
#  'Quebec City',
#  'Far North Queensland',
#  'Far North Queensland',
#  'Far North Queensland',
#  'Mount Sheridan',
#  'Bentley Park',
#  'Trinity Beach',
#  'Easter',
#  'Easter',
#  'Coolum Beach',
#  'the Sunshine Coast',
#  'Easter',
#  'Western Australia',
#  'South Australia',
#  'the Northern Territory',
#  'Metcalfe County',
#  'Adair County',
#  'Adair County',
#  'Metcalfe County',
#  'Metcalfe County Fire',
#  'Barren County',
#  'Cedar Flat Rd',
#  'Metcalfe County',
#  'the Metcalfe County Coroner',
#  'Metcalfe County',
#  'Delicie',
#  'North London',
#  'Upper Edmonton',
#  "St Edmund's",
#  'Hertford Road',
#  'Essex - Aseany Duncan',
#  'Northumberland Park',
#  'Stoke Newington',
#  'Oleksiak',
#  'Rio de Janeiro',
#  'Sask',
#  'New York City',
#  'the United States',
#  'Bourelle',
#  'Mount Royal',
#  'The City of Montreal',
#  'the Peace River',
#  'Peace River Valley',
#  'Victoria Park',
#  'New York',
#  'South Charleston',
#  'Sioux City',
#  'LAUREL COUNTY',
#  'Laurel County',
#  'Pope County',
#  'Little Rock',
#  'New Mexico',
#  'San Francisco',
#  'New Jersey',
#  'San Francisco',
#  'the LaFayette County',
#  'Allamakee County',
#  'Dallas County',
#  'Plymouth County',
#  'Plymouth County',
#  'Monroe County',
#  'Linn County',
#  'Monroe County',
#  'Marion County',
#  'Mile Hill',
#  'the County of',
#  'Hall County',
#  'the South Plains College',
#  'North Carolina',
#  'the United States',
#  'Eastern Cape',
#  'Conrad',
#  'South Africa',
#  'South Africa',
#  'South Africa',
#  'Vale',
#  'MVA',
#  'Ust-Kamenogorsk',
#  'New York',
#  'Seminole County',
#  'Plantation Lakes Apartments',
#  'Lakes Edge Apartments',
#  'Lakes Edge',
#  'Fort Lauderdale',
#  'Sichuan province',
#  'Puge county',
#  'Sichuan province',
#  'Hunan city',
#  'Zhejiang province',
#  'Guangxi province',
#  'Hong Kong',
#  'East Azerbaijan',
#  'Hypermarket',
#  'Fars Province',
#  'South',
#  'Silver Street']

# %%
fns
# Out:
# ['Turkish',
#  'Aleppo',
#  'Turkish',
#  'Syrian',
#  'Syrian',
#  'U.S.',
#  'Turkish',
#  'Kurdish',
#  'Turkish',
#  'Russian',
#  'Syrian',
#  'Russian',
#  'Turkish',
#  'Russian',
#  'Turkish',
#  'Turkish',
#  'Russian',
#  'Turkish',
#  'Turkish',
#  'Russian',
#  'Russian',
#  'Turkish',
#  'Russian',
#  'Russian',
#  'Hawaii',
#  'Russian',
#  'Syrian',
#  'North Carolina',
#  'West Virginia',
#  'Granville County',
#  'West Virginia',
#  'West Virginia',
#  'North Carolina',
#  'West Virginia',
#  'West Virginia',
#  'West Virginia',
#  'Granville County',
#  'New York',
#  'New York',
#  'New York City',
#  'United States',
#  'United States',
#  'United States',
#  'White House',
#  'Texas',
#  'College Station',
#  'Texas',
#  'Texas',
#  'U.S.',
#  'West Chester',
#  'Xavier University',
#  'United States',
#  'British',
#  'European',
#  'U.S.',
#  'New York',
#  'DETROIT',
#  'U.S.',
#  'U.S.',
#  'United States',
#  'New York',
#  'Michigan',
#  'Wisconsin',
#  'South Carolina',
#  'South Carolina',
#  'Cuban',
#  'BANTAM',
#  'Bantam',
#  'New Milford',
#  'Danbury',
#  'New Milford',
#  'Calgary',
#  'Red Deer',
#  'Russian',
#  'Russian',
#  'Russian',
#  'Russian',
#  'London',
#  'Heathrow',
#  'Gatwick',
#  'Heathrow',
#  'Heathrow',
#  'London',
#  'San Francisco',
#  'Anatolia',
#  'German',
#  'Iraqi',
#  'Rhineland-Palatinate',
#  'Iraqi',
#  'German',
#  'Spanish',
#  'South Pacific',
#  'Venice',
#  'Canadian',
#  'Cannes',
#  'Spanish',
#  'French',
#  'French',
#  'Spanish',
#  'South East Asian',
#  'Berlin',
#  'German',
#  'European',
#  'American',
#  'Chinese',
#  'American',
#  'Central Coast',
#  'West Coast',
#  'Pearson International Airport',
#  'Macdonald-Cartier International Airport',
#  'Montreal-Pierre Elliott Trudeau International Airport',
#  'Mont-Royal Avenue',
#  'Canada',
#  'Churchill',
#  'Man.',
#  'Churchill',
#  'Churchill',
#  'Churchill',
#  'Manitoba',
#  'Toronto',
#  'Little Portugal',
#  'College Street',
#  'Dufferin Street',
#  "St. Michael's Hospital",
#  'Que.',
#  'Jordanian',
#  'Jordanian',
#  'Irbid',
#  'Jordanian',
#  'Karak district',
#  'Karak Castle',
#  'Aleppo',
#  'Paris',
#  'France',
#  'France',
#  'Stade de France',
#  'Boulevard Voltaire',
#  'United States',
#  'White House',
#  'Tunisian',
#  'Kef',
#  'Qatari',
#  'French',
#  'Middle East',
#  'New York',
#  'Russian',
#  'Russian',
#  'Russian',
#  'St. Peter and St. Paul',
#  "St. Mark's Coptic Orthodox Cathedral",
#  'Egyptian',
#  'Coptic Orthodox Church',
#  'Egyptian',
#  'Coptic Orthodox Church',
#  'Alexandria',
#  'Haram',
#  'Egyptian',
#  'Saint Peter and Saint Paul Coptic Orthodox Church',
#  'St. Takla Church',
#  'Vancouver Art Gallery',
#  'Ont.',
#  'Greater Toronto Area',
#  'British Columbia',
#  'Toronto',
#  'Toronto',
#  'Costa Rica',
#  'Canadian',
#  'Costa Rica',
#  'Costa Rica',
#  'Winnipeg',
#  'Costa Rica',
#  'Manitoba',
#  'Costa Rica',
#  'Costa Rica',
#  'Southern California',
#  'Penn Park',
#  'Los Angeles County',
#  'INNISFAIL',
#  'Red Deer',
#  'Canada',
#  'Red Deer',
#  'Red Deer',
#  'Alberta',
#  'New Zealand',
#  'New Zealand',
#  'United States',
#  'Pacific',
#  'Canada',
#  'Asian',
#  'Canadian',
#  'New Zealand',
#  'Canadian',
#  'Asian',
#  'New South Wales',
#  'Western Australia',
#  'North America',
#  'Alberta',
#  'Canadian',
#  'Canada',
#  'Quebec City',
#  'Canada',
#  'Edmonton',
#  'Canadian',
#  'Edmonton',
#  'Queensland',
#  'Archibald Street',
#  'Queensland',
#  'Queensland',
#  'Cairns',
#  'Queensland',
#  'Queensland',
#  'Queensland',
#  'Queensland',
#  'Mount Sheridan',
#  'Bentley Park',
#  'Trinity Beach',
#  'Queensland',
#  'Coolum Beach',
#  'Sunshine Coast',
#  'Western Australia',
#  'South Australia',
#  'Northern Territory',
#  'Metcalfe County',
#  'Adair County',
#  'Kentucky',
#  'Dean Woods Road',
#  'Adair County',
#  'Columbia',
#  'T.J. Health Hospital',
#  'Metcalfe County',
#  'Kentucky',
#  'Kentucky',
#  'Kentucky',
#  'Metcalfe County',
#  'Metcalfe County',
#  'Glasgow',
#  'North Jackson Highway',
#  'Hutcheson Road',
#  'Hutcheson Road',
#  'Barren County',
#  'Cedar Flat',
#  'Metcalfe County',
#  'Kentucky',
#  'Kentucky',
#  'Metcalfe County',
#  'Metcalfe County',
#  'Kentucky',
#  'Scott',
#  'Barren County',
#  'North London',
#  'Upper Edmonton',
#  'St Edmund',
#  'Hertford Road',
#  'Crescent',
#  'Hertford Road',
#  'Dunnock Close',
#  'Essex',
#  'Church Street',
#  'Fore Street',
#  'North Circular Road',
#  'Northumberland Park',
#  'Hornsey',
#  'Stoke Newington',
#  'Canadian',
#  'Rio de Janeiro',
#  'Canadian',
#  'Canadian',
#  'Canadian',
#  'Canadian',
#  'Canada',
#  'German',
#  'Manitoba',
#  'Winnipeg',
#  'Manitoba',
#  'Sask.',
#  'Edmonton',
#  'Alta.',
#  'Edmonton',
#  'New York City',
#  'United States',
#  'Beaconsfield',
#  'Mount Royal',
#  'Montreal',
#  'British Columbia',
#  'Peace River',
#  'Peace River',
#  'Froom Crescent',
#  'Syrian',
#  'Syrian',
#  'Aleppo',
#  'Syrian',
#  'Idlib',
#  'Russian',
#  'Syrian',
#  'Syrian',
#  'Russian',
#  'Aleppo',
#  'Syrian',
#  'Idlib',
#  'Turkish',
#  'Russian',
#  'Turkish',
#  'Russian',
#  'Syrian',
#  'Victoria Park',
#  'London',
#  'St. Thomas',
#  'Falcon Street',
#  'Trafalgar Street',
#  'Clarke Road',
#  'London',
#  'New York',
#  'Thomas Memorial Hospital',
#  'South Charleston',
#  'Sioux City',
#  'LAUREL COUNTY',
#  'Laurel County',
#  'Laurel County',
#  'Blackwater Road',
#  'Pope County',
#  'Arkansas',
#  'Little Rock',
#  'Paris',
#  'New Mexico',
#  'Paris',
#  'Paris',
#  'Powderly',
#  'Toco',
#  'Hugo',
#  'Champs-Elysees',
#  'Champs-Elysees',
#  'Georgetown',
#  'Georgetown',
#  'French',
#  'San Francisco',
#  'New Jersey',
#  'San Francisco',
#  'San Francisco',
#  'PLYMOUTH CO.',
#  'Hinton',
#  'Plymouth County',
#  'Plymouth County',
#  'Black Hawk County',
#  'LaFayette County',
#  'Allamakee County',
#  'Dallas County',
#  'Plymouth County',
#  'Black Hawk County',
#  'Plymouth County',
#  'Black Hawk County',
#  'Ohio',
#  'Monroe County',
#  'Missouri',
#  'Linn County',
#  'Missouri',
#  'Monroe County',
#  'Marion County',
#  'University Hospital',
#  'Rest Acres Road',
#  'Brant',
#  'Powerline Road',
#  'Rest Acres Road',
#  'King Edward Street',
#  'Highway 403',
#  'Powerline Road',
#  'Cleaver Road',
#  'Mile Hill',
#  'Brant',
#  'Hall County',
#  'Texas',
#  'South Plains',
#  'Bob Wills Museum',
#  'Bob Wills Museum',
#  'Turkey',
#  'American',
#  'Turkish',
#  'North Carolina',
#  'Turkish',
#  'Turkish',
#  'United States',
#  'American',
#  'American',
#  'Turkish',
#  'Turkish',
#  'U.S.',
#  'Turkish',
#  'European',
#  'Turkish',
#  'South African',
#  'Eastern Cape',
#  'South Africa',
#  'South Africa',
#  'Eastern',
#  'Southern Europe',
#  'South Africa',
#  'French',
#  'New Caledonia',
#  'South Africa',
#  'Ust-Kamenogorsk',
#  'Russian',
#  'British',
#  'U.S.',
#  'New York',
#  'British',
#  'KY',
#  'Seminole County',
#  'Sears',
#  'Fort Lauderdale',
#  'Maoxian',
#  'Sichuan',
#  'Xinmo',
#  'Puge',
#  'Sichuan',
#  'Hunan',
#  'Zhejiang',
#  'Guangxi',
#  'Chinese',
#  'Chinese',
#  'Hong Kong',
#  'US',
#  'Haris',
#  'East Azerbaijan',
#  'Iranian',
#  'Shiraz',
#  'Iranian',
#  'Fars Province',
#  'French',
#  'Felixstowe Road',
#  'UK',
#  'British',
#  'Seaton Street',
#  'Colton Way',
#  'Enfield',
#  'Millfield Theatre',
#  'Silver Street']

# %%
# Filtered toponyms
fps, fns = evaluate.evaluate(data_filtered_toponyms, processed_results)
# Out:
# fp: 190 | tp: 807 | fn: 445
# precision: 0.809 | recall: 0.645 | f-score: 0.718

# %%
fps
# Out:
# ['Hawaii U.N.',
#  'North Carolina',
#  'West Virginia',
#  'West Virginia',
#  'West Virginia',
#  'North Carolina',
#  'the South Regional Jail',
#  'West Virginia',
#  'West Virginia',
#  'West Virginia',
#  'New York',
#  'New York',
#  'the United States',
#  'the United States',
#  'the United States',
#  'Atlantic',
#  'West Chester',
#  'the United States',
#  'Southern District',
#  'New York',
#  'South Carolina',
#  'South Carolina',
#  'New Milford',
#  'Eastside',
#  'London City',
#  'London City',
#  "San Francisco's",
#  'Central Anatolia',
#  'the South Pacific',
#  'Navhal',
#  'Air Berlin',
#  'the Central Coast',
#  'West Coast',
#  'Montreal',
#  'Palma',
#  'Little Portugal',
#  'Phoenix',
#  'Phoenix',
#  'Karak',
#  'the United States',
#  'New York',
#  'Giza',
#  'the Saint Peter and Saint Paul Coptic Orthodox Church',
#  'Costa Rica',
#  'Costa Rica',
#  'Costa Rica',
#  'Costa Rica',
#  'Costa Rica',
#  'Southern California',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Red Deer',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'New Zealand',
#  'the United States',
#  "Western Canada's",
#  'Pacific',
#  'New Zealand',
#  'West',
#  'New South Wales',
#  'Western Australia',
#  'North America',
#  'Quebec City',
#  'Far North Queensland',
#  'Far North Queensland',
#  'Far North Queensland',
#  'Mount Sheridan',
#  'Bentley Park',
#  'Trinity Beach',
#  'Easter',
#  'Easter',
#  'Coolum Beach',
#  'the Sunshine Coast',
#  'Easter',
#  'Western Australia',
#  'South Australia',
#  'the Northern Territory',
#  'Metcalfe County',
#  'Adair County',
#  'Adair County',
#  'Metcalfe County',
#  'Metcalfe County Fire',
#  'Barren County',
#  'Cedar Flat Rd',
#  'Metcalfe County',
#  'the Metcalfe County Coroner',
#  'Metcalfe County',
#  'Delicie',
#  'North London',
#  'Upper Edmonton',
#  "St Edmund's",
#  'Hertford Road',
#  'Northumberland Park',
#  'Stoke Newington',
#  'Oleksiak',
#  'Rio de Janeiro',
#  'Sask',
#  'New York City',
#  'the United States',
#  'Bourelle',
#  'Mount Royal',
#  'The City of Montreal',
#  'the Peace River',
#  'Peace River Valley',
#  'Victoria Park',
#  'New York',
#  'South Charleston',
#  'Sioux City',
#  'LAUREL COUNTY',
#  'Laurel County',
#  'Pope County',
#  'Little Rock',
#  'New Mexico',
#  'San Francisco',
#  'New Jersey',
#  'San Francisco',
#  'the LaFayette County',
#  'Allamakee County',
#  'Dallas County',
#  'Plymouth County',
#  'Plymouth County',
#  'Monroe County',
#  'Linn County',
#  'Monroe County',
#  'Marion County',
#  'Mile Hill',
#  'the County of',
#  'Hall County',
#  'the South Plains College',
#  'North Carolina',
#  'the United States',
#  'Eastern Cape',
#  'Conrad',
#  'South Africa',
#  'South Africa',
#  'South Africa',
#  'Vale',
#  'MVA',
#  'Ust-Kamenogorsk',
#  'New York',
#  'Seminole County',
#  'Plantation Lakes Apartments',
#  'Lakes Edge Apartments',
#  'Lakes Edge',
#  'Fort Lauderdale',
#  'Sichuan province',
#  'Puge county',
#  'Sichuan province',
#  'Hunan city',
#  'Zhejiang province',
#  'Guangxi province',
#  'Hong Kong',
#  'East Azerbaijan',
#  'Hypermarket',
#  'Fars Province',
#  'South',
#  'Silver Street']

# %%
fns
# Out:
# ['Turkish',
#  'Aleppo',
#  'Turkish',
#  'Syrian',
#  'Syrian',
#  'U.S.',
#  'Turkish',
#  'Turkish',
#  'Russian',
#  'Syrian',
#  'Russian',
#  'Turkish',
#  'Russian',
#  'Turkish',
#  'Turkish',
#  'Russian',
#  'Turkish',
#  'Turkish',
#  'Russian',
#  'Russian',
#  'Turkish',
#  'Russian',
#  'Russian',
#  'Hawaii',
#  'Russian',
#  'Syrian',
#  'North Carolina',
#  'West Virginia',
#  'Granville County',
#  'West Virginia',
#  'West Virginia',
#  'North Carolina',
#  'West Virginia',
#  'West Virginia',
#  'West Virginia',
#  'Granville County',
#  'New York',
#  'New York',
#  'New York City',
#  'United States',
#  'United States',
#  'United States',
#  'White House',
#  'Texas',
#  'College Station',
#  'Texas',
#  'Texas',
#  'U.S.',
#  'West Chester',
#  'Xavier University',
#  'United States',
#  'British',
#  'European',
#  'U.S.',
#  'New York',
#  'DETROIT',
#  'U.S.',
#  'U.S.',
#  'United States',
#  'New York',
#  'Michigan',
#  'Wisconsin',
#  'South Carolina',
#  'South Carolina',
#  'Cuban',
#  'BANTAM',
#  'Bantam',
#  'New Milford',
#  'Danbury',
#  'New Milford',
#  'Calgary',
#  'Red Deer',
#  'Russian',
#  'Russian',
#  'Russian',
#  'Russian',
#  'London',
#  'Heathrow',
#  'Gatwick',
#  'Heathrow',
#  'Heathrow',
#  'London',
#  'San Francisco',
#  'Anatolia',
#  'German',
#  'Iraqi',
#  'Rhineland-Palatinate',
#  'Iraqi',
#  'German',
#  'Spanish',
#  'South Pacific',
#  'Venice',
#  'Canadian',
#  'Cannes',
#  'Spanish',
#  'French',
#  'French',
#  'Spanish',
#  'South East Asian',
#  'Berlin',
#  'German',
#  'European',
#  'American',
#  'Chinese',
#  'American',
#  'Central Coast',
#  'Pearson International Airport',
#  'Macdonald-Cartier International Airport',
#  'Montreal-Pierre Elliott Trudeau International Airport',
#  'Canada',
#  'Churchill',
#  'Man.',
#  'Churchill',
#  'Churchill',
#  'Churchill',
#  'Manitoba',
#  'Toronto',
#  'Little Portugal',
#  "St. Michael's Hospital",
#  'Que.',
#  'Jordanian',
#  'Jordanian',
#  'Irbid',
#  'Jordanian',
#  'Karak district',
#  'Aleppo',
#  'Paris',
#  'France',
#  'France',
#  'Stade de France',
#  'United States',
#  'White House',
#  'Tunisian',
#  'Kef',
#  'Qatari',
#  'French',
#  'Middle East',
#  'New York',
#  'Russian',
#  'Russian',
#  'Russian',
#  "St. Mark's Coptic Orthodox Cathedral",
#  'Egyptian',
#  'Coptic Orthodox Church',
#  'Egyptian',
#  'Coptic Orthodox Church',
#  'Alexandria',
#  'Haram',
#  'Egyptian',
#  'St. Takla Church',
#  'Vancouver Art Gallery',
#  'Ont.',
#  'Greater Toronto Area',
#  'British Columbia',
#  'Toronto',
#  'Toronto',
#  'Costa Rica',
#  'Canadian',
#  'Costa Rica',
#  'Costa Rica',
#  'Winnipeg',
#  'Costa Rica',
#  'Manitoba',
#  'Costa Rica',
#  'Costa Rica',
#  'Southern California',
#  'Penn Park',
#  'Los Angeles County',
#  'INNISFAIL',
#  'Red Deer',
#  'Canada',
#  'Red Deer',
#  'Red Deer',
#  'Alberta',
#  'New Zealand',
#  'New Zealand',
#  'United States',
#  'Pacific',
#  'Canada',
#  'Asian',
#  'Canadian',
#  'New Zealand',
#  'Canadian',
#  'Asian',
#  'New South Wales',
#  'Western Australia',
#  'North America',
#  'Alberta',
#  'Canadian',
#  'Canada',
#  'Quebec City',
#  'Canada',
#  'Edmonton',
#  'Canadian',
#  'Edmonton',
#  'Queensland',
#  'Queensland',
#  'Queensland',
#  'Cairns',
#  'Queensland',
#  'Queensland',
#  'Queensland',
#  'Queensland',
#  'Mount Sheridan',
#  'Bentley Park',
#  'Trinity Beach',
#  'Queensland',
#  'Coolum Beach',
#  'Sunshine Coast',
#  'Western Australia',
#  'South Australia',
#  'Northern Territory',
#  'Metcalfe County',
#  'Adair County',
#  'Kentucky',
#  'Adair County',
#  'Columbia',
#  'Metcalfe County',
#  'Kentucky',
#  'Kentucky',
#  'Kentucky',
#  'Metcalfe County',
#  'Metcalfe County',
#  'Glasgow',
#  'Barren County',
#  'Cedar Flat',
#  'Metcalfe County',
#  'Kentucky',
#  'Kentucky',
#  'Metcalfe County',
#  'Metcalfe County',
#  'Kentucky',
#  'Scott',
#  'Barren County',
#  'North London',
#  'Upper Edmonton',
#  'St Edmund',
#  'Crescent',
#  'Essex',
#  'Northumberland Park',
#  'Hornsey',
#  'Stoke Newington',
#  'Canadian',
#  'Rio de Janeiro',
#  'Canadian',
#  'Canadian',
#  'Canadian',
#  'Canadian',
#  'Canada',
#  'German',
#  'Manitoba',
#  'Winnipeg',
#  'Manitoba',
#  'Sask.',
#  'Edmonton',
#  'Alta.',
#  'Edmonton',
#  'New York City',
#  'United States',
#  'Beaconsfield',
#  'Mount Royal',
#  'Montreal',
#  'British Columbia',
#  'Peace River',
#  'Peace River',
#  'Syrian',
#  'Syrian',
#  'Aleppo',
#  'Syrian',
#  'Idlib',
#  'Russian',
#  'Syrian',
#  'Syrian',
#  'Russian',
#  'Aleppo',
#  'Syrian',
#  'Idlib',
#  'Turkish',
#  'Russian',
#  'Turkish',
#  'Russian',
#  'Syrian',
#  'Victoria Park',
#  'London',
#  'St. Thomas',
#  'London',
#  'New York',
#  'Thomas Memorial Hospital',
#  'South Charleston',
#  'Sioux City',
#  'LAUREL COUNTY',
#  'Laurel County',
#  'Laurel County',
#  'Pope County',
#  'Arkansas',
#  'Little Rock',
#  'Paris',
#  'New Mexico',
#  'Paris',
#  'Paris',
#  'Powderly',
#  'Toco',
#  'Hugo',
#  'Champs-Elysees',
#  'Champs-Elysees',
#  'Georgetown',
#  'Georgetown',
#  'French',
#  'San Francisco',
#  'New Jersey',
#  'San Francisco',
#  'San Francisco',
#  'PLYMOUTH CO.',
#  'Hinton',
#  'Plymouth County',
#  'Plymouth County',
#  'Black Hawk County',
#  'LaFayette County',
#  'Allamakee County',
#  'Dallas County',
#  'Plymouth County',
#  'Black Hawk County',
#  'Plymouth County',
#  'Black Hawk County',
#  'Ohio',
#  'Monroe County',
#  'Missouri',
#  'Linn County',
#  'Missouri',
#  'Monroe County',
#  'Marion County',
#  'University Hospital',
#  'Brant',
#  'Brant',
#  'Hall County',
#  'Texas',
#  'South Plains',
#  'Bob Wills Museum',
#  'Bob Wills Museum',
#  'Turkey',
#  'American',
#  'Turkish',
#  'North Carolina',
#  'Turkish',
#  'Turkish',
#  'United States',
#  'American',
#  'American',
#  'Turkish',
#  'Turkish',
#  'U.S.',
#  'Turkish',
#  'European',
#  'Turkish',
#  'South African',
#  'Eastern Cape',
#  'South Africa',
#  'South Africa',
#  'Eastern',
#  'Southern Europe',
#  'South Africa',
#  'French',
#  'New Caledonia',
#  'South Africa',
#  'Ust-Kamenogorsk',
#  'Russian',
#  'British',
#  'U.S.',
#  'New York',
#  'British',
#  'KY',
#  'Seminole County',
#  'Sears',
#  'Fort Lauderdale',
#  'Maoxian',
#  'Sichuan',
#  'Xinmo',
#  'Puge',
#  'Sichuan',
#  'Hunan',
#  'Zhejiang',
#  'Guangxi',
#  'Chinese',
#  'Chinese',
#  'Hong Kong',
#  'US',
#  'Haris',
#  'East Azerbaijan',
#  'Iranian',
#  'Shiraz',
#  'Iranian',
#  'Fars Province',
#  'French',
#  'UK',
#  'British',
#  'Enfield']

# %% [markdown]
# ## LGL

# %% [markdown]
# ### Loading the dataset

# %%
# Get file path LGL dataset
file_path = '../../../data/LGL/LGL.xml'

import loading_functions

data_all_toponyms = loading_functions.prepare_data(file_path, filtered=False, split=True)

data_filtered_toponyms = loading_functions.prepare_data(file_path, filtered=True, split=True)

# %% [markdown]
# ### Make Predictions

# %%
import spaCy_predictions

processed_results = spaCy_predictions.make_predictions(ner_pipeline, data_all_toponyms)
# Out:
# 887it [00:06, 128.40it/s]

# %% [markdown]
# ### Evaluation LGL

# %%
import evaluate

# All toponyms
fps, fns = evaluate.evaluate(data_all_toponyms, processed_results)
# Out:
# fp: 1172 | tp: 2089 | fn: 2670
# precision: 0.641 | recall: 0.439 | f-score: 0.521

# %%
fps
# Out:
# ['Orchard St.',
#  'Pogemiller',
#  'Twin Lakes - Highway',
#  'Pelican Rapids',
#  'the Red River',
#  'Red River',
#  'the Red River Valley',
#  'North Dakota',
#  'Oakport Township',
#  'Groth',
#  'Fargo City',
#  'Red River',
#  'Lake Vermont',
#  'Freeborn Lake',
#  'North Nokomis Street',
#  'New Haven',
#  'Sioux Falls',
#  'New Haven',
#  'the Alexandria City Public Schools',
#  'Old Town',
#  'Old Town',
#  'New York City',
#  'Old Town',
#  'Northwest D.C.',
#  'Cutts',
#  'Southern Sudan',
#  'Sub-Saharan Africa',
#  'Sri Lanka',
#  'Sri Lanka',
#  'Sri Lanka',
#  'Sri Lanka',
#  'Sri Lanka',
#  "Sri Lanka's",
#  'Petrojet',
#  'Petrojet',
#  'Petrojet',
#  'Zamalek',
#  'Esperance',
#  'Esperance',
#  'US',
#  'the Middle East',
#  'Gulf',
#  'the Middle East',
#  'Gulf',
#  'US',
#  'US',
#  'US',
#  'the West Bank',
#  'Gulf',
#  'US',
#  'Gulf',
#  'the Middle East',
#  'US',
#  'Sharm El-Sheikh',
#  'the High Dam',
#  'North Monticello',
#  'DuPage County',
#  'Babcock Grove',
#  'Charlotte',
#  'Glen Ellyn',
#  'Macon County',
#  'Hudson',
#  'Evergreen Lake',
#  'Decatur',
#  'Des Plaines',
#  'North Texas',
#  'Tarrant County',
#  'Fort Worth',
#  'Tarrant County',
#  'Fort Worth',
#  'Houston',
#  'Fort Worth',
#  'Eastland County',
#  'Kermanshah province',
#  'North Texas',
#  'the United States',
#  'the Islamic Republic',
#  'Huffines Communities',
#  'Viridian',
#  'Hampton Hills',
#  'North Arlington Neighbors',
#  'South Arlington',
#  'Northeast Georgia',
#  'Oconee County',
#  'Northeast Georgia',
#  'Athens-Clarke County',
#  'North Lumpkin Street',
#  'Elkview Drive',
#  'Sunny Hills Drive',
#  'Madison Heights',
#  'Lombardy Drive',
#  'North',
#  'Northeast Georgia',
#  'Barrow County',
#  'Northeast Georgia',
#  'Walton County',
#  'Walton County',
#  "Walton County's",
#  'McKinney',
#  'Holstein',
#  'Henderson County',
#  'Navarro County',
#  'Barrel City',
#  'Marriott',
#  'Marriott',
#  'Kaufman County',
#  'Kaufman County',
#  'Torenia',
#  'Kaufman County',
#  'McMinn County',
#  'Metro Nashville',
#  'County',
#  'Madison County',
#  'The City of Edwardsville',
#  'Illinois Route',
#  'District Drive',
#  'Glen Carbon',
#  'Fort Worth',
#  'Fort Worth',
#  'Fort Worth',
#  'South Carolina',
#  'South Carolina',
#  'Columbia County',
#  'Richmond County',
#  'Richmond County',
#  'Hot Springs Drive',
#  'Newton County',
#  'Falls Village',
#  'New England',
#  'New Jersey',
#  'West Africa',
#  'New Milford',
#  'the Naugatuck River',
#  'EAST HAMPTON - Police',
#  'East Hampton',
#  'North Main Street',
#  'the Huntingdon Sea Cadets',
#  'St Ives',
#  'Mount Gilead',
#  'Richland County',
#  'Pleasant City',
#  'Franklin County',
#  "Warren County's",
#  'Recreation District',
#  'CHARLESTON',
#  'W.Va.',
#  'W.Va. - Jim McMillon',
#  'South Charleston',
#  'W.Va.',
#  'CHARLESTON',
#  'W.Va.',
#  'South Charleston',
#  'South Charleston',
#  'South Charleston',
#  'West Virginia',
#  'Virginia Beach',
#  'Cedar Grove',
#  'Cabell County',
#  'St. Albans',
#  'Kanawha City',
#  'South Charleston',
#  'Shawnee Park',
#  'the Kanawha Valley',
#  'South Charleston',
#  'South Charleston',
#  'Knights Inn',
#  'Kanawha City',
#  'Bronx County',
#  'Kanawha County',
#  'Kanawha County',
#  'Grant County',
#  'South Charleston',
#  'South Charleston',
#  'West Virginia',
#  'South Charleston',
#  'West Virginia',
#  'Mason County',
#  'Mason County',
#  'Kanawha River',
#  'W.Va.',
#  'the Kanawha River',
#  'W.Va.',
#  'Kanawha County',
#  'Tri-State',
#  'Kanawha County',
#  'Tri-State',
#  'Tri-State',
#  'Las Vegas',
#  'W.Va.',
#  'Manchester',
#  'West Virginia',
#  'Plains West Wilderness',
#  'Canaan Valley',
#  'the Greenbrier River Valley',
#  'Anthony Creek',
#  'the Cranberry Wilderness',
#  'the Dry Fork River',
#  'the Otter Creek Wilderness',
#  'Manchester',
#  "Mount Hood's",
#  'W.Va',
#  'East Bank',
#  'Kanawha County',
#  'East Bank',
#  'East Bank',
#  'Kanawha County',
#  'East Bank',
#  'East Bank',
#  'Kanawha County Emergency',
#  'W.Va',
#  'W.Va.',
#  'West Virginia',
#  'Mercer County',
#  'Virginia',
#  'W.Va.',
#  'W.Va.',
#  'Kanawha County',
#  'W.Va.',
#  'Putnam County',
#  'Putnam County',
#  'Putnam County',
#  'Kanawha County',
#  'West Virginia',
#  'West Virginia',
#  'Bikefest',
#  'ATLANTIC BEACH',
#  'South Carolina',
#  'Myrtle Beach',
#  'Atlantic Beach',
#  'Myrtle Beach',
#  'Horry County',
#  'Goose Creek - A Goose Creek',
#  'Wild Dunes',
#  'Hampton Park',
#  'Lexington County',
#  'DUI',
#  'Lexington County',
#  'Lexington County',
#  'Gaston',
#  'W. Columbia',
#  'Parkwood Drive',
#  'West Columbia',
#  'Lexington County',
#  'Gaston',
#  'Lexington County',
#  'Batesburg-Leesville',
#  'Ravenel',
#  'South Carolina',
#  'South Carolina',
#  'Apalache Lake',
#  'City Park',
#  'West Columbia City Council',
#  'the West Metro Chamber of Commerce',
#  "West Metro's",
#  'West Columbia',
#  'West Columbia',
#  'South Carolina',
#  'West Columbia',
#  'the South Central District',
#  'South Central',
#  'Williamson County',
#  'Tennessee',
#  'the South Central District',
#  'Galaxy Lanes',
#  'Recreation',
#  'Williamson County',
#  'Tennessee',
#  'New England',
#  'East Fourth Street',
#  'Drawbough',
#  'West Virginia',
#  'Wood County',
#  'W. Va.',
#  'the North Central Regional Jail',
#  'W. Va.',
#  'Meigs County',
#  'Meigs County',
#  'County',
#  'Pleasant Township',
#  'Madison Township',
#  'Grove City',
#  'DeKalb County',
#  'Briar Vista',
#  'DeKalb County',
#  'North Druid Hills',
#  'North Druid Hills Road',
#  'DeKalb County',
#  'Clayton County',
#  'Clayton County',
#  'South Fourth Street',
#  'DeKalb County',
#  'Hopkins Park',
#  'DeKalb County',
#  'Culver',
#  'North Seventh',
#  'Kish River',
#  'the Kishwaukee River',
#  'Hopkins Park',
#  'DeKalb County',
#  'West Allis',
#  'Hopkins Park',
#  'Historic District',
#  'Talla 2',
#  'Jerome Township',
#  'Cuyahoga Falls',
#  'Wichita',
#  'Historic Dublin',
#  'North Street',
#  'North Street',
#  'the Chestatee River',
#  'Lake Lanier',
#  'Flat Creek',
#  'Flat Creek',
#  'Orchard Brook',
#  "Lake Lanier's",
#  'Hall County',
#  'Forsyth County',
#  'Hall County',
#  'Bankolemoh',
#  'Norman to D.C',
#  'Washington',
#  'Cooke County',
#  'Wichita',
#  'Cooke County',
#  'Cooke County',
#  'Cooke County',
#  'North Texas',
#  'the Southwest Pacific',
#  'the Aleutian Islands',
#  'the Far East',
#  'the Middle East',
#  'the Soviet Union',
#  'Tex Hill',
#  'Rodeo Gainesville',
#  'the Rodeo Gainesville',
#  'Holly Heights',
#  'Alachua County',
#  'S.W. Second Terrace',
#  'Micanopy',
#  'St. Marys River',
#  'St. Marys - The',
#  'St. Marys River',
#  'the United States',
#  'Hall County and',
#  'Hall County',
#  'Hall County',
#  'North Georgia',
#  'Lake Hartwell',
#  'South Ossetia',
#  'United Georgia',
#  'U.S.',
#  'the United States',
#  'the Ochamchire district',
#  'South Ossetia',
#  'the South Ossetians',
#  'the South Ossetians',
#  'Utiashvili',
#  'the North Caucasus',
#  'Utiashvili',
#  'South Ossetia',
#  'the Russian Federation',
#  'North Ossetian',
#  'South Ossetian',
#  'South Ossetia',
#  'Walker County',
#  'Walker County',
#  'Walker County',
#  'Walker County',
#  'Walker County',
#  'Huntsville City',
#  'the City of Huntsville',
#  'Walker County',
#  'Sand Creek Township',
#  'Jackson County Central',
#  'Delano',
#  'Kivel',
#  'Hentges',
#  'Scott County',
#  'Delano',
#  'Milaca',
#  'Johnson County',
#  'Johnson County',
#  'Johnson County',
#  'Leavenworth County',
#  'Kansas City',
#  'Jackson County',
#  'East Elm Street',
#  'Cass County',
#  'Kansas City',
#  'Kansas City',
#  'Wyandotte County District Court',
#  'Kansas City',
#  'Roanoke Park',
#  'Kansas City',
#  'Kansas City',
#  'South 13th Terrace',
#  'the Kansas City',
#  'Blue Springs',
#  'Blue Springs',
#  'North Kansas City',
#  'North Kansas City',
#  'Kansas City',
#  'Kansas City',
#  'North',
#  'Kansas City',
#  'Platte City',
#  'Boulder City',
#  'the Eldorado Valley',
#  'Henderson',
#  'Boulder City',
#  'Boulder City',
#  'Boulder City',
#  'Boulder City',
#  'North Las Vegas',
#  'North Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas Valley',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'San Diego',
#  'Las Vegas',
#  'Las Vegas',
#  'Interfaith Manor',
#  'North Annville Township',
#  'New York City',
#  'Jackson Township',
#  'the H. L. Snyder Funeral Home, Inc.',
#  'Pine Grove',
#  "the St. John's Union Cemetery",
#  "Boone County's",
#  "St. Patrick's",
#  'Boone County',
#  'Fairfield',
#  'Boone County',
#  'East Washington Street',
#  'the Boone County Jail',
#  "Boone County's",
#  "Boone County's",
#  "Boone County's",
#  'Montgomery County',
#  'Boone County',
#  "Boone County's",
#  'Allaw',
#  'AMEL',
#  'NGO',
#  'NGO',
#  'AMEL',
#  'BEIRUT',
#  'the Bekaa Valley',
#  'Mieh Mieh',
#  'Readington Township',
#  'Clinton Township',
#  'Mulligan Quarry',
#  'ST',
#  'the North Atlantic',
#  'Newfoundland',
#  'Kingsmills',
#  'Erie',
#  'North America',
#  'Quebec City',
#  'Laurel County',
#  'Laurel County',
#  "the 5th District's",
#  'Laurel County',
#  'Laurel County',
#  'Clay County',
#  'Laurel County',
#  'Laurel County',
#  'Laurel County',
#  'Laurel County',
#  'Eastern Redbud',
#  'Laurel County',
#  'Laurel County',
#  'Clark County',
#  "Clark County's",
#  'Southeastern Confernce',
#  'Los Angeles',
#  'Los Angeles',
#  'Los Angeles',
#  'Los Angeles',
#  'Los Angeles',
#  'Los Angeles',
#  'El Dorado Avenue',
#  'the Antelope Valley Freeway',
#  'San Fernando City',
#  'Los Angeles',
#  'Los Angeles',
#  "Los Angeles'",
#  'New Delhi',
#  'Los Angeles',
#  'the South Coast Air Quality Management District',
#  'Santa Ana',
#  'Los Angeles',
#  'Harbor City',
#  'Mount Washington',
#  'Los Feliz',
#  'Historic',
#  'Los Angeles',
#  'Echo Park',
#  'Mount Washington',
#  'Los Angeles',
#  'Orange County',
#  'Orange County',
#  'Vuelta',
#  'Castilla',
#  'the United States',
#  'Castilla',
#  'South L.A',
#  'South Los Angeles',
#  'East 51st Street',
#  'West 11th Street',
#  'San Diego',
#  'San Diego State',
#  'Dallas',
#  'Riley County',
#  'Pottawatomie County',
#  'Kane County',
#  'Jefferson County',
#  'St. George',
#  'Kansas',
#  'KANSAS CITY',
#  'Marion County',
#  'Riley County',
#  'Anderson County',
#  'Flint Hills',
#  'Dodge City',
#  'Garden City',
#  'Dodge City',
#  'Pratt County',
#  'Dodge City',
#  'Daytona Beach',
#  'Volusia County',
#  'Volusia County',
#  'Seminole County',
#  'I-95',
#  'Pacific Ocean',
#  'Volusia County',
#  'Osceola County',
#  'South Florida',
#  'Panama City',
#  'New York',
#  'St. Petersburg',
#  "New York's",
#  "St. Petersburg's",
#  'St. Petersburg',
#  'North America',
#  'New York',
#  'the United States',
#  'New York',
#  'Los Angeles',
#  'Rego Park',
#  'New York',
#  'the United States',
#  'New York',
#  'the North Caucasus',
#  'United Russia',
#  'non-United Russia',
#  'United Russia',
#  'United Russia',
#  'United Russia',
#  'Yevdokimov',
#  'United Russia',
#  'United Russia',
#  'United Russia',
#  'New London',
#  'New London',
#  'New London',
#  'New London',
#  'Culver',
#  'Culver',
#  'Henry',
#  'Des Moines',
#  'the Southeast District Competition',
#  'Iowa City',
#  'Mt. Pleasant',
#  'Henry County',
#  'Big Creek',
#  'Mount Vernon',
#  'Mount Pleasant',
#  'the City of Canton',
#  'Mount Pleasant',
#  'Hellinghausen',
#  'Mount Pleasant',
#  'Texas',
#  'Mount Pleasant',
#  'Sulphur Springs',
#  'North Carolina',
#  "North Carolina's",
#  'Sandhills region',
#  'Pinelake',
#  'Pinelake',
#  'South Main Street',
#  'New Zealand',
#  'New Zealand',
#  "the United States'",
#  'New Hampshire',
#  'New Zealand',
#  'New Zealand',
#  "New Zealand's",
#  'New Zealand',
#  'North Island',
#  'Licking County',
#  'Licking County',
#  'Licking County cities',
#  'Valley',
#  'Licking Valley',
#  'Licking County',
#  'Farallon Islands',
#  'Cassin',
#  'Santa Cruz',
#  'Delta',
#  'Alameda County',
#  'Tri-City',
#  'Tri-City',
#  'New Haven',
#  'New Haven',
#  'New Haven',
#  'Bay Area',
#  'D-N.J.',
#  'Cedar County',
#  'Cedar County',
#  'Cedar County',
#  'Montessori',
#  'Montessori',
#  'the City of Norfolk',
#  'North Fork River',
#  "Northeast Nebraska's",
#  'Diamond Dick District',
#  'Battle Creek',
#  'Northeast Nebraska',
#  'Osney Island',
#  'Osney Island',
#  'Osney Island',
#  'West Street',
#  'East Oxford',
#  'East Oxford',
#  'UK',
#  'Weston',
#  'Holm Way',
#  'Manzil Way',
#  'Cleveland Drive',
#  "St Bartholomew's",
#  'East Oxford',
#  'Butler County',
#  'West Chester',
#  'Butler County',
#  'West Chester Twp',
#  'South Bend',
#  'South Bend',
#  'BUTLER COUNTY - Butler County Community',
#  'Lake Ontario',
#  'Patullo Ridge',
#  'the United States',
#  'Europe',
#  'Europe',
#  'the Czech Republic',
#  'the United States',
#  'the United States',
#  'Arctic coast',
#  'Renfrew County',
#  'Juvederm',
#  'Lycka',
#  'the Province of Ontario',
#  'Tavistock',
#  'Henderson County',
#  'the Gulf of Mexico',
#  'Neches River Valley',
#  'Caddo',
#  'the Neches River National Wildlife Refuge',
#  'Big Slough Wilderness',
#  'Upland Island Wilderness',
#  'Neches River',
#  'the Neches River National Wildlife Refuge',
#  'East Texas',
#  'the Neches River National Wildlife Refuge',
#  'Tennessee Colony',
#  'Tennessee Colony',
#  'Anderson County',
#  'Paris',
#  'Paris',
#  'Anderson County',
#  'Anderson County',
#  'Freestone County',
#  'Freestone County',
#  'the Anderson County Jail',
#  'Anderson County',
#  'Anderson County',
#  'Anderson County',
#  'Tennessee Colony',
#  'U.S',
#  'the United States',
#  'New York',
#  'North Carolina',
#  'Anderson County',
#  'Vermilion Grove',
#  'St. Louis',
#  'Eastern Illinois Area',
#  'Edgar County',
#  'The City of Paris',
#  'Schwartz',
#  'Henry County',
#  'Henry County',
#  'Motels',
#  'East Ridge',
#  'Henry County',
#  'Benton County',
#  'Carroll County',
#  'Stewart County',
#  'Weakley County',
#  'Williamson County',
#  'El Salvador',
#  'Delaware Bay beach',
#  'Fumo',
#  'Fumo',
#  'Fumo',
#  'South Philadelphia',
#  'Fumo',
#  'South Philadelphia',
#  'W. Phila',
#  'Phila',
#  'Woodlands',
#  'Woodlands',
#  'South Fayette',
#  'North Shore',
#  'North Shore',
#  'North Shore',
#  'the Market Districts',
#  'Bethel Park',
#  'Chabad',
#  'Market District',
#  'Waterford',
#  'Westmoreland County',
#  'Ann Arbor',
#  'Grand River',
#  'Charles City County',
#  'Charles City',
#  'the James River',
#  'Charles City',
#  'Charles City',
#  'Henrico County',
#  'Glen Allen',
#  'North Carolina',
#  'Chesapeake Bay',
#  'Prince William County Circuit Court',
#  'York County',
#  'York County',
#  'Greene',
#  'Henrico County',
#  'North Side',
#  'North Richmond',
#  "St. Patrick's",
#  'Darke County',
#  'Jordan',
#  'East Chicago',
#  'Hammond Marina',
#  'East Chicago',
#  "Warren County's",
#  'Hamilton Township',
#  'Cambridge City',
#  'Henrico County',
#  'Sledding',
#  'Chesterfield County',
#  'Chesterfield County Police',
#  'New York',
#  'Taliaferro',
#  'Madison County',
#  'Rockcastle County',
#  'North',
#  'Madison County',
#  'Jefferson County',
#  'Madison County',
#  'McLean County',
#  'Montgomery County',
#  'Madison County',
#  "the City of Richmond's",
#  'Camelot',
#  'TfL',
#  'TfL',
#  'Dziekanski',
#  'Dziekanski',
#  'Millington',
#  'Bo Kong Vegetarian Restaurant',
#  'The Bo Kong Vegetarian Restaurant',
#  'Metro Vancouver',
#  'Metro Vancouver',
#  'B.C.',
#  'the Lower Mainland',
#  'the Gulf of Alaska',
#  'B.C.',
#  'El Nino',
#  'Penac',
#  'New York City',
#  'Hudson',
#  'the Russian Empire',
#  'the Soviet Union for America',
#  'San Diego',
#  'St. Petersburg',
#  'the Soviet Union',
#  'the United States',
#  'New York',
#  'Los Angeles',
#  'the Russian Empire',
#  'Shaab district',
#  'St. Petersburg',
#  'Sochi',
#  "St. Petersburg's",
#  'St. Petersburg',
#  'St. Petersburg',
#  'Black Sea',
#  'the Nice of Russia',
#  'United Russia',
#  'Padalka',
#  'Santa Clara',
#  'Santa Clara',
#  'Santa Clara',
#  'Rhode Island',
#  'Santa Clara County',
#  'SAN FRANCISCO',
#  'San Francisco',
#  'San Francisco',
#  'Santa Clara',
#  'Valley Water District',
#  "Silicon Valley's",
#  'Santa Clara',
#  'Santa Clara County',
#  'Los Altos',
#  'Morgan Hill',
#  'Santa Clara County',
#  'Santa Clara County',
#  'Santa Clara County',
#  'Trapani',
#  'Trapani',
#  'Trapani',
#  'Los Angeles',
#  'Los Angeles',
#  'Jurassic Park',
#  'San Jose',
#  'San Jose',
#  'Santa Clara County',
#  'West Stockbridge',
#  'West Newton',
#  'West Stockbridge',
#  'New York',
#  'Western Massachusetts',
#  'Long Island',
#  'Western Mass.',
#  'West Springfield',
#  'Western Massachusetts',
#  'Jupiter',
#  'Greene County',
#  'New York City',
#  'Logan-Rogersville',
#  'Logan-Rogersville',
#  'Greene County',
#  'Webster County',
#  'Greene County',
#  'Watts',
#  'ST',
#  'PARIS',
#  'St. Paris',
#  'Ohio',
#  'Yellow Springs',
#  'Yellow Springs',
#  'Greene County',
#  'New Miami',
#  'New Miami',
#  'Butler County',
#  'the Butler County Jail',
#  'ST',
#  'PARIS',
#  'St. Paris',
#  'Springfield City Schools',
#  'Muscogee County',
#  'Fort Knox',
#  'Fort Benning',
#  'YMCA',
#  'Newbern',
#  'Muscogee County',
#  'the Chattahoochee River',
#  'Phenix City',
#  'Phenix City',
#  'Rock Hill',
#  'Rock Hill',
#  "South Carolina's",
#  'the Catawba River',
#  'the Catawba River',
#  'Rock Hill',
#  'Fort Mill',
#  'York County',
#  'the Catawba River',
#  'the Carolina Thread',
#  'York County',
#  'Birkdale Village',
#  'Cel-River Road',
#  'Rock Hill City',
#  'Rock Hill',
#  'Red Sea',
#  'St. Kitts',
#  'Nevis',
#  'Schalit',
#  'the Gaza Strip',
#  'the West Bank',
#  'the Gaza Strip',
#  'the West Bank',
#  'the West Bank',
#  'the West Bank',
#  'the West Bank',
#  'Saudi Arabia',
#  'Saudi Arabia',
#  'Olmsted County',
#  'ST',
#  'South St. Paul',
#  'N.W. Rochester',
#  'Lamar County',
#  'Lamar County',
#  'Sun Valley',
#  "Sun Valley's",
#  'S.E. Paris',
#  'Oaks Apartments',
#  'Northeast Texas',
#  'Metroplex',
#  'Northeast Texas',
#  'Birch',
#  'Birch',
#  'DFW',
#  'Lamar County',
#  'Columbus East',
#  'Columbus North',
#  'Kenton County',
#  'Smoky Mountains',
#  'the Nebraska Sandhills',
#  'Nord',
#  'Europe',
#  'New York',
#  'Southwest Asia',
#  'Near East',
#  'the Middle East',
#  'the Czech Republic',
#  'the Gaza Strip',
#  'the Golan Heights',
#  'the United States',
#  'the Czech Republic',
#  'West Bank',
#  'West Bank',
#  'the West Bank',
#  'the Gaza Strip',
#  'the West Bank',
#  'North',
#  'North',
#  "St Therese's",
#  'Drive',
#  'Carrowclough',
#  'Carrowclough',
#  'the River Pollagh',
#  'the River Moy',
#  'Platte County',
#  'Sherman County',
#  'Loup City',
#  "Lincoln County's",
#  'Madison County',
#  'Meadow Grove',
#  'Meadow Grove',
#  'Meadow Grove',
#  'Meadow Grove',
#  'Meadow Grove',
#  'Trenton Kuta',
#  'Vt.',
#  'Lake Opechee',
#  'New England',
#  'Cpl',
#  'Cpl',
#  'New Hampshire']

# %%
fns
# Out:
# ['Memphis St.',
#  'Augusta St.',
#  'Mansfield',
#  'Mansfield',
#  'Shreveport',
#  'Mansfield',
#  'DeSoto Parish',
#  'Cook',
#  'Minneapolis',
#  'Highway 200',
#  'Mahnomen',
#  'Mahnomen County Road',
#  'Mahnomen County Road',
#  'Twin Lakes',
#  'Highway 10',
#  'Otter Tail County',
#  'Highway 108',
#  'Pelican Rapids',
#  'Star Lake',
#  'Otter Tail/Grant',
#  'Grant/Wilkin',
#  'County Road 43',
#  'Highway 114',
#  'Douglas County',
#  'Lake Mary',
#  'Benson',
#  'Minnesota',
#  'Minnesota',
#  'Alexandria',
#  'Red River',
#  'Fargo',
#  'Moorhead',
#  'Red River',
#  'Red River Valley',
#  'Fargo',
#  'Fargo',
#  '40th Avenue South',
#  'North Dakota',
#  'Oakport Township',
#  'Moorhead',
#  'Red River',
#  'Moorhead',
#  'Minnesota',
#  'Fargo',
#  'Fargo',
#  'Red River',
#  'Fargo',
#  'Douglas County',
#  'County Road 35',
#  'Lake Vermont',
#  'County Road 56',
#  'County Road 15',
#  'Brandon',
#  'County Road 96',
#  'Freeborn Lake',
#  'North Nokomis Street',
#  'Darling Avenue',
#  'Van Dorn Street',
#  'Alexandria',
#  'Alexandria',
#  'New Haven',
#  'Sioux Falls',
#  'S.D.',
#  'Surprise',
#  'Alexandria',
#  'New Haven',
#  'Alexandria',
#  'Alexandria',
#  'Old Town',
#  'Old Town',
#  'New York City',
#  'Old Town',
#  'Washington',
#  'D.C.',
#  'D.C.',
#  'Penn Quarter',
#  'Sudanese',
#  'Sudan',
#  'Chinese',
#  'Africa',
#  'African',
#  'Egyptian',
#  'Egyptian',
#  'Sudan',
#  'Sudanese',
#  'Sudanese',
#  'Sudanese',
#  'Sudanese',
#  'Egyptian',
#  'Sudanese',
#  'Sudanese',
#  'Sudanese',
#  'Sudanese',
#  'Sudanese',
#  'Sudanese',
#  'Egyptian',
#  'Sudanese',
#  'Sudanese',
#  'Alexandria',
#  'Sudanese',
#  'Sri Lankan',
#  'Sri Lankan',
#  'Sinhalese',
#  'Sri Lanka',
#  'Sinhalese',
#  'Sinhalese',
#  'Sri Lanka',
#  'Sri Lanka',
#  'Sri Lanka',
#  'Sri Lankan',
#  'Sri Lankan',
#  'Sri Lankan',
#  'Sri Lankan',
#  'Sri Lankan',
#  'Sri Lankan',
#  'Sri Lankan',
#  'Sinhalese',
#  'Sri Lanka',
#  'Sri Lanka',
#  'Sinhalese',
#  'Sri Lankan',
#  'Sri Lankan',
#  'Sri Lanka',
#  'Sri Lanka',
#  'Zamalek',
#  'Port Said',
#  'Middle East',
#  'Egyptian',
#  'US',
#  'Egyptian',
#  'Egyptian',
#  'Israeli',
#  'Madrid Conference',
#  'Middle East',
#  'Palestinian',
#  'Israeli',
#  'Palestinian',
#  'West Bank',
#  'Palestinian',
#  'Egyptian',
#  'American',
#  'Egyptian',
#  'Egyptian',
#  'US',
#  'Israeli',
#  'Egyptian',
#  'US',
#  'Americans',
#  'Egypt',
#  'Middle East',
#  'Palestinian',
#  'Palestinian',
#  'Syrians',
#  'Syrians',
#  'Palestinians',
#  'Palestinians',
#  'Sharm El-Sheikh',
#  'Americans',
#  'Israeli',
#  'Israeli',
#  'Israeli',
#  'Egyptian',
#  'Palestinian',
#  'High Dam',
#  'Palestinians',
#  'Rolling Meadows',
#  'Rolling Meadows',
#  'Rolling Meadows',
#  'North Monticello',
#  'DuPage County',
#  'Lombard',
#  'Lombard',
#  'Babcock Grove',
#  'Lombard',
#  'Lombard',
#  'Roselle',
#  'Roselle',
#  'Illinois',
#  'Roselle',
#  'DuPage',
#  'Glen Ellyn',
#  'Macon County',
#  'Evergreen Lake',
#  'Des Plaines',
#  'Kenyan',
#  'Kenyan',
#  'North Texas',
#  'Tarrant County',
#  "Burger's Lake",
#  'Fort Worth',
#  'Tarrant County',
#  'Fort Worth',
#  'Texas',
#  'Grand Prairie',
#  'Mansfield',
#  'MANSFIELD',
#  'Mansfield',
#  'Fort Worth',
#  'Eastland County',
#  'Kermanshah',
#  'Texas',
#  'United States',
#  'Islamic Republic',
#  'Colleyville',
#  'North Cooper Street',
#  'Green Oaks Boulevard',
#  'Arlington',
#  'Bucknell Drive',
#  'Washington Drive',
#  'Arlington',
#  'Arlington',
#  'Arlington',
#  'Arlington',
#  'Arlington',
#  'Grand Prairie',
#  'Grand Prairie',
#  'Tarrant County',
#  'Mayfield Road',
#  'State Highway 360',
#  'Forum Drive',
#  'Mayfield Road',
#  'Grand Prairie',
#  'Fort Worth',
#  'Georgia',
#  'Clarke County',
#  'Oconee County',
#  'Georgia',
#  'Jackson',
#  'Barrow County',
#  'Clarke',
#  'Oconee',
#  'Georgia',
#  'Athens',
#  'Clarke County',
#  'Pine Needle Drive',
#  'Sylvan Road',
#  'Athens',
#  'Acadia Drive',
#  'Freeman Drive',
#  'Sunny Hills Drive',
#  'Freeman Circle',
#  'Boley Drive',
#  'Freeman Drive',
#  'Madison Heights',
#  'Strickland',
#  'North',
#  'Danielsville Road',
#  'Berry Lane',
#  'Lombardy Drive',
#  'Strickland',
#  'Ruth Drive',
#  'Strickland Avenue',
#  'Georgia',
#  'Barrow County',
#  'Jackson County',
#  'Clarke',
#  'Georgia',
#  'Barrow',
#  'MONROE',
#  'Georgia',
#  'Walton County',
#  'Walton County',
#  "Moore's Ford",
#  'Walton',
#  "Moore's Ford",
#  'Walton County',
#  'Henderson County',
#  'Texas',
#  'Athens',
#  'Henderson County',
#  'Henderson County',
#  'Athens',
#  'Athens',
#  'CORSICANA',
#  'Henderson County',
#  'Navarro County',
#  'Gun Barrel City',
#  'Kaufman County',
#  'Kaufman County',
#  'Kaufman County',
#  'Navarro County',
#  'Corsicana',
#  'Athens',
#  'Athens',
#  'Knox Park',
#  'McMinn County',
#  'McMinn County',
#  'McMinn County',
#  'Nashville',
#  'Alton',
#  'Evansville',
#  'Princeton',
#  'Madison County',
#  'Gillis Street',
#  'Edwardsville',
#  'Edwardsville',
#  'Illinois Route 159',
#  "Governors' Parkway",
#  'District Drive',
#  'Glen Crossing Road',
#  'Glen Carbon',
#  "Governors' Parkway",
#  'Goshen Road',
#  'Vicksburg',
#  "Governors' Parkway",
#  "Governors' Parkway",
#  'Glen Carbon',
#  'Glen Carbon',
#  'Fort Worth',
#  'Fort Worth',
#  'Fort Worth',
#  'Fort Worth',
#  'Rochester',
#  'COLUMBIA',
#  'South Carolina',
#  'South Carolina',
#  'South Carolina',
#  'New York',
#  'Augusta',
#  'New York',
#  'Augusta',
#  'Augusta',
#  'New York City',
#  'Columbia County',
#  'Richmond County',
#  'Martinez',
#  'Highland Avenue',
#  'Richmond County',
#  'Hot Springs Drive',
#  'Lou Lane',
#  'Columbia County',
#  'Knox Road',
#  'Grovetown',
#  'Ala.',
#  'Grovetown',
#  'Newton County',
#  'Grovetown',
#  'Kings Way',
#  'Columbia County',
#  'Georgia',
#  'Atlanta',
#  'America',
#  'Salisbury',
#  'Sharon',
#  'Falls Village',
#  'HARWINTON',
#  'Harwinton',
#  'Harwinton',
#  'Harwinton',
#  'Burlington',
#  'HARTFORD',
#  'Connecticut',
#  'New England',
#  'New Jersey',
#  'U.S.',
#  'Hartford',
#  'Africa',
#  'BANTAM',
#  'Bantam',
#  'New Milford',
#  'Danbury',
#  'New Milford',
#  'TORRINGTON',
#  'Torrington',
#  'Main St.',
#  'Dawes Street',
#  'Litchfield',
#  'Torrington',
#  'Naugatuck River',
#  'Lois Street',
#  'MIDDLETOWN',
#  'Middletown',
#  'Hartford',
#  'Clinton',
#  'CLINTON',
#  'New Haven',
#  'EAST HAMPTON',
#  'East Hampton',
#  'North Main Street',
#  'Oakdale',
#  'Cherry Hinton',
#  'Flumeri',
#  'Kentford',
#  'Arbury',
#  'Chesterton',
#  'Hills Road',
#  'Cambridgeshire',
#  'Newmarket Road',
#  'Huntingdon Sea',
#  'Mill Road',
#  'Anglesey Abbey',
#  'East Cambridgeshire',
#  'Barton',
#  'Chesterton',
#  'Guernsey County',
#  'Guernsey County',
#  'Guernsey County',
#  'MOUNT GILEAD',
#  'Mount Gilead',
#  'Morrow County',
#  'Richland County',
#  'BYESVILLE',
#  'Indian Lake Road',
#  'Byesville',
#  'Indian Lake Road',
#  'Guernsey County',
#  'Pleasant City',
#  'Lore City',
#  'U.S.',
#  'Ohio',
#  'Franklin County',
#  'Warren County',
#  'Hamilton Township',
#  'Chesterland',
#  'New Concord',
#  'New Concord',
#  'New Concord',
#  'New Concord',
#  'Shadyside Drive',
#  'SOUTH CHARLESTON',
#  'W.Va.',
#  'Southridge',
#  'Southridge',
#  'Capitol Market',
#  'Southridge',
#  'W.Va.',
#  'Charleston',
#  'Charleston',
#  'South Charleston',
#  'Charleston',
#  'W.Va.',
#  'Interstate 64 West',
#  'South Charlston',
#  'SOUTH CHARLESTON',
#  'W.Va.',
#  'South Charleston',
#  'South Charleston',
#  'South Charleston',
#  'West Virginia',
#  'Midland Trail',
#  'Midland Trail',
#  'West Virginia',
#  'Virginia Beach',
#  'Cedar Grove',
#  'Cabell County',
#  'St. Albans',
#  'Kanawha City',
#  'Sunset Memorial Park',
#  'South Charleston',
#  'Shawnee Park',
#  'South Charleston',
#  'Kanawha Valley',
#  'South Charleston',
#  'South Charleston',
#  'D Street',
#  'South Charleston',
#  'MacCorkle Avenue',
#  'Kanawha City',
#  'Central Avenue',
#  'Bronx County',
#  'Kanawha County',
#  'Kanawha County',
#  'American',
#  'Grant County',
#  'South Charleston',
#  'French',
#  'South Charleston',
#  'West Virginia',
#  'South Charleston',
#  'United States',
#  'West Virginia',
#  'American',
#  'German',
#  'American',
#  'Mason County',
#  'American',
#  'Mason County',
#  'Mason County',
#  'American',
#  'Mason County',
#  'Kanawha River',
#  'W.Va.',
#  'Kanawha River',
#  'Haddad Riverfront Park',
#  'Kanawha Boulevard',
#  'Charleston',
#  'West Virginia',
#  'W.Va.',
#  'W.Va.',
#  'Kanawha County',
#  'Nitro',
#  'West Virginia',
#  'Kanawha County',
#  'Las Vegas',
#  'W.Va.',
#  'Monongahela National Forest',
#  'W. Va.',
#  'Americans',
#  'West Virginia',
#  'Roaring Plains West Wilderness',
#  'Dolly Sods Wilderness',
#  'Canaan Valley',
#  'Spice Run Wilderness',
#  'Greenbrier River Valley',
#  'Greenbrier',
#  'Pocahontas County',
#  'Big Draft Wilderness',
#  'Anthony Creek',
#  'Dolly Sods Wilderness',
#  'Williams',
#  'Cranberry',
#  'Cranberry Wilderness',
#  'Dry Fork River',
#  'Otter Creek Wilderness',
#  'Jefferson National Forest',
#  'Mount Hood',
#  'Pictured Rocks National Lakeshore',
#  'Zion National Park',
#  'Rocky Mountain National Park',
#  'W.Va. 61',
#  'East Bank',
#  'Kanawha County',
#  'W.Va. 61',
#  'East Bank',
#  'East Bank',
#  'East Bank',
#  'East Bank',
#  'Kanawha County',
#  'W.Va. 61',
#  'East Bank',
#  'East Bank',
#  'Kanawha County',
#  'W.Va. 61',
#  'First Avenue',
#  'East Bank',
#  'East Bank',
#  'East Bank',
#  'W.Va. 61',
#  'W.Va.',
#  'W.Va.',
#  'West Virginia',
#  'Princeton',
#  'Mercer County',
#  'West Virginia',
#  'W. Va.',
#  'W.Va.',
#  'West Virginia',
#  'W.Va.',
#  'Kanawha County',
#  'Kanawha County',
#  'HURRICANE',
#  'W.Va.',
#  'Putnam County',
#  'Putnam County',
#  'Putnam County',
#  'Kanawha County',
#  'West Virginia',
#  'Hardy',
#  'Raleigh',
#  'Berkeley',
#  'Raleigh',
#  'McDowell',
#  'West Virginia',
#  'Charleston',
#  'Charleston',
#  'ATLANTIC BEACH',
#  'South Carolina',
#  'Atlantic Beach',
#  'Myrtle Beach',
#  'Horry County',
#  'North Myrtle Beach',
#  'Goose Creek',
#  'Goose Creek',
#  'ISLE OF PALMS',
#  'Wild Dunes',
#  'Wild Dunes',
#  'Francis Street',
#  'Hampton Park',
#  'Columbia',
#  'Columbia',
#  'Lexington County',
#  'Lexington County',
#  'Lexington County',
#  'Lexington',
#  'W. Columbia',
#  'Parkwood Drive',
#  'West Columbia',
#  'Lexington County',
#  'Columbia',
#  'Columbia',
#  'Lexington County',
#  'Batesburg-Leesville',
#  'Batesburg-Leesville',
#  'South Carolina',
#  'South Carolina',
#  'Greer',
#  'Lake Robinson',
#  'Lake Cunningham',
#  'Apalache Lake',
#  'Greenville',
#  'Spartanburg',
#  'Greer',
#  'Greer Station',
#  'Greer Station',
#  'Greer Station',
#  'Greer Station',
#  'Greer',
#  'West Columbia',
#  'West Columbia',
#  'West Columbia',
#  'Columbia',
#  'West Columbia',
#  'South Carolina',
#  'West Columbia',
#  'West Columbia',
#  'Lexington County',
#  'Maury County',
#  'LAWRENCEBURG',
#  'South Central',
#  'South Central',
#  'Williamson County',
#  'Tennessee',
#  'Lawrenceburg',
#  'Shelbyville',
#  'Williamson County',
#  'Ohio',
#  'Ohioans',
#  'Ohio',
#  'New England',
#  'East Fourth Street',
#  'Ashland',
#  'West Virginia',
#  'Wood County',
#  'W. Va.',
#  'W. Va.',
#  'Meigs County',
#  'Meigs County',
#  'Meigs County',
#  'Pleasant Township',
#  'Madison Township',
#  'Grove City',
#  'Pleasant',
#  'Ohioans',
#  'Franklin County',
#  'Briarcliff Road',
#  'DeKalb County',
#  'LaVista Road',
#  'Briar Vista',
#  'DeKalb County',
#  'North Druid Hills',
#  'DeKalb County',
#  'North Druid Hills',
#  'DeKalb',
#  'North Druid Hills',
#  'Avondale Estates',
#  'Avondale Estates',
#  'DeKalb County',
#  'Sams Crossing',
#  'Avondale',
#  'Clayton County',
#  'Clayton County',
#  'Lovejoy',
#  'Lovejoy',
#  'Ohio',
#  'Georgia',
#  'Sycamore',
#  'DeKalb County',
#  'Hopkins Park',
#  'DeKalb County',
#  'DeKalb County',
#  'S. Seventh St.',
#  'W. Dresser Road',
#  'North Seventh Street',
#  'Malta Road',
#  'DeKALB',
#  'DeKalb',
#  'Illinois',
#  'Charter',
#  'Kish River',
#  'Kishwaukee River',
#  'Hopkins Park',
#  'DeKalb County',
#  'West Allis',
#  'Hopkins Park',
#  'Irish',
#  'Irish',
#  'Dublin',
#  'Dublin',
#  'Dublin',
#  'Dublin',
#  'Dublin',
#  'Hyland-Croy Road',
#  'Hyland-Croy Road',
#  'Jerome Township',
#  'Dublin',
#  'Dublin',
#  'Cuyahoga Falls',
#  'Carriage Place',
#  'Wichita Street',
#  'Wichita Drive',
#  'Dublin',
#  'Franklin County',
#  'Wichita Street',
#  'Wichita Drive',
#  'Wichita Street',
#  'Wichita Drive',
#  'Wichita Drive',
#  'Wichita Drive',
#  'Darby Street',
#  'Dublin',
#  'North Street',
#  'North Street',
#  'Dublin',
#  'Dublin',
#  'Dublin',
#  'Dublin',
#  'Dublin',
#  'Dublin',
#  'Dublin',
#  'Post Road',
#  'Dublin',
#  'Dublin',
#  'Dublin Center Drive',
#  'Ohio',
#  'Bolding Mill',
#  'Chestatee River',
#  'Lake Lanier',
#  'North Hall',
#  'Flat Creek',
#  'Flat Creek',
#  'Gainesville',
#  'McEver Road',
#  'Hall County',
#  'Georgia',
#  'Lake Lanier',
#  'Hall County',
#  'Forsyth County',
#  'Hall County',
#  'Gwinnett County',
#  'Gwinnett',
#  'Gwinnett County',
#  'Norman',
#  'D.C.',
#  'U.S.',
#  'Norman',
#  'Cooke County',
#  'U.S.',
#  'Wichita Falls',
#  'Cooke County',
#  'FM 678',
#  'Highway 82',
#  'Cooke County',
#  'Red River',
#  'Grand Avenue',
#  'Grand Avenue',
#  'Lindsay',
#  'Cooke County',
#  'American',
#  'Texas',
#  'Aleutian Islands',
#  'Far East',
#  'Middle East',
#  'Soviet Union',
#  'Chinese',
#  'Texan',
#  'Chinese',
#  'Lindsay',
#  'Lindsay',
#  'Cooke County',
#  'Lindsay',
#  'Cooke County',
#  'Cooke',
#  'Grayson',
#  'Love',
#  'Gainesville',
#  'Gainesville',
#  'Gainesville',
#  'Gainesville',
#  'California Street',
#  'Gainesville',
#  'Holly Heights',
#  'Chiefland',
#  'Chiefland',
#  'Levy County',
#  'Florida',
#  'Chiefland',
#  'Cross City',
#  'Alachua County',
#  'Chiefland',
#  'Hardeetown',
#  'Chiefland',
#  'Levy County',
#  'Williston',
#  'Georgia',
#  'St. Marys River',
#  'St. Marys',
#  'St. Marys River',
#  'St. Marys',
#  'St. Marys River',
#  'St. Marys River',
#  'Baker',
#  'Charlton County',
#  'Ocilla',
#  'Georgia',
#  'Fitzgerald',
#  'Georgia',
#  'United States',
#  'Pa.',
#  'Georgia',
#  'Hall County',
#  'Hall County',
#  'Hall County',
#  'Georgia',
#  'Lake Lanier',
#  'Lake Hartwell',
#  'Hartsfield',
#  'Jackson',
#  'Georgia',
#  'Atlanta',
#  'America',
#  'Abkhaz',
#  'S.Ossetian',
#  'South Ossetia',
#  'Georgian',
#  'Georgia',
#  'Tbilisi',
#  'Georgia',
#  'Georgian',
#  'Dvani',
#  'Georgian',
#  'Dvani',
#  'United States',
#  'Abkhaz',
#  'Ochamchire',
#  'Abkhaz',
#  'Georgian',
#  'Georgian',
#  'Abkhaz',
#  'Abkhaz',
#  'Abkhaz',
#  'Ochamchire',
#  'South Ossetia',
#  'Georgian',
#  'South Ossetian',
#  'South Ossetia',
#  'South Ossetian',
#  'Georgian',
#  'Georgian',
#  'Russian',
#  'Georgian',
#  'Georgian',
#  'South Ossetians',
#  'South Ossetians',
#  'Georgian',
#  'Georgian',
#  'Georgian',
#  'South Ossetian',
#  'Georgian',
#  'Ossetian',
#  'South Ossetian',
#  'Georgian',
#  'Prisi',
#  'Georgian',
#  'Prisi',
#  'Tamarasheni',
#  'Georgian',
#  'Georgian',
#  'Georgian',
#  'South Ossetian',
#  'Caucasus',
#  'Tskhinvali',
#  'Georgian',
#  'Georgian',
#  'Russian',
#  'South Ossetia',
#  'Georgian',
#  'Russian Federation',
#  'Russian Federation',
#  'Georgian',
#  'Russian',
#  'Russian',
#  'Russian',
#  'South Ossetian',
#  'Tskhinvali',
#  'Tskhinvali',
#  'Georgian',
#  'South Ossetia',
#  'South Ossetian',
#  'Russian',
#  'North Ossetian',
#  'South Ossetian',
#  'Georgian',
#  'South Ossetia',
#  'Latvian',
#  'Latvian',
#  'Latvians',
#  'Svaneti',
#  'Ushba',
#  'Georgian',
#  'Hartford',
#  'Walker County',
#  'Huntsville',
#  'Walker County',
#  'Walker County',
#  'Huntsville',
#  'Walker County',
#  'Walker County',
#  'Calif',
#  'New York',
#  'N.D.',
#  'New York',
#  'Walker County',
#  'Walker County',
#  'Huntsville',
#  'Walker County',
#  'Walker County',
#  'Capitol Hill',
#  'Russian',
#  'California',
#  'Capitol Hill',
#  'N.D.',
#  'Huntsville',
#  'Walker County',
#  'Interstate 45',
#  'Highway 19',
#  'Huntsville',
#  'Highway 19',
#  'Walker County',
#  'Avenue Q',
#  'Huntsville',
#  'Sam Houston State University',
#  'Walker County',
#  'Walker County',
#  'Jordan',
#  'Jordan',
#  'Sand Creek Township',
#  'Marystown Road',
#  'Jackson County',
#  'Watertown',
#  'Delano',
#  'Watertown',
#  'Scott County',
#  'St. Paul',
#  'Plainview',
#  'Elgin',
#  'Belle Plaine',
#  'Belle Plaine',
#  'Watertown',
#  'Mayer',
#  'Jordan',
#  'United States',
#  'Jordan',
#  'Johnson County',
#  'Johnson County',
#  'Johnson County',
#  'Leavenworth County',
#  'Douglas',
#  'Kansas City',
#  'Jackson County',
#  'East Elm Street',
#  'Kansas City',
#  'Cass County',
#  'Cass County',
#  'Kansas City',
#  'Kansas City',
#  'Wyandotte County',
#  'Kansas City',
#  'Roanoke Park',
#  'Kansas City',
#  'Kansas City',
#  'Kansas City',
#  'Blue Springs',
#  'Jackson County',
#  'Blue Springs',
#  'North Kansas City',
#  'North Kansas City',
#  'Kansas City',
#  'North Kansas City',
#  'Kansas City',
#  'Kansas City',
#  'Platte City',
#  'Vivion Road',
#  'North Oak Trafficway',
#  'Kansas',
#  'Riley',
#  'Boulder City',
#  'Boulder City',
#  'Eldorado Valley',
#  'Henderson',
#  'Boulder City',
#  'Boulder City',
#  'U.S.',
#  'Boulder City',
#  'Boulder City',
#  'North Las Vegas',
#  'North Las Vegas',
#  'North Las Vegas',
#  'Revere Street',
#  'Ann Road',
#  'North Las Vegas',
#  ...]

# %%
# Filtered toponyms
fps, fns = evaluate.evaluate(data_filtered_toponyms, processed_results)
# Out:
# fp: 1202 | tp: 2029 | fn: 2214
# precision: 0.628 | recall: 0.478 | f-score: 0.543

# %%
fps
# Out:
# ['Orchard St.',
#  'Pogemiller',
#  'Twin Lakes - Highway',
#  'Pelican Rapids',
#  'the Red River',
#  'Red River',
#  'the Red River Valley',
#  'North Dakota',
#  'Oakport Township',
#  'Groth',
#  'Fargo City',
#  'Red River',
#  'Lake Vermont',
#  'Nokomis',
#  'North Nokomis Street',
#  'New Haven',
#  'Sioux Falls',
#  'New Haven',
#  'the Alexandria City Public Schools',
#  'Old Town',
#  'Old Town',
#  'New York City',
#  'Old Town',
#  'Northwest D.C.',
#  'Cutts',
#  'Southern Sudan',
#  'Sub-Saharan Africa',
#  'Godapitiya',
#  'Sri Lanka',
#  'Sri Lanka',
#  'Sri Lanka',
#  'Sri Lanka',
#  'Sri Lanka',
#  'Petrojet',
#  'Zamalek',
#  'Esperance',
#  'Esperance',
#  'US',
#  'the Middle East',
#  'Gulf',
#  'the Middle East',
#  'Gulf',
#  'US',
#  'US',
#  'US',
#  'the West Bank',
#  'Gulf',
#  'US',
#  'Gulf',
#  'the Middle East',
#  'US',
#  'Sharm El-Sheikh',
#  'the High Dam',
#  'North Monticello',
#  'DuPage County',
#  'Babcock Grove',
#  'Charlotte',
#  'Glen Ellyn',
#  'Woodfield',
#  'Macon County',
#  'Hudson',
#  'Evergreen Lake',
#  'Decatur',
#  'Des Plaines',
#  'North Texas',
#  'Tarrant County',
#  'Fort Worth',
#  'Tarrant County',
#  'Fort Worth',
#  'Houston',
#  'Fort Worth',
#  'Eastland County',
#  'Kermanshah province',
#  'North Texas',
#  'the United States',
#  'the Islamic Republic',
#  'North Arlington Neighbors',
#  'South Arlington',
#  'Northeast Georgia',
#  'Oconee County',
#  'Northeast Georgia',
#  'Athens-Clarke County',
#  'North Lumpkin Street',
#  'Northeast Georgia',
#  'Barrow County',
#  'Northeast Georgia',
#  'Walton County',
#  'Walton County',
#  "Walton County's",
#  'McKinney',
#  'Holstein',
#  'Henderson County',
#  'Navarro County',
#  'Barrel City',
#  'Marriott',
#  'Marriott',
#  'Kaufman County',
#  'Kaufman County',
#  'Torenia',
#  'Kaufman County',
#  'McMinn County',
#  'Metro Nashville',
#  'County',
#  'Madison County',
#  'The City of Edwardsville',
#  'District Drive',
#  'Glen Carbon',
#  'Fort Worth',
#  'Fort Worth',
#  'Fort Worth',
#  'South Carolina',
#  'South Carolina',
#  'Columbia County',
#  'Richmond County',
#  'Newton County',
#  'Falls Village',
#  'New England',
#  'New Jersey',
#  'West Africa',
#  'New Milford',
#  'the Naugatuck River',
#  'EAST HAMPTON - Police',
#  'East Hampton',
#  'North Main Street',
#  'the Huntingdon Sea Cadets',
#  'St Ives',
#  'Mount Gilead',
#  'Richland County',
#  'Pleasant City',
#  'Franklin County',
#  "Warren County's",
#  'CHARLESTON',
#  'W.Va. - Jim McMillon',
#  'South Charleston',
#  'CHARLESTON',
#  'W.Va.',
#  'South Charleston',
#  'South Charleston',
#  'South Charleston',
#  'West Virginia',
#  'Virginia Beach',
#  'Cedar Grove',
#  'Cabell County',
#  'St. Albans',
#  'Kanawha City',
#  'South Charleston',
#  'Shawnee Park',
#  'the Kanawha Valley',
#  'South Charleston',
#  'South Charleston',
#  'Knights Inn',
#  'Kanawha City',
#  'Bronx County',
#  'Kanawha County',
#  'Kanawha County',
#  'Grant County',
#  'South Charleston',
#  'South Charleston',
#  'West Virginia',
#  'South Charleston',
#  'West Virginia',
#  'Mason County',
#  'Mason County',
#  'Kanawha River',
#  'W.Va.',
#  'the Kanawha River',
#  'W.Va.',
#  'Kanawha County',
#  'Tri-State',
#  'Kanawha County',
#  'Tri-State',
#  'Tri-State',
#  'Las Vegas',
#  'W.Va.',
#  'Manchester',
#  'Plains West Wilderness',
#  'Canaan Valley',
#  'the Greenbrier River Valley',
#  'Anthony Creek',
#  'Monongahela',
#  'the Cranberry Wilderness',
#  'the Dry Fork River',
#  'the Otter Creek Wilderness',
#  'Manchester',
#  "Mount Hood's",
#  'W.Va',
#  'East Bank',
#  'Kanawha County',
#  'East Bank',
#  'East Bank',
#  'Kanawha County',
#  'East Bank',
#  'East Bank',
#  'Kanawha County Emergency',
#  'W.Va',
#  'W.Va.',
#  'West Virginia',
#  'Mercer County',
#  'Virginia',
#  'W.Va.',
#  'W.Va.',
#  'Kanawha County',
#  'W.Va.',
#  'Putnam County',
#  'Putnam County',
#  'Putnam County',
#  'Kanawha County',
#  'West Virginia',
#  'West Virginia',
#  'Bikefest',
#  'ATLANTIC BEACH',
#  'South Carolina',
#  'Myrtle Beach',
#  'Atlantic Beach',
#  'Myrtle Beach',
#  'Horry County',
#  'Goose Creek - A Goose Creek',
#  'Hampton Park',
#  'Lexington County',
#  'DUI',
#  'Lexington County',
#  'Lexington County',
#  'Gaston',
#  'W. Columbia',
#  'Parkwood Drive',
#  'West Columbia',
#  'Lexington County',
#  'Gaston',
#  'Lexington County',
#  'Batesburg-Leesville',
#  'Ravenel',
#  'South Carolina',
#  'South Carolina',
#  'Apalache Lake',
#  'City Park',
#  'West Columbia City Council',
#  'the West Metro Chamber of Commerce',
#  "West Metro's",
#  'West Columbia',
#  'West Columbia',
#  'South Carolina',
#  'West Columbia',
#  'the South Central District',
#  'South Central',
#  'Williamson County',
#  'Tennessee',
#  'the South Central District',
#  'Galaxy Lanes',
#  'Recreation',
#  'Williamson County',
#  'Tennessee',
#  'New England',
#  'East Fourth Street',
#  'Drawbough',
#  'West Virginia',
#  'Wood County',
#  'W. Va.',
#  'the North Central Regional Jail',
#  'W. Va.',
#  'Meigs County',
#  'Meigs County',
#  'County',
#  'Pleasant Township',
#  'Madison Township',
#  'Grove City',
#  'Briarcliff',
#  'DeKalb County',
#  'Briarcliff',
#  'Briar Vista',
#  'DeKalb County',
#  'Clairmont',
#  'North Druid Hills',
#  'Clairmont',
#  'North Druid Hills Road',
#  'DeKalb County',
#  'Clayton County',
#  'Clayton County',
#  'South Fourth Street',
#  'DeKalb County',
#  'Hopkins Park',
#  'DeKalb County',
#  'Culver',
#  'Culver',
#  'Kish River',
#  'the Kishwaukee River',
#  'Hopkins Park',
#  'DeKalb County',
#  'West Allis',
#  'Hopkins Park',
#  'Historic District',
#  'Talla 2',
#  'Jerome Township',
#  'Cuyahoga Falls',
#  'Wichita',
#  'Historic Dublin',
#  'North Street',
#  'Darby',
#  'North Street',
#  'Flat Creek',
#  'Flat Creek',
#  'Orchard Brook',
#  "Lake Lanier's",
#  'Hall County',
#  'Forsyth County',
#  'Hall County',
#  'Bankolemoh',
#  'Norman to D.C',
#  'Washington',
#  'Cooke County',
#  'Wichita',
#  'Cooke County',
#  'Texoma',
#  'Cooke County',
#  'North Texas',
#  'the Southwest Pacific',
#  'the Aleutian Islands',
#  'the Far East',
#  'the Middle East',
#  'the Soviet Union',
#  'Tex Hill',
#  'Rodeo Gainesville',
#  'the Rodeo Gainesville',
#  'Holly Heights',
#  'Alachua County',
#  'S.W. Second Terrace',
#  'Micanopy',
#  'St. Marys River',
#  'St. Marys - The',
#  'St. Marys River',
#  'the United States',
#  'Midtown',
#  'Hall County and',
#  'Hall County',
#  'North Georgia',
#  'Lake Hartwell',
#  'South Ossetia',
#  'United Georgia',
#  'Tskhinvali',
#  'U.S.',
#  'the United States',
#  'Achguara',
#  'the Ochamchire district',
#  'South Ossetia',
#  'the South Ossetians',
#  'the South Ossetians',
#  'Utiashvili',
#  'Tskhinvali',
#  'the North Caucasus',
#  'Utiashvili',
#  'South Ossetia',
#  'the Russian Federation',
#  'Tskhinvali',
#  'North Ossetian',
#  'South Ossetian',
#  'South Ossetia',
#  'Walker County',
#  'Walker County',
#  'Walker County',
#  'Walker County',
#  'Walker County',
#  'Taji',
#  'Huntsville City',
#  'the City of Huntsville',
#  'Walker County',
#  'Sand Creek Township',
#  'Jackson County Central',
#  'Delano',
#  'Kivel',
#  'Hentges',
#  'Scott County',
#  'Delano',
#  'Milaca',
#  'Johnson County',
#  'Johnson County',
#  'Johnson County',
#  'Leavenworth County',
#  'Kansas City',
#  'Jackson County',
#  'East Elm Street',
#  'Cass County',
#  'Kansas City',
#  'Kansas City',
#  'Wyandotte County District Court',
#  'Kansas City',
#  'Roanoke Park',
#  'Kansas City',
#  'Kansas City',
#  'South 13th Terrace',
#  'the Kansas City',
#  'Blue Springs',
#  'Northland',
#  'North Kansas City',
#  'Northland',
#  'North Kansas City',
#  'Kansas City',
#  'Kansas City',
#  'North',
#  'Kansas City',
#  'Boulder City',
#  'the Eldorado Valley',
#  'Henderson',
#  'Boulder City',
#  'Boulder City',
#  'Boulder City',
#  'Boulder City',
#  'North Las Vegas',
#  'North Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas Valley',
#  'Las Vegas',
#  'Las Vegas',
#  'Decatur',
#  'Las Vegas',
#  'San Diego',
#  'Las Vegas',
#  'Interfaith Manor',
#  'North Annville Township',
#  'New York City',
#  'Jackson Township',
#  'the H. L. Snyder Funeral Home, Inc.',
#  'Pine Grove',
#  "the St. John's Union Cemetery",
#  "Boone County's",
#  "St. Patrick's",
#  'Boone County',
#  'Fairfield',
#  'Boone County',
#  'East Washington Street',
#  'the Boone County Jail',
#  "Boone County's",
#  "Boone County's",
#  "Boone County's",
#  'Montgomery County',
#  'Boone County',
#  "Boone County's",
#  'Maameltein',
#  'Allaw',
#  'AMEL',
#  'NGO',
#  'NGO',
#  'AMEL',
#  'BEIRUT',
#  'the Bekaa Valley',
#  'Mieh Mieh',
#  'Readington Township',
#  'Mulligan Quarry',
#  'ST',
#  'the North Atlantic',
#  'Newfoundland',
#  'Kingsmills',
#  'Erie',
#  'North America',
#  'Quebec City',
#  'Waterford',
#  'Laurel County',
#  'Laurel County',
#  "the 5th District's",
#  'Laurel County',
#  'Laurel County',
#  'Clay County',
#  'Laurel County',
#  'Laurel County',
#  'Laurel County',
#  'Laurel County',
#  'Eastern Redbud',
#  'Laurel County',
#  'Laurel County',
#  'Clark County',
#  "Clark County's",
#  'Southeastern Confernce',
#  'Lybia',
#  'Los Angeles',
#  'Los Angeles',
#  'Los Angeles',
#  'Los Angeles',
#  'Los Angeles',
#  'Los Angeles',
#  'El Dorado Avenue',
#  'the Antelope Valley Freeway',
#  'San Fernando City',
#  'Los Angeles',
#  'Los Angeles',
#  "Los Angeles'",
#  'New Delhi',
#  'Los Angeles',
#  'the South Coast Air Quality Management District',
#  'Santa Ana',
#  'Los Angeles',
#  'Harbor City',
#  'Mount Washington',
#  'Los Feliz',
#  'Historic',
#  'Los Angeles',
#  'Echo Park',
#  'Mount Washington',
#  'Los Angeles',
#  'Orange County',
#  'Orange County',
#  'Vuelta',
#  'Castilla',
#  'the United States',
#  'Castilla',
#  'South L.A',
#  'South Los Angeles',
#  'East 51st Street',
#  'West 11th Street',
#  'San Diego',
#  'San Diego State',
#  'Dallas',
#  'Riley County',
#  'Pottawatomie County',
#  'Kane County',
#  'Jefferson County',
#  'St. George',
#  'Kansas',
#  'KANSAS CITY',
#  'Marion County',
#  'Riley County',
#  'Anderson County',
#  'Flint Hills',
#  'Dodge City',
#  'Garden City',
#  'Dodge City',
#  'Pratt County',
#  'Dodge City',
#  'Daytona Beach',
#  'Volusia County',
#  'Volusia County',
#  'DeLand',
#  'Seminole County',
#  'I-95',
#  'Pacific Ocean',
#  'Volusia County',
#  'Osceola County',
#  'South Florida',
#  'Panama City',
#  'New York',
#  'St. Petersburg',
#  "New York's",
#  "St. Petersburg's",
#  'St. Petersburg',
#  'North America',
#  'New York',
#  'the United States',
#  'Dulles',
#  'New York',
#  'Los Angeles',
#  'Rego Park',
#  'New York',
#  'the United States',
#  'New York',
#  'the North Caucasus',
#  'United Russia',
#  'non-United Russia',
#  'United Russia',
#  'United Russia',
#  'United Russia',
#  'Yevdokimov',
#  'United Russia',
#  'United Russia',
#  'United Russia',
#  'New London',
#  'New London',
#  'New London',
#  'New London',
#  'Culver',
#  'Culver',
#  'Henry',
#  'Des Moines',
#  'the Southeast District Competition',
#  'Iowa City',
#  'Mt. Pleasant',
#  'Henry County',
#  'Big Creek',
#  'Midwest',
#  'Mount Vernon',
#  'Mount Pleasant',
#  'the City of Canton',
#  'Mount Pleasant',
#  'Hellinghausen',
#  'Mount Pleasant',
#  'Texas',
#  'Mount Pleasant',
#  'Sulphur Springs',
#  'North Carolina',
#  "North Carolina's",
#  'Sandhills region',
#  'Pinelake',
#  'Pinelake',
#  'New Zealand',
#  'New Zealand',
#  "the United States'",
#  'New Hampshire',
#  'New Zealand',
#  'New Zealand',
#  "New Zealand's",
#  'New Zealand',
#  'North Island',
#  'Licking County',
#  'Licking County',
#  'Licking County cities',
#  'Valley',
#  'Licking Valley',
#  'Licking County',
#  'Farallon Islands',
#  'Cassin',
#  'Santa Cruz',
#  'Delta',
#  'Alameda County',
#  'Tri-City',
#  'Tri-City',
#  'New Haven',
#  'New Haven',
#  'New Haven',
#  'Bay Area',
#  'D-N.J.',
#  'Cedar County',
#  'Cedar County',
#  'Cedar County',
#  'Montessori',
#  'Montessori',
#  'the City of Norfolk',
#  'North Fork River',
#  "Northeast Nebraska's",
#  'Diamond Dick District',
#  'Battle Creek',
#  'Northeast Nebraska',
#  'East Oxford',
#  'East Oxford',
#  'UK',
#  'Weston',
#  'Chesteron',
#  'Holm Way',
#  'Manzil Way',
#  'Cleveland Drive',
#  'East Oxford',
#  'Butler County',
#  'West Chester',
#  'Butler County',
#  'West Chester Twp',
#  'South Bend',
#  'South Bend',
#  'BUTLER COUNTY - Butler County Community',
#  'Lake Ontario',
#  'Patullo Ridge',
#  'the United States',
#  'Europe',
#  'Europe',
#  'the Czech Republic',
#  'the United States',
#  'the United States',
#  'Arctic coast',
#  'Renfrew County',
#  'Juvederm',
#  'Lycka',
#  'the Province of Ontario',
#  'Tavistock',
#  'Henderson County',
#  'the Gulf of Mexico',
#  'Neches River Valley',
#  'Caddo',
#  'the Neches River National Wildlife Refuge',
#  'Big Slough Wilderness',
#  'Upland Island Wilderness',
#  'Neches River',
#  'the Neches River National Wildlife Refuge',
#  'East Texas',
#  'the Neches River National Wildlife Refuge',
#  'Tennessee Colony',
#  'Tennessee Colony',
#  'Anderson County',
#  'Paris',
#  'Paris',
#  'Anderson County',
#  'Anderson County',
#  'Freestone County',
#  'Freestone County',
#  'the Anderson County Jail',
#  'Anderson County',
#  'Anderson County',
#  'Anderson County',
#  'Tennessee Colony',
#  'U.S',
#  'the United States',
#  'New York',
#  'North Carolina',
#  'Anderson County',
#  'Vermilion Grove',
#  'Midwest',
#  'St. Louis',
#  'Eastern Illinois Area',
#  'Edgar County',
#  'The City of Paris',
#  'Schwartz',
#  'Henry County',
#  'Henry County',
#  'Motels',
#  'East Ridge',
#  'Henry County',
#  'Benton County',
#  'Carroll County',
#  'Stewart County',
#  'Weakley County',
#  'Williamson County',
#  'El Salvador',
#  'Delaware Bay beach',
#  'Fumo',
#  'Fumo',
#  'Fumo',
#  'South Philadelphia',
#  'Fumo',
#  'South Philadelphia',
#  'W. Phila',
#  'Phila',
#  'Woodlands',
#  'Woodlands',
#  'South Fayette',
#  'North Shore',
#  'Columbus',
#  'North Shore',
#  'North Shore',
#  'the Market Districts',
#  'Bethel Park',
#  'Chabad',
#  'Market District',
#  'Waterford',
#  'Westmoreland County',
#  'Ann Arbor',
#  'Grand River',
#  'Charles City County',
#  'Charles City',
#  'the James River',
#  'Charles City',
#  'Charles City',
#  'Henrico County',
#  'North Carolina',
#  'Earth',
#  'Chesapeake Bay',
#  'Earth',
#  'Earth',
#  'Earth',
#  'Prince William County Circuit Court',
#  'York County',
#  'York County',
#  'Greene',
#  'Henrico County',
#  'North Side',
#  'North Richmond',
#  "St. Patrick's",
#  'Darke County',
#  'Jordan',
#  'East Chicago',
#  'Hammond Marina',
#  'East Chicago',
#  "Warren County's",
#  'Hamilton Township',
#  'Cambridge City',
#  'Henrico County',
#  'Sledding',
#  'Chesterfield County',
#  'Chesterfield County Police',
#  'New York',
#  'Taliaferro',
#  'Madison County',
#  'Rockcastle County',
#  'North',
#  'Madison County',
#  'Jefferson County',
#  'Madison County',
#  'McLean County',
#  'Montgomery County',
#  'Madison County',
#  'Camelot',
#  'Townmead',
#  'Hampton',
#  'TfL',
#  'TfL',
#  'Dziekanski',
#  'Dziekanski',
#  'Millington',
#  'Bo Kong Vegetarian Restaurant',
#  'The Bo Kong Vegetarian Restaurant',
#  'Metro Vancouver',
#  'Metro Vancouver',
#  'B.C.',
#  'the Lower Mainland',
#  'the Gulf of Alaska',
#  'B.C.',
#  'El Nino',
#  'Penac',
#  'New York City',
#  'Hudson',
#  'the Russian Empire',
#  'the Soviet Union for America',
#  'San Diego',
#  'St. Petersburg',
#  'the Soviet Union',
#  'the United States',
#  'New York',
#  'Los Angeles',
#  'the Russian Empire',
#  'Shaab district',
#  'St. Petersburg',
#  'Sochi',
#  "St. Petersburg's",
#  'St. Petersburg',
#  'St. Petersburg',
#  'Black Sea',
#  'the Nice of Russia',
#  'United Russia',
#  'Earth',
#  'Santa Clara',
#  'Santa Clara',
#  'Santa Clara',
#  'Rhode Island',
#  'Santa Clara County',
#  'SAN FRANCISCO',
#  'San Francisco',
#  'San Francisco',
#  'Santa Clara',
#  'Valley Water District',
#  "Silicon Valley's",
#  'Santa Clara',
#  'Santa Clara County',
#  'Los Altos',
#  'Morgan Hill',
#  'Santa Clara County',
#  'Santa Clara County',
#  'Santa Clara County',
#  'Trapani',
#  'Trapani',
#  'Trapani',
#  'Los Angeles',
#  'Los Angeles',
#  'Jurassic Park',
#  'San Jose',
#  'San Jose',
#  'Santa Clara County',
#  'West Stockbridge',
#  'West Newton',
#  'West Stockbridge',
#  'New York',
#  'Western Massachusetts',
#  'Long Island',
#  'Western Mass.',
#  'West Springfield',
#  'Western Massachusetts',
#  'New York City',
#  'Logan-Rogersville',
#  'Logan-Rogersville',
#  'Greene County',
#  'Webster County',
#  'Greene County',
#  'Watts',
#  'ST',
#  'PARIS',
#  'St. Paris',
#  'Ohio',
#  'Yellow Springs',
#  'Yellow Springs',
#  'Greene County',
#  'New Miami',
#  'New Miami',
#  'Butler County',
#  'the Butler County Jail',
#  'ST',
#  'PARIS',
#  'St. Paris',
#  'Springfield City Schools',
#  'Muscogee County',
#  'Fort Knox',
#  'Fort Benning',
#  'Muscogee County',
#  'the Chattahoochee River',
#  'Phenix City',
#  'Phenix City',
#  'Rock Hill',
#  "South Carolina's",
#  'the Catawba River',
#  'the Catawba River',
#  'Rock Hill',
#  'Fort Mill',
#  'York County',
#  'the Catawba River',
#  'the Carolina Thread',
#  'Birkdale Village',
#  'Cel-River Road',
#  'Rock Hill City',
#  'Rock Hill',
#  'Marketgate',
#  'Red Sea',
#  'St. Kitts',
#  'Nevis',
#  'Schalit',
#  'the Gaza Strip',
#  'the West Bank',
#  'the Gaza Strip',
#  'the West Bank',
#  'the West Bank',
#  'the West Bank',
#  'the West Bank',
#  'Saudi Arabia',
#  'Saudi Arabia',
#  'Olmsted County',
#  'Plains',
#  'ST',
#  'South St. Paul',
#  'N.W. Rochester',
#  'Lamar County',
#  'Lamar County',
#  'Sun Valley',
#  "Sun Valley's",
#  'S.E. Paris',
#  'Oaks Apartments',
#  'Northeast Texas',
#  'Metroplex',
#  'Northeast Texas',
#  'Birch',
#  'Birch',
#  'DFW',
#  'Lamar County',
#  'Columbus East',
#  'Columbus North',
#  'Kenton County',
#  'Smoky Mountains',
#  'the Nebraska Sandhills',
#  'Nord',
#  'Europe',
#  'Mideast',
#  'Mideast',
#  'New York',
#  'Southwest Asia',
#  'Gulf',
#  'Near East',
#  'Mideast',
#  'the Middle East',
#  'the Czech Republic',
#  'the Gaza Strip',
#  'the Golan Heights',
#  'the United States',
#  'the Czech Republic',
#  'West Bank',
#  'West Bank',
#  'the West Bank',
#  'the Gaza Strip',
#  'the West Bank',
#  'North',
#  'North',
#  "St Therese's",
#  'Drive',
#  'Carrowclough',
#  'Carrowclough',
#  'the River Pollagh',
#  'Platte County',
#  'Sherman County',
#  'Loup City',
#  "Lincoln County's",
#  'Madison County',
#  'Meadow Grove',
#  'Meadow Grove',
#  'Meadow Grove',
#  'Meadow Grove',
#  'Meadow Grove',
#  'Trenton Kuta',
#  'Lakeview',
#  'Vt.',
#  'Lake Opechee',
#  'New England',
#  'Cpl',
#  'Cpl',
#  'Anbar',
#  'New Hampshire']

# %%
fns
# Out:
# ['Mansfield',
#  'Mansfield',
#  'Shreveport',
#  'Mansfield',
#  'Cook',
#  'Minneapolis',
#  'Mahnomen',
#  'Twin Lakes',
#  'Otter Tail County',
#  'Pelican Rapids',
#  'Star Lake',
#  'Douglas County',
#  'Minnesota',
#  'Minnesota',
#  'Alexandria',
#  'Red River',
#  'Fargo',
#  'Moorhead',
#  'Red River',
#  'Fargo',
#  'Fargo',
#  'North Dakota',
#  'Oakport Township',
#  'Moorhead',
#  'Red River',
#  'Moorhead',
#  'Minnesota',
#  'Fargo',
#  'Fargo',
#  'Red River',
#  'Fargo',
#  'Douglas County',
#  'Lake Vermont',
#  'Brandon',
#  'Freeborn Lake',
#  'Alexandria',
#  'Alexandria',
#  'New Haven',
#  'Sioux Falls',
#  'S.D.',
#  'Surprise',
#  'Alexandria',
#  'New Haven',
#  'Alexandria',
#  'Alexandria',
#  'New York City',
#  'D.C.',
#  'D.C.',
#  'Sudanese',
#  'Sudan',
#  'Chinese',
#  'Africa',
#  'African',
#  'Egyptian',
#  'Egyptian',
#  'Sudan',
#  'Sudanese',
#  'Sudanese',
#  'Sudanese',
#  'Sudanese',
#  'Egyptian',
#  'Sudanese',
#  'Sudanese',
#  'Sudanese',
#  'Sudanese',
#  'Sudanese',
#  'Sudanese',
#  'Egyptian',
#  'Sudanese',
#  'Sudanese',
#  'Alexandria',
#  'Sudanese',
#  'Sri Lankan',
#  'Sri Lankan',
#  'Sinhalese',
#  'Sri Lanka',
#  'Sinhalese',
#  'Sinhalese',
#  'Sri Lanka',
#  'Sri Lanka',
#  'Sri Lanka',
#  'Sri Lankan',
#  'Sri Lankan',
#  'Sri Lankan',
#  'Sri Lankan',
#  'Sri Lankan',
#  'Sri Lankan',
#  'Sri Lankan',
#  'Sinhalese',
#  'Sri Lanka',
#  'Sri Lanka',
#  'Sinhalese',
#  'Sri Lankan',
#  'Sri Lankan',
#  'Sri Lanka',
#  'Sri Lanka',
#  'Zamalek',
#  'Port Said',
#  'Middle East',
#  'Egyptian',
#  'US',
#  'Egyptian',
#  'Egyptian',
#  'Israeli',
#  'Middle East',
#  'Palestinian',
#  'Israeli',
#  'Palestinian',
#  'West Bank',
#  'Palestinian',
#  'Egyptian',
#  'American',
#  'Egyptian',
#  'Egyptian',
#  'US',
#  'Israeli',
#  'Egyptian',
#  'US',
#  'Americans',
#  'Egypt',
#  'Middle East',
#  'Palestinian',
#  'Palestinian',
#  'Syrians',
#  'Syrians',
#  'Palestinians',
#  'Palestinians',
#  'Sharm El-Sheikh',
#  'Americans',
#  'Israeli',
#  'Israeli',
#  'Israeli',
#  'Egyptian',
#  'Palestinian',
#  'Palestinians',
#  'Rolling Meadows',
#  'Rolling Meadows',
#  'Rolling Meadows',
#  'DuPage County',
#  'Lombard',
#  'Lombard',
#  'Lombard',
#  'Lombard',
#  'Roselle',
#  'Roselle',
#  'Illinois',
#  'Roselle',
#  'DuPage',
#  'Glen Ellyn',
#  'Macon County',
#  'Des Plaines',
#  'Kenyan',
#  'Kenyan',
#  'Tarrant County',
#  'Fort Worth',
#  'Tarrant County',
#  'Fort Worth',
#  'Texas',
#  'Grand Prairie',
#  'Mansfield',
#  'MANSFIELD',
#  'Mansfield',
#  'Fort Worth',
#  'Eastland County',
#  'Kermanshah',
#  'Texas',
#  'United States',
#  'Islamic Republic',
#  'Colleyville',
#  'Arlington',
#  'Arlington',
#  'Arlington',
#  'Arlington',
#  'Arlington',
#  'Arlington',
#  'Grand Prairie',
#  'Grand Prairie',
#  'Tarrant County',
#  'Grand Prairie',
#  'Fort Worth',
#  'Georgia',
#  'Clarke County',
#  'Oconee County',
#  'Georgia',
#  'Jackson',
#  'Barrow County',
#  'Clarke',
#  'Oconee',
#  'Georgia',
#  'Athens',
#  'Clarke County',
#  'Athens',
#  'Georgia',
#  'Barrow County',
#  'Jackson County',
#  'Clarke',
#  'Georgia',
#  'Barrow',
#  'MONROE',
#  'Georgia',
#  'Walton County',
#  'Walton County',
#  'Walton',
#  'Walton County',
#  'Henderson County',
#  'Texas',
#  'Athens',
#  'Henderson County',
#  'Henderson County',
#  'Athens',
#  'Athens',
#  'CORSICANA',
#  'Henderson County',
#  'Navarro County',
#  'Gun Barrel City',
#  'Kaufman County',
#  'Kaufman County',
#  'Kaufman County',
#  'Navarro County',
#  'Corsicana',
#  'Athens',
#  'Athens',
#  'Knox Park',
#  'McMinn County',
#  'McMinn County',
#  'McMinn County',
#  'Nashville',
#  'Alton',
#  'Evansville',
#  'Madison County',
#  'Edwardsville',
#  'Edwardsville',
#  'Glen Carbon',
#  'Glen Carbon',
#  'Glen Carbon',
#  'Fort Worth',
#  'Fort Worth',
#  'Fort Worth',
#  'Fort Worth',
#  'Rochester',
#  'COLUMBIA',
#  'South Carolina',
#  'South Carolina',
#  'South Carolina',
#  'New York',
#  'Augusta',
#  'New York',
#  'Augusta',
#  'Augusta',
#  'New York City',
#  'Columbia County',
#  'Richmond County',
#  'Martinez',
#  'Richmond County',
#  'Columbia County',
#  'Grovetown',
#  'Ala.',
#  'Grovetown',
#  'Newton County',
#  'Grovetown',
#  'Columbia County',
#  'Georgia',
#  'Atlanta',
#  'America',
#  'Salisbury',
#  'Sharon',
#  'Falls Village',
#  'HARWINTON',
#  'Harwinton',
#  'Harwinton',
#  'Harwinton',
#  'Burlington',
#  'HARTFORD',
#  'Connecticut',
#  'New Jersey',
#  'U.S.',
#  'Hartford',
#  'Africa',
#  'BANTAM',
#  'Bantam',
#  'New Milford',
#  'Danbury',
#  'New Milford',
#  'TORRINGTON',
#  'Torrington',
#  'Litchfield',
#  'Torrington',
#  'Naugatuck River',
#  'MIDDLETOWN',
#  'Middletown',
#  'Hartford',
#  'Clinton',
#  'CLINTON',
#  'New Haven',
#  'EAST HAMPTON',
#  'East Hampton',
#  'Oakdale',
#  'Cherry Hinton',
#  'Flumeri',
#  'Kentford',
#  'Chesterton',
#  'Cambridgeshire',
#  'East Cambridgeshire',
#  'Barton',
#  'Chesterton',
#  'Guernsey County',
#  'Guernsey County',
#  'Guernsey County',
#  'MOUNT GILEAD',
#  'Mount Gilead',
#  'Morrow County',
#  'Richland County',
#  'BYESVILLE',
#  'Byesville',
#  'Guernsey County',
#  'Pleasant City',
#  'Lore City',
#  'U.S.',
#  'Ohio',
#  'Franklin County',
#  'Warren County',
#  'Hamilton Township',
#  'Chesterland',
#  'New Concord',
#  'New Concord',
#  'New Concord',
#  'New Concord',
#  'SOUTH CHARLESTON',
#  'W.Va.',
#  'W.Va.',
#  'Charleston',
#  'Charleston',
#  'South Charleston',
#  'Charleston',
#  'W.Va.',
#  'SOUTH CHARLESTON',
#  'W.Va.',
#  'South Charleston',
#  'South Charleston',
#  'South Charleston',
#  'West Virginia',
#  'West Virginia',
#  'Virginia Beach',
#  'Cedar Grove',
#  'Cabell County',
#  'St. Albans',
#  'Kanawha City',
#  'South Charleston',
#  'Shawnee Park',
#  'South Charleston',
#  'South Charleston',
#  'South Charleston',
#  'South Charleston',
#  'Kanawha City',
#  'Bronx County',
#  'Kanawha County',
#  'Kanawha County',
#  'American',
#  'Grant County',
#  'South Charleston',
#  'French',
#  'South Charleston',
#  'West Virginia',
#  'South Charleston',
#  'United States',
#  'West Virginia',
#  'American',
#  'German',
#  'American',
#  'Mason County',
#  'American',
#  'Mason County',
#  'Mason County',
#  'American',
#  'Mason County',
#  'Kanawha River',
#  'W.Va.',
#  'Kanawha River',
#  'Charleston',
#  'West Virginia',
#  'W.Va.',
#  'W.Va.',
#  'Kanawha County',
#  'Nitro',
#  'West Virginia',
#  'Kanawha County',
#  'Las Vegas',
#  'W.Va.',
#  'W. Va.',
#  'Americans',
#  'West Virginia',
#  'Canaan Valley',
#  'Greenbrier',
#  'Pocahontas County',
#  'Anthony Creek',
#  'Williams',
#  'Cranberry',
#  'Mount Hood',
#  'Pictured Rocks National Lakeshore',
#  'Zion National Park',
#  'Rocky Mountain National Park',
#  'East Bank',
#  'Kanawha County',
#  'East Bank',
#  'East Bank',
#  'East Bank',
#  'East Bank',
#  'Kanawha County',
#  'East Bank',
#  'East Bank',
#  'Kanawha County',
#  'East Bank',
#  'East Bank',
#  'East Bank',
#  'W.Va.',
#  'W.Va.',
#  'West Virginia',
#  'Princeton',
#  'Mercer County',
#  'West Virginia',
#  'W. Va.',
#  'W.Va.',
#  'West Virginia',
#  'W.Va.',
#  'Kanawha County',
#  'Kanawha County',
#  'HURRICANE',
#  'W.Va.',
#  'Putnam County',
#  'Putnam County',
#  'Putnam County',
#  'Kanawha County',
#  'West Virginia',
#  'Hardy',
#  'Raleigh',
#  'Berkeley',
#  'Raleigh',
#  'McDowell',
#  'West Virginia',
#  'Charleston',
#  'Charleston',
#  'ATLANTIC BEACH',
#  'South Carolina',
#  'Atlantic Beach',
#  'Myrtle Beach',
#  'Horry County',
#  'North Myrtle Beach',
#  'Goose Creek',
#  'Goose Creek',
#  'ISLE OF PALMS',
#  'Hampton Park',
#  'Columbia',
#  'Columbia',
#  'Lexington County',
#  'Lexington County',
#  'Lexington County',
#  'Lexington',
#  'W. Columbia',
#  'West Columbia',
#  'Lexington County',
#  'Columbia',
#  'Columbia',
#  'Lexington County',
#  'Batesburg-Leesville',
#  'Batesburg-Leesville',
#  'South Carolina',
#  'South Carolina',
#  'Greer',
#  'Lake Robinson',
#  'Lake Cunningham',
#  'Greenville',
#  'Spartanburg',
#  'Greer',
#  'Greer Station',
#  'Greer Station',
#  'Greer Station',
#  'Greer Station',
#  'Greer',
#  'West Columbia',
#  'West Columbia',
#  'West Columbia',
#  'Columbia',
#  'West Columbia',
#  'South Carolina',
#  'West Columbia',
#  'West Columbia',
#  'Lexington County',
#  'Maury County',
#  'LAWRENCEBURG',
#  'Williamson County',
#  'Tennessee',
#  'Lawrenceburg',
#  'Shelbyville',
#  'Williamson County',
#  'Ohio',
#  'Ohio',
#  'Ashland',
#  'West Virginia',
#  'Wood County',
#  'W. Va.',
#  'W. Va.',
#  'Meigs County',
#  'Meigs County',
#  'Meigs County',
#  'Pleasant Township',
#  'Madison Township',
#  'Grove City',
#  'Pleasant',
#  'Ohioans',
#  'Franklin County',
#  'DeKalb County',
#  'DeKalb County',
#  'North Druid Hills',
#  'DeKalb County',
#  'North Druid Hills',
#  'DeKalb',
#  'North Druid Hills',
#  'Avondale Estates',
#  'Avondale Estates',
#  'DeKalb County',
#  'Avondale',
#  'Clayton County',
#  'Clayton County',
#  'Lovejoy',
#  'Lovejoy',
#  'Ohio',
#  'Georgia',
#  'Sycamore',
#  'DeKalb County',
#  'Hopkins Park',
#  'DeKalb County',
#  'DeKalb County',
#  'DeKALB',
#  'DeKalb',
#  'Illinois',
#  'Kish River',
#  'Kishwaukee River',
#  'Hopkins Park',
#  'DeKalb County',
#  'West Allis',
#  'Hopkins Park',
#  'Irish',
#  'Irish',
#  'Dublin',
#  'Dublin',
#  'Dublin',
#  'Dublin',
#  'Dublin',
#  'Jerome Township',
#  'Dublin',
#  'Dublin',
#  'Cuyahoga Falls',
#  'Dublin',
#  'Franklin County',
#  'Dublin',
#  'Dublin',
#  'Dublin',
#  'Dublin',
#  'Dublin',
#  'Dublin',
#  'Dublin',
#  'Dublin',
#  'Dublin',
#  'Dublin',
#  'Ohio',
#  'Chestatee River',
#  'Gainesville',
#  'Hall County',
#  'Georgia',
#  'Hall County',
#  'Forsyth County',
#  'Hall County',
#  'Gwinnett County',
#  'Gwinnett',
#  'Gwinnett County',
#  'Norman',
#  'D.C.',
#  'U.S.',
#  'Norman',
#  'Cooke County',
#  'Wichita Falls',
#  'Cooke County',
#  'Cooke County',
#  'Lindsay',
#  'Cooke County',
#  'American',
#  'Texas',
#  'Aleutian Islands',
#  'Chinese',
#  'Texan',
#  'Chinese',
#  'Lindsay',
#  'Lindsay',
#  'Cooke County',
#  'Lindsay',
#  'Cooke County',
#  'Cooke',
#  'Grayson',
#  'Love',
#  'Gainesville',
#  'Gainesville',
#  'Gainesville',
#  'Gainesville',
#  'Gainesville',
#  'Chiefland',
#  'Chiefland',
#  'Levy County',
#  'Florida',
#  'Chiefland',
#  'Cross City',
#  'Alachua County',
#  'Chiefland',
#  'Hardeetown',
#  'Chiefland',
#  'Levy County',
#  'Williston',
#  'St. Marys River',
#  'St. Marys',
#  'St. Marys River',
#  'St. Marys',
#  'St. Marys River',
#  'St. Marys River',
#  'Baker',
#  'Charlton County',
#  'Ocilla',
#  'Georgia',
#  'Fitzgerald',
#  'Georgia',
#  'United States',
#  'Pa.',
#  'Georgia',
#  'Hall County',
#  'Hall County',
#  'Hall County',
#  'Georgia',
#  'Lake Lanier',
#  'Lake Hartwell',
#  'Hartsfield',
#  'Georgia',
#  'Atlanta',
#  'America',
#  'Abkhaz',
#  'South Ossetia',
#  'Georgian',
#  'Georgia',
#  'Tbilisi',
#  'Georgia',
#  'Georgian',
#  'Dvani',
#  'Georgian',
#  'Dvani',
#  'United States',
#  'Abkhaz',
#  'Abkhaz',
#  'Georgian',
#  'Georgian',
#  'Abkhaz',
#  'Abkhaz',
#  'Abkhaz',
#  'South Ossetia',
#  'Georgian',
#  'South Ossetian',
#  'South Ossetia',
#  'South Ossetian',
#  'Georgian',
#  'Georgian',
#  'Russian',
#  'Georgian',
#  'Georgian',
#  'South Ossetians',
#  'South Ossetians',
#  'Georgian',
#  'Georgian',
#  'Georgian',
#  'South Ossetian',
#  'Georgian',
#  'South Ossetian',
#  'Georgian',
#  'Prisi',
#  'Georgian',
#  'Prisi',
#  'Tamarasheni',
#  'Georgian',
#  'Georgian',
#  'Georgian',
#  'South Ossetian',
#  'Caucasus',
#  'Georgian',
#  'Georgian',
#  'Russian',
#  'South Ossetia',
#  'Georgian',
#  'Russian Federation',
#  'Russian Federation',
#  'Georgian',
#  'Russian',
#  'Russian',
#  'Russian',
#  'South Ossetian',
#  'Georgian',
#  'South Ossetia',
#  'South Ossetian',
#  'Russian',
#  'North Ossetian',
#  'South Ossetian',
#  'Georgian',
#  'South Ossetia',
#  'Latvian',
#  'Latvian',
#  'Latvians',
#  'Svaneti',
#  'Ushba',
#  'Georgian',
#  'Hartford',
#  'Walker County',
#  'Huntsville',
#  'Walker County',
#  'Walker County',
#  'Huntsville',
#  'Walker County',
#  'Walker County',
#  'Calif',
#  'New York',
#  'N.D.',
#  'New York',
#  'Walker County',
#  'Walker County',
#  'Huntsville',
#  'Walker County',
#  'Walker County',
#  'Russian',
#  'California',
#  'N.D.',
#  'Huntsville',
#  'Walker County',
#  'Huntsville',
#  'Walker County',
#  'Huntsville',
#  'Walker County',
#  'Walker County',
#  'Jordan',
#  'Jordan',
#  'Jackson County',
#  'Watertown',
#  'Delano',
#  'Watertown',
#  'Scott County',
#  'St. Paul',
#  'Plainview',
#  'Elgin',
#  'Belle Plaine',
#  'Belle Plaine',
#  'Watertown',
#  'Mayer',
#  'Jordan',
#  'United States',
#  'Jordan',
#  'Johnson County',
#  'Johnson County',
#  'Johnson County',
#  'Leavenworth County',
#  'Douglas',
#  'Kansas City',
#  'Jackson County',
#  'Kansas City',
#  'Cass County',
#  'Cass County',
#  'Kansas City',
#  'Kansas City',
#  'Wyandotte County',
#  'Kansas City',
#  'Roanoke Park',
#  'Kansas City',
#  'Kansas City',
#  'Kansas City',
#  'Blue Springs',
#  'Jackson County',
#  'Blue Springs',
#  'North Kansas City',
#  'North Kansas City',
#  'Kansas City',
#  'North Kansas City',
#  'Kansas City',
#  'Kansas City',
#  'Platte City',
#  'Kansas',
#  'Riley',
#  'Boulder City',
#  'Boulder City',
#  'Henderson',
#  'Boulder City',
#  'Boulder City',
#  'U.S.',
#  'Boulder City',
#  'Boulder City',
#  'North Las Vegas',
#  'North Las Vegas',
#  'North Las Vegas',
#  'North Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'Clark County',
#  'Las Vegas',
#  'Las Vegas Valley',
#  'Las Vegas',
#  'Las Vegas',
#  'Las Vegas',
#  'San Diego',
#  'Las Vegas',
#  'Las Vegas',
#  'Hershey',
#  'North Annville Township',
#  'Elizabethtown',
#  'New York City',
#  'New Jersey',
#  'Jackson Township',
#  'Myerstown',
#  'Pine Grove',
#  'Boone County',
#  'Boone County',
#  'Whitestown',
#  'Whitestown',
#  'Whitestown',
#  'Whitestown',
#  'Boone County',
#  'Boone County',
#  'Boone County',
#  'Boone County',
#  'Boone County',
#  'Boone County',
#  'Indiana',
#  'Boone County',
#  'Boone County',
#  'Hamilton',
#  'Hendricks',
#  'Montgomery County',
#  'Clinton',
#  'Boone County',
#  'Boone County',
#  'Indiana',
#  'Iraqi',
#  'Lebanese',
#  'Iraqi',
#  'Iraqis',
#  'Iraqi',
#  'Lebanese',
#  'Lebanese',
#  'Israeli',
#  'Lebanese',
#  'Israeli',
#  'Lebanese',
#  'Iraqi',
#  'Iraqi',
#  'Lebanese',
#  'Palestinian',
#  'Palestinian',
#  'Palestinians',
#  'Palestinian',
#  'Readington',
#  'Readington Township',
#  'Readington Township',
#  'Clinton Township',
#  'Red Mill',
#  'Flemington',
#  'Flemington',
#  "ST. JOHN'S",
#  'North Atlantic',
#  'Newfoundland and Labrador',
#  'Erie',
#  'North America',
#  'London',
#  'Ontario',
#  'Quebec City',
#  'Groton',
#  'Town of Groton',
#  'Laurel County',
#  'Laurel County',
#  'Laurel County',
#  'Laurel County',
#  'Clay County',
#  'Laurel County',
#  'Laurel County',
#  'Laurel County',
#  'Laurel County',
#  'Laurel County',
#  'Cumberland Falls',
#  'Kentucky',
#  'Laurel County',
#  'Laurel County',
#  'Laurel County',
#  'Laurel County',
#  'Clark County',
#  'Clark County',
#  'Laurel County',
#  'Laurel County',
#  'Florida',
#  'Atlas Mountains',
#  'L.A.',
#  'Los Angeles',
#  'Los Angeles',
#  'South Los Angeles',
#  'Los Angeles',
#  'Los Angeles',
#  'New York',
#  'Los Angeles',
#  'Los Angeles',
#  'Los Angeles',
#  'San Fernando',
#  'Los Angeles',
#  'San Fernando',
#  'Port of Los Angeles',
#  'New Delhi',
#  'Port of Los Angeles',
#  'California',
#  'Santa Ana',
#  'Los Angeles',
#  'Harbor City',
#  'Laguna Hills',
#  'L.A.',
#  'Mount Washington',
#  'Los Feliz',
#  'Los Angeles',
#  'Echo Park',
#  'Mount Washington',
#  'Los Angeles',
#  'Mount Washington',
#  'Glendale',
#  'Griffith Park',
#  'Echo Park',
#  'Orange County',
#  'Long Beach',
#  'Orange County',
#  'Los Angeles',
#  'Calif.',
#  'California',
#  'Los Angeles',
#  'France',
#  'United States',
#  'France',
#  'South L.A.',
#  'South Los Angeles',
#  'Los Angeles',
#  'Los Angeles',
#  'Oakland',
#  'San Pedro',
#  'Pottawatomie County',
#  'San Diego',
#  'San Diego',
#  'Kansas',
#  'American',
#  'American',
#  'Manhattan',
#  'American',
#  'Kansas City',
#  'Riley County',
#  'Kansas',
#  'Riley County',
#  'Pott Co.',
#  'Pottawatomie County',
#  'Kane County',
#  'Jefferson County',
#  'St. George',
#  'KANSAS CITY',
#  'Hutchinson',
#  'Marion County',
#  'Riley County',
#  'Kansas',
#  'Kansas City',
#  'Anderson County',
#  'Pratt',
#  'Dodge City',
#  'Kansas',
#  'Garden City',
#  'Dodge City',
#  'Pratt County',
#  'Hutchinson',
#  'Harper',
#  'Kingman',
#  'Dodge City',
#  'Great Bend',
#  'Larned',
#  'Wichita',
#  'Coral Gables',
#  'Coral Gables',
#  'Miami-Dade',
#  'Miami-Dade',
#  'Miami Beach',
#  'Daytona Beach',
#  'Volusia County',
#  'Volusia County',
#  'Seminole County',
#  'Florida',
#  'Florida',
#  'Volusia County',
#  'Osceola County',
#  'Golden Glades',
#  'Florida',
#  'Panama City',
#  'U.S.',
#  'New York',
#  ...]

# %% [markdown]
# ## GeoWebNews

# %% [markdown]
# ### Loading the dataset

# %%
# Get file path GWN dataset
file_path = '../../../data/GeoWebNews/GeoWebNews.xml'

import loading_functions

data_all_toponyms = loading_functions.prepare_data(file_path, filtered=False, split=True)

data_filtered_toponyms = loading_functions.prepare_data(file_path, filtered=True, split=True)

# %% [markdown]
# ### Make Predictions

# %%
import spaCy_predictions

processed_results = spaCy_predictions.make_predictions(ner_pipeline, data_all_toponyms)
# Out:
# 348it [00:03, 103.70it/s]

# %%
processed_results_filtered = spaCy_predictions.make_predictions(ner_pipeline, data_filtered_toponyms)
# Out:
# 346it [00:03, 112.88it/s]

# %% [markdown]
# ### Evaluation GWN

# %%
import evaluate

# All toponyms
fps, fns = evaluate.evaluate(data_all_toponyms, processed_results)
# Out:
# fp: 418 | tp: 1193 | fn: 4086
# precision: 0.741 | recall: 0.226 | f-score: 0.346

# %%
fps
# Out:
# ['Finiels',
#  'the Mississippi River',
#  'Methodist',
#  'Frenchmen Street',
#  'Lake Manassas',
#  'Manassas',
#  'San Marcos',
#  'Ruby',
#  "Mississippi State's",
#  'Mississippi State',
#  "Victoria Vivians'",
#  'UConn',
#  "Mississippi State's",
#  'North Carolina',
#  "St. Peter's Basilica",
#  'Bollywood',
#  'Manisha Koirala',
#  'Fire Island',
#  'Fort Salonga',
#  'New Orleans',
#  'New York',
#  'South Korea',
#  'New York City',
#  'New Orleans',
#  "the Islamic Republic's",
#  'Godolphin',
#  'West Coast',
#  'Godolphin',
#  'North America',
#  'West Coast',
#  'West Coast',
#  'Treasure Beach',
#  'Animal Kingdom',
#  'Morris County',
#  'Morris County',
#  'New York',
#  'New York',
#  'NEW JERSEY',
#  'Washington',
#  'D.C.',
#  'the Middle East',
#  'West',
#  'the United States',
#  'the United Kingdom',
#  'the United States',
#  'Asia-Pacific',
#  'Tamil Nadu',
#  'States',
#  'Kamenné Square',
#  'the United States',
#  'the United States',
#  'Washington Township',
#  'New Jersey',
#  'South Africa',
#  'South Venezuela',
#  'The United States',
#  'the United States',
#  'the United States',
#  'LOS ANGELES',
#  'Easter',
#  'Dayasiri Jayasekara',
#  'IoTX',
#  'IoTX',
#  'IoTX',
#  'the Middle East',
#  'the Middle East',
#  'IoTX',
#  'the Middle East',
#  'the Middle East',
#  'IoTX',
#  'IoTX',
#  'CSA Singapore',
#  'Ocean Infinity',
#  'the Indian Ocean',
#  'Kuala Lumpur',
#  'Indian Ocean',
#  'the North West',
#  'the North West',
#  'the Pilanesburg Mountains',
#  'Jirai Amayah',
#  'New York',
#  'the United States',
#  'New York',
#  'the United States',
#  'Prin',
#  'Washington',
#  'D.C.',
#  'the United Kingdom',
#  'St. North',
#  'the United States',
#  'CALAMBA CITY',
#  'Sokoto State',
#  'Benue',
#  'Torkula village',
#  'Umemger village',
#  'Guma LGA',
#  'SOUTH WAZIRISTAN',
#  'South Waziristan Agency',
#  'Peshawar',
#  'West Wales',
#  'New Quay',
#  'New Quay',
#  'New Quay',
#  'Nuneaton',
#  'Suffolk County',
#  'Suffolk City',
#  'Beverly Hills',
#  'Beverly Hills',
#  'Los Angeles',
#  'Gilgit',
#  'Gilgit',
#  'Gilgit',
#  'Gilgit',
#  'Gilgit',
#  'Klamath Falls',
#  'NEW YORK',
#  'Crown Heights',
#  'NEW YORK',
#  'New York City',
#  'New York',
#  'Crown Heights',
#  'Crown Heights',
#  'MEXICO CITY',
#  'Birmingham City',
#  'Birmingham City',
#  'North Carolina',
#  "North Carolina's",
#  'Hamilton County',
#  'Oaxaca State',
#  'Oaxaca State',
#  'Mexico City',
#  'the Republic of Armenia',
#  'the Czech Republic',
#  'Vatican Gardens',
#  'the Republic of Armenia',
#  'the Republic of Armenia',
#  'the Greek islands',
#  'New York',
#  'New York',
#  "New York's",
#  'the Nile Delta',
#  'New Cairo',
#  'Yuba City',
#  'the Korean Peninsula',
#  'Korean Peninsula',
#  'Korean Peninsula',
#  'the United States',
#  'the Korean Peninsula',
#  'South Korea',
#  'South Korea',
#  'the Korean Peninsula',
#  "the United States'",
#  'US',
#  'the United States',
#  'El Financiero',
#  'the United States',
#  'Ciudad Juarez',
#  'the United States',
#  'Petro',
#  'El Financiero',
#  'St. Louis',
#  'New York City',
#  'Latin America',
#  'OKLAHOMA',
#  'West Virginia',
#  'West Virginia',
#  'Oklahoma City',
#  'Orange County',
#  'Orange County',
#  'Orange County',
#  'Gotham City',
#  "Orange County's",
#  'Orange County',
#  'Orange County',
#  'Orange County',
#  'Orange County',
#  'Orange County',
#  "Orange County's",
#  'Orange County',
#  'Connecting California',
#  "Tipperary County Council's",
#  'Building Ireland',
#  'Tokyo',
#  'St. Petersburg',
#  'St. Petersburg',
#  'South America',
#  'New Mexico',
#  'Kansas City',
#  'Montgomery County',
#  'North Fourth Street',
#  'Red Oak',
#  'Des Moines',
#  'Montgomery County',
#  'the United States',
#  'New Jersey',
#  'New Jersey',
#  'the United States',
#  'United States',
#  'the Pacific Ocean',
#  'El Niño',
#  'Colorado State',
#  'Colorado State',
#  'West Surrey',
#  'E.R.',
#  'New York City',
#  'Saint Lucian',
#  "St George's",
#  'Western Cape',
#  'Western Cape',
#  'Cape Town',
#  'the Eastern Cape',
#  'Cape Town',
#  'Eastern Cape',
#  'District',
#  'District of Massachusetts',
#  'MURRAY',
#  'Washington',
#  'D.C.',
#  'Slidell PD',
#  'the Tijuana River',
#  'Baja',
#  'California',
#  'Trinidad',
#  'Trinidad',
#  'Tobago',
#  'Kuala Lumpur',
#  'LOS ANGELES',
#  'Los Angeles',
#  'Los Angeles',
#  'West Palm Beach',
#  'New York',
#  'New Jersey',
#  'New Jersey',
#  'New York City',
#  'Local Ireland',
#  'West Wing',
#  'the West Wing',
#  'McLean County',
#  'Muhlenberg County',
#  'Ohio County',
#  'NGO',
#  'Russia',
#  'Great Britain',
#  'Great Britain',
#  'the Soviet Union',
#  'Germany',
#  'Bosnia and Herzegovina',
#  "North America's",
#  'Manchester City',
#  'City',
#  'Eastern Ghouta',
#  'Eastern Ghouta',
#  'ST',
#  'St. Louis',
#  'St. Louis Hills',
#  'Jeffords',
#  'Glenrock Lagoon',
#  'Glenrock Lagoon',
#  'Quebec City',
#  'Freeland',
#  'Lighthizer',
#  'the United States',
#  'Cambridge Analytica',
#  'Cambridge Analytica',
#  'Cambridge Analytica',
#  'Kuala Lumpur',
#  'The United States',
#  'Saudi Arabia',
#  "Saudi Arabia's",
#  'Saudi Arabia',
#  'the Middle East',
#  'Saudi Arabia',
#  'Saudi Arabia',
#  'the United States',
#  'the United States',
#  'the Middle East',
#  'the United States',
#  'Saudi Arabia',
#  'New York',
#  'West Coast',
#  'Saudi Arabia',
#  'Saudi Arabia',
#  'the United States',
#  'the United States',
#  'the United States of America',
#  'Cambridge Analytica',
#  'West Virginia',
#  'Los Angeles',
#  'Kasba Bonli',
#  'New Delhi',
#  'HORRY COUNTY',
#  'Garden City',
#  'Garden City',
#  'Lindenwald',
#  'Lindenwald',
#  'LOS ANGELES',
#  'Beverly Hills',
#  'the Beverly Hills Police Department',
#  'the United States',
#  'the United States',
#  'the United States',
#  'Turtle Rock',
#  'Turtle Rock',
#  'Cuyahoga County',
#  'Coincheck',
#  'Mount Chaambi',
#  'Alliance',
#  'the United States',
#  'North Africa',
#  'North Africa',
#  'North Africa',
#  'North Africa',
#  'Thames Valley',
#  "New Mexico's",
#  'New Mexico',
#  'SAN DIEGO',
#  'West Virginia',
#  'Kemira',
#  'Northern Europe',
#  'Great Britain',
#  'Great Britain',
#  'Cape Peron',
#  'the Safety Bay',
#  'South Side',
#  'River North',
#  'South Ingleside Avenue',
#  'Park Ridge',
#  'North State Street',
#  'the Near North Side',
#  'United States',
#  'Los Angeles',
#  'Boa Vista',
#  'Saint Croix County',
#  'the United States',
#  'The United States',
#  'San Antonio',
#  'Miami-Dade County',
#  'Nuiry',
#  'Miami-Dade',
#  'South Florida',
#  'Miami-Dade',
#  'Nuiry',
#  'Nuiry',
#  'BA',
#  'Zimndaba',
#  'Air Zimbabwe',
#  'New Brunswick RCMP',
#  'South Korea',
#  'Park',
#  'South Korea',
#  'Park',
#  'South Korea',
#  'Park',
#  'Park',
#  'Park',
#  "South Korea's",
#  'Park',
#  'Park',
#  'Park',
#  'PV',
#  'Latin America',
#  "South Korea's",
#  'South Korea',
#  'South Korea',
#  "South Korea's",
#  'Donington Park',
#  'Oulton Park',
#  'U.S.',
#  'R-Neb.',
#  'Miami Beach',
#  'Miami Beach',
#  'Francisco',
#  'South Africa',
#  "South Africa's",
#  'Zuma',
#  "South Africa's",
#  'Asia',
#  'Parañaque City',
#  'NEW YORK',
#  'Great Yarmouth',
#  'Las Vegas',
#  'Tchaikovsky',
#  "St Patrick's",
#  'Norwich City',
#  'East Yorkshire',
#  'CBD',
#  'Los Angeles',
#  'South Africa',
#  'New York',
#  'Northern Ireland',
#  'the Republic and',
#  'United States',
#  'Collier County']

# %%
fns
# Out:
# ['area',
#  'plantation',
#  'mansion',
#  'substation',
#  'Louisiana',
#  'Louisiana Purchase',
#  'parcel',
#  'French',
#  'plat',
#  'French Quarter',
#  'Mississippi River',
#  "Rue d'Enghein",
#  'street',
#  'Almonaster',
#  'Franklin',
#  'avenue',
#  'Marigny Plantation',
#  'faubourg',
#  'Press Street',
#  'area',
#  "Faubourg D'Aunoy",
#  'neighbor',
#  'building',
#  'Chartres',
#  'Franklin',
#  'Methodist church',
#  'restaurant',
#  'street',
#  'complex',
#  'Royal Street',
#  'Royal Street',
#  'Rue Casa Calvo',
#  'Faubourg Marigny',
#  '2231 Royal',
#  '2231 Royal',
#  'townhouse',
#  'basement',
#  'Greek',
#  'structures',
#  'Elysian Fields',
#  'Royal Street',
#  'Bourbon',
#  'Marigny Canal',
#  'grid',
#  'avenue',
#  'park',
#  'Washington Square',
#  'Champs-Élysées',
#  'Elysian Fields',
#  'Pontchartrain Railroad',
#  'Pontchartrain Railroad',
#  'Appalachians',
#  'line',
#  'Royal Street',
#  'Washington Square',
#  'block',
#  'Holy Redeemer Church',
#  'edifice',
#  'Third Presbyterian Church',
#  'Frenchmen Street',
#  'Kurdish',
#  'city',
#  'Turkish',
#  'Syrian',
#  'Kurdish',
#  'Qamishli',
#  'towns',
#  'Syrian',
#  'Turkish',
#  'campaign',
#  'Syrian',
#  'Kurdish',
#  'Afrin',
#  'frontier',
#  'forces',
#  'Turkish',
#  'Afrin',
#  'community',
#  'style',
#  'design',
#  'residences',
#  'garage',
#  'clubroom',
#  'terrace',
#  'yard',
#  'Jamison',
#  'Lake Manassas',
#  'reservoir',
#  'homes',
#  'lake',
#  'Residents',
#  'clubhouse',
#  'courts',
#  'fields',
#  'playground',
#  'trails',
#  'Robert Trent Jones Golf Club',
#  'Robert Trent Jones Golf Club',
#  'Stonewall Golf Club',
#  'Stonewall Golf Club',
#  'Stonewall',
#  'Stonewall',
#  'Virginia Gateway',
#  'Virginia Gateway',
#  'Haymarket Village Center',
#  'Haymarket Village Center',
#  'Buckland Elementary',
#  'Buckland Elementary',
#  'Ronald Wilson Reagan Middle',
#  'Ronald Wilson Reagan Middle',
#  'Patriot High',
#  'Patriot High',
#  'Turtle Point',
#  'Turtle Point',
#  'Wegmans',
#  'Old Town Manassas',
#  'Vienna/Fairfax-GMU Metro',
#  'Dulles International Airport',
#  'The Washington Post',
#  'Washington',
#  'vacation',
#  'angels',
#  'viewers',
#  'vacation',
#  'The Washington Post',
#  'Washington',
#  'criticism',
#  'controversy',
#  'shooting',
#  'Marjory Stoneman Douglas High School',
#  'Marjory Stoneman Douglas High School',
#  'rallies',
#  'senior',
#  'Florida Atlantic University',
#  'Florida Atlantic University',
#  'California Polytechnic State University',
#  'California Polytechnic State University',
#  'California State University',
#  'California State University',
#  'San Marcos',
#  'companies',
#  'brand',
#  'advertisers',
#  'show',
#  'Parkland',
#  'controversies',
#  'The Washington Post',
#  'Washington',
#  'Parkland',
#  'supporters',
#  'president',
#  'Parkland',
#  'government',
#  'shooting',
#  'people',
#  'Transforming the African Public Service',
#  'African',
#  'service',
#  'base',
#  'foundations',
#  'African',
#  'author',
#  'African',
#  'Nigerian',
#  'African',
#  'continent',
#  'culture',
#  'African',
#  'workforce',
#  'gulf',
#  'chasm',
#  'parties',
#  'audience',
#  'service',
#  'Transforming the African Public Service',
#  'African',
#  'Africans',
#  'Russian',
#  'Russian',
#  'police',
#  'woman',
#  'Russian Higher School of Economics',
#  'Russian Higher School of Economics',
#  'tournament',
#  'overtime',
#  'Mississippi',
#  'Mississippi State',
#  'corner',
#  'Irish',
#  'years',
#  'Mississippi',
#  'Mississippi State',
#  'room',
#  'American',
#  'HOUSE',
#  'life',
#  'Mississippi',
#  'Mississippi State',
#  'North Carolina',
#  'game',
#  'Mississippi',
#  'Mississippi State',
#  'Mississippi',
#  'Mississippi State',
#  'Louisville',
#  'service',
#  "St. Peter's Basilica",
#  'faith',
#  'Nigerian',
#  'aisle',
#  'basilica',
#  'scene',
#  'faith',
#  'Nigerian',
#  'Muscat',
#  'The 10th Muscat International Film Festival',
#  'Muscat',
#  'New York Times',
#  'New York',
#  'Long Islanders',
#  'Below Deck Mediterranean',
#  'Mediterranean',
#  'ferry',
#  'Fire Island',
#  'boat',
#  'season',
#  'pageants',
#  'school',
#  'psychology',
#  'career',
#  'Fort Salonga',
#  'Manila Cathedral',
#  'tomb',
#  'Air France KLM',
#  'France',
#  'EU Aviation Strategy',
#  'EU',
#  'sector',
#  'EU',
#  'EU Aviation Strategy',
#  'EU',
#  'aviation',
#  'airlines',
#  'Commission',
#  'European',
#  'European',
#  'airspace',
#  'Single European Sky',
#  'European',
#  'Air France KLM',
#  'France',
#  'aviation',
#  'European Aviation Strategy',
#  'European',
#  'market',
#  'jobs',
#  'EU',
#  'EU',
#  'chain',
#  'EU',
#  'EU',
#  'airports',
#  'EU',
#  'regulation',
#  'EU',
#  'policies',
#  'EU',
#  'states',
#  'passengers',
#  'August',
#  'August',
#  'New Orleans',
#  'Le Bernardin',
#  'Le Bernardin',
#  'New York',
#  'South Korea',
#  'Korean',
#  'script',
#  'rooftop',
#  'apartment',
#  'Broadway',
#  'chefs',
#  'friend',
#  'life',
#  'New York City',
#  'city',
#  'chefs',
#  'world',
#  'character',
#  'New Orleans',
#  'places',
#  'kitchen',
#  'Culinary Institute of America',
#  'America',
#  'mom',
#  'school',
#  'table',
#  'world',
#  'food',
#  'shah',
#  'SAN ANTONIO',
#  'world',
#  'country',
#  'programs',
#  'report',
#  'players',
#  'college',
#  'politicians',
#  'Iran',
#  'Islamic Republic',
#  'countries',
#  'countries',
#  'regions',
#  'region',
#  'city',
#  'Meydan Racecourse',
#  'Dubai World Cup',
#  'Dubai World Cup',
#  'family',
#  'Dubai World Cup',
#  'Dubai World Cup',
#  'colt',
#  'Helmet',
#  'Emirati',
#  'favourite',
#  'West Coast',
#  'American',
#  'career',
#  'Dubai World Cup',
#  'Dubai World Cup',
#  'trainer',
#  'Dubai Turf',
#  'Dubai Turf',
#  'Belgian',
#  'Dubai World Cup',
#  'Dubai World Cup',
#  'gates',
#  'UAE',
#  'Americans',
#  'West Coast',
#  'start',
#  'American',
#  'World Cup',
#  'World Cup',
#  'jockey',
#  'position',
#  'Emirati',
#  'daughter',
#  'track',
#  'West Coast',
#  'corner',
#  'straight',
#  'Syrian',
#  'towns',
#  'villages',
#  'Ghouta',
#  'operations',
#  'bastion',
#  'Syrian',
#  'campaign',
#  'Syrian',
#  'parts',
#  'country',
#  'Iraqi',
#  'east',
#  'command',
#  'outskirts',
#  'city',
#  'group',
#  'patch',
#  'Ghouta',
#  'insurgents',
#  'Douma',
#  'stronghold',
#  'capital',
#  'town',
#  'protests',
#  'analysts',
#  'campaign',
#  'capital',
#  'Ghouta',
#  'enemies',
#  'terrorists',
#  'headquarter',
#  'fortifications',
#  'forces',
#  'town',
#  'rebels',
#  'Russian',
#  'city',
#  'Russian',
#  'Ghouta',
#  'civilians',
#  'authorities',
#  'region',
#  'Ghouta',
#  'Idlib',
#  'Lukeoil',
#  'Lukeoil',
#  'winner',
#  'Morris County',
#  'person',
#  'Morris County',
#  'highway',
#  'customers',
#  'cashiers',
#  'game',
#  'winner',
#  'Riverdale Luke Oil',
#  'Riverdale Luke Oil',
#  'jackpot',
#  'employees',
#  'charity',
#  'store',
#  'man',
#  'New York',
#  'New York',
#  'NEW JERSEY',
#  'Riverdale Lukoil South',
#  'Riverdale Lukoil South',
#  'New Jersey',
#  'New Jersey Lottery',
#  'states',
#  'Washington, D.C.',
#  'U.S. Virgin Islands',
#  'soldier',
#  'serviceman',
#  'US Special Forces',
#  'US',
#  'Turkish',
#  'blast',
#  'American',
#  'British',
#  'spokesman',
#  'action',
#  'Middle East',
#  'country',
#  'duty',
#  'Sheikh Akil graveyard',
#  'Sheikh Akil graveyard',
#  'country',
#  'operations',
#  'Middle East',
#  'Peel',
#  'Peel Regional Police',
#  'suspects',
#  'CTV Saskatoon',
#  'Saskatoon',
#  'man',
#  'Police',
#  'directions',
#  'Northumberland Avenue',
#  'Russian',
#  'daughter',
#  'Russian',
#  'United States',
#  'Russian Embassy',
#  'Russian Embassy',
#  'Russian',
#  'diplomats',
#  'families',
#  'compound',
#  'agents',
#  'embassy',
#  'United Nations',
#  'United Nations',
#  'country',
#  'Russian',
#  'Russian',
#  'dispute',
#  'Russian',
#  'British',
#  'Russian',
#  'allies',
#  'French',
#  'probe',
#  'Soviet Union',
#  'Russians',
#  'United Kingdom',
#  'luggage',
#  'website',
#  'Russian',
#  'British',
#  'British',
#  'Russian',
#  'Russian',
#  'English',
#  'country',
#  'embassy',
#  'British',
#  'plane',
#  'Heathrow',
#  'Russian',
#  'British',
#  'daughter',
#  'Russian',
#  'Russian',
#  'Russian',
#  'British',
#  'Russian',
#  'United States',
#  'Russian',
#  'father',
#  'Asian',
#  'Pacific',
#  'region',
#  'world',
#  'Vietnam',
#  'reception',
#  'Russian',
#  'Party',
#  'country',
#  'country',
#  'Asia',
#  'Pacific',
#  'world',
#  'ministries',
#  'countries',
#  'partnership',
#  'Russian',
#  'friendship',
#  'Russian',
#  'Vietnamese',
#  'Tamil Nadu',
#  'government',
#  'judgment',
#  'Cauvery',
#  'State',
#  'Centre',
#  'court',
#  'Cauvery',
#  'Cauvery Management Board',
#  'Cauvery',
#  'Cauvery Water Regulation Committee',
#  'Tamil Nadu',
#  'tribunal',
#  'Centre',
#  'tribunal',
#  'Centre',
#  'Tamil Nadu',
#  'Tamil Nadu',
#  'Karnataka',
#  'committee',
#  'Tamil Nadu',
#  'Centre',
#  'Government',
#  'Cauvery',
#  'Cauvery Management Board',
#  'Cauvery',
#  'Cauvery Water Regulation Committee',
#  'Tamil Nadu',
#  'Government',
#  'victims',
#  'world',
#  'sweep',
#  'critics',
#  'authorities',
#  'authorities',
#  'jail',
#  'authorities',
#  'No. 2 Detention Centre',
#  'city',
#  'officials',
#  'snowstorm',
#  'court',
#  'judge',
#  'police',
#  'office',
#  "Supreme People's Court",
#  "Supreme People's Court",
#  'cheeks',
#  'officers',
#  'apartment',
#  'home',
#  'Chinese',
#  'prison',
#  'person',
#  'Tianjin',
#  'charity',
#  'Chinese Human Rights Defenders',
#  'Chinese',
#  'members',
#  'family',
#  'British',
#  'stores',
#  'Nitra',
#  'Prešov',
#  'estate',
#  'English',
#  'Kamenné Square',
#  'Kamenné Square',
#  'countries',
#  'United States',
#  'ministry',
#  'United States',
#  'US',
#  'US Trade Representative',
#  'office',
#  'place',
#  'insurers',
#  'Canadian',
#  'show',
#  "The Allendale Woman's Club",
#  'Allendale',
#  'Maywood',
#  "Eva's Village",
#  "Eva's Village",
#  'mothers',
#  "The Allendale Woman's Club",
#  'Allendale',
#  "Eva's Village",
#  "Eva's Village",
#  'Seasons restaurant',
#  'Seasons restaurant',
#  'Washington Township',
#  'community',
#  'club',
#  '100 Years of Allendale Women Helping Others Award',
#  'Allendale',
#  'families',
#  "The Allendale Woman's Club",
#  'Allendale',
#  'New Jersey',
#  'Russian',
#  'Venezuelan',
#  'Russian',
#  'Russian',
#  'negotiations',
#  'South Africa',
#  'South Venezuela',
#  'United States',
#  'fight',
#  'world',
#  'United States',
#  'countries',
#  'country',
#  'United States',
#  'countries',
#  'areas',
#  'United States',
#  'countries',
#  'LOS ANGELES',
#  'star',
#  'House',
#  'time',
#  'Minister',
#  'scam',
#  'motion',
#  'legislators',
#  'government',
#  'Gulf',
#  'Gulf Information Security Conference',
#  'makers',
#  'globe',
#  'Gulf Information Security Conference',
#  'Gulf',
#  'region',
#  'trends',
#  'Dubai World Trade Centre',
#  'exhibitors',
#  'countries',
#  'demand',
#  'professionals',
#  'experts',
#  'agendas',
#  'Smart Dubai Office',
#  'Smart Dubai Office',
#  'world',
#  'sectors',
#  'Middle East',
#  'cybercriminals',
#  'countries',
#  'Middle East',
#  'attacks',
#  'region',
#  'song',
#  'Middle East',
#  'agenda',
#  'cybersecurity',
#  'region',
#  'public',
#  'region',
#  'era',
#  'Middle East',
#  'show',
#  'sector',
#  'industries',
#  'globe',
#  'sphere',
#  'world',
#  'region',
#  'planet',
#  'region',
#  'city',
#  'Dubai Electronic Security Center',
#  'Dubai Electronic Security Center',
#  'Dubai Police',
#  'Smart Dubai',
#  'Dubai',
#  'CSA Singapore',
#  'Singapore',
#  'Malaysia Airlines',
#  'Malaysia',
#  'mysteries',
#  'ship',
#  'area',
#  'Indian Ocean',
#  'area',
#  'jet',
#  'Kuala Lumpur',
#  'zone',
#  'Australian',
#  'history',
#  'Malaysian',
#  'zone',
#  'area',
#  'Indian Ocean',
#  'Indian Ocean',
#  'land',
#  'chiefs',
#  'SA',
#  'areas',
#  'mining',
#  'communities',
#  'North West',
#  'government',
#  'chiefs',
#  'governance',
#  'authorities',
#  'areas',
#  'government',
#  'chiefs',
#  'land',
#  'law',
#  'resources',
#  'Chiefs',
#  'trend',
#  'chiefs',
#  'communities',
#  'belt',
#  'Chiefs',
#  'Bafokeng',
#  'Bafokeng',
#  'communities',
#  'land',
#  'North West',
#  'chiefs',
#  'villages',
#  'chiefs',
#  'SA',
#  'community',
#  'villages',
#  'foothills',
#  'Pilanesburg Mountains',
#  'New York',
#  'United States',
#  'New York',
#  'artists',
#  'United States',
#  'owner',
#  'buildings',
#  'site',
#  'buildings',
#  'organizers',
#  'board',
#  'damage',
#  'cities',
#  'cities',
#  'works',
#  'millennials',
#  'cities',
#  'Washington, D.C.',
#  'D.C.',
#  'D.C. Commission on the Arts and Humanities',
#  'artists',
#  'wall',
#  'development',
#  'murals',
#  'panels',
#  'buildings',
#  'owners',
#  'site',
#  'Cork',
#  'Cork',
#  'Minister',
#  'conference',
#  'Cork',
#  'language',
#  'European',
#  'systems',
#  'European',
#  'user',
#  'Europeans',
#  'European',
#  'EU',
#  'ambition',
#  'citizens',
#  'others',
#  'learners',
#  'Europeans',
#  'European',
#  'English',
#  'EU',
#  'mantra',
#  'Europeans',
#  'people',
#  'English',
#  'English',
#  'EU',
#  'United Kingdom',
#  'English',
#  'EU',
#  'EU',
#  'French',
#  'EU',
#  'EU',
#  'European',
#  'English',
#  'English',
#  'speakers',
#  'market',
#  'Organizers',
#  'website',
#  'Sloss Furnaces',
#  'Sloss Furnaces',
#  'St. North',
#  'Business',
#  'move',
#  'appeal',
#  'sociologists',
#  'world',
#  'government',
#  'country',
#  'Chinese',
#  'denominations',
#  'European',
#  'services',
#  'city-centre',
#  'city-centre',
#  'airports',
#  'London',
#  'trip',
#  'destination',
#  'Dutch',
#  'Dutch Rail',
#  'plane',
#  'airports',
#  'place',
#  'passengers',
#  'Lelystad',
#  'future',
#  'train',
#  'Airlines',
#  'flights',
#  'European',
#  'European Rail Traffic Management System',
#  'continent',
#  'countries',
#  'territory',
#  'Almelo',
#  'Rail',
#  'British',
#  'boy',
#  'hospital',
#  'wishes',
#  'Doctors',
#  "Alder Hey Children's Hospital",
#  'coma',
#  'parents',
#  'Vatican',
#  'Bambino Gesu Paediatric Hospital',
#  'parents',
#  'British',
#  'courts',
#  'United States',
#  'parents',
#  'son',
#  'death',
#  'doctors',
#  'courts',
#  'Russian',
#  'bench',
#  'English',
#  'attack',
#  'British',
#  'episode',
#  'staff',
#  'condition',
#  'hospital',
#  'unit',
#  'Russian',
#  'CALAMBA CITY',
#  'program',
#  'Philippine',
#  'Philippine Sports Commission',
#  'Philippine',
#  'Philippine Sports Institute',
#  'government',
#  'officials',
#  'barangays',
#  'colleges',
#  'partnerships',
#  'support',
#  'program',
#  'hall',
#  'University of Perpetual Help Dalta System Calamba',
#  'University of Perpetual Help Dalta System Calamba',
#  'Barangay Paciano Rizal',
#  'city',
#  'city',
#  'stakeholders',
#  'council',
#  'city',
#  'employees',
#  'A120',
#  'lorry',
#  'police',
#  'road',
#  'man',
#  'crash',
#  'Colchester Hospital',
#  'road',
#  'congestion',
#  'Coggeshall',
#  'Marks Tey',
#  'East of England',
#  'East of England Ambulance Service',
#  'collision',
#  'cyclist',
#  'A120',
#  'Coggeshall',
#  'crew',
#  'Owerri',
#  'Federal University of Technology',
#  'Federal University of Technology',
#  'Owerri',
#  'fence',
#  'community',
#  'Obinze',
#  'fencing',
#  'youths',
#  'school',
#  'school',
#  'Sokoto State',
#  'measles',
#  'camp',
#  'Benue state',
#  'Benue State',
#  'newsmen',
#  'outbreak',
#  'hospitals',
#  'ministry',
#  'day',
#  'home',
#  'Torkula',
#  'Guma Local Government Area',
#  'state',
#  'treatment',
#  'camp',
#  'team',
#  'siblings',
#  'Umemger',
#  'Guma LGA',
#  'SOUTH WAZIRISTAN',
#  'projects',
#  'South Waziristan Agency',
#  'elders',
#  'phase',
#  'peace',
#  'FATA',
#  'tribes',
#  'brethren',
#  'elders',
#  'Pakistan',
#  'Pakistan Army',
#  'Pakistan Army',
#  'Pakistan',
#  'peace',
#  'Makeen',
#  'army',
#  'path',
#  'West Wales',
#  'New Quay',
#  'Police',
#  'woman',
#  'bodies',
#  'helicopter',
#  'St Athan',
#  'New Quay',
#  'Gwbert',
#  'New Quay RNLI',
#  'New Quay RNLI',
#  'path',
#  'New Quay',
#  'place',
#  'angel',
#  'area',
#  'Irish',
#  'actor',
#  'tanks',
#  ...]

# %%
# Filtered toponyms
fps, fns = evaluate.evaluate(data_filtered_toponyms, processed_results_filtered)
# Out:
# fp: 423 | tp: 1179 | fn: 1287
# precision: 0.736 | recall: 0.478 | f-score: 0.580

# %%
fps
# Out:
# ['Finiels',
#  'the Mississippi River',
#  'Methodist',
#  'Frenchmen Street',
#  'Norbury',
#  'Granville',
#  'Somerville',
#  'Manassas',
#  'San Marcos',
#  'Ruby',
#  "Mississippi State's",
#  'Mississippi State',
#  "Victoria Vivians'",
#  'UConn',
#  "Mississippi State's",
#  "St. Peter's Basilica",
#  'Bollywood',
#  'Manisha Koirala',
#  'Fire Island',
#  'Fort Salonga',
#  'New Orleans',
#  'New York',
#  'South Korea',
#  'New York City',
#  "the Islamic Republic's",
#  'Godolphin',
#  'West Coast',
#  'Godolphin',
#  'North America',
#  'West Coast',
#  'West Coast',
#  'Treasure Beach',
#  'Animal Kingdom',
#  'Morris County',
#  'Morris County',
#  'New York',
#  'New York',
#  'NEW JERSEY',
#  'Washington',
#  'D.C.',
#  'the Middle East',
#  'the United States',
#  'West',
#  'the Soviet Union',
#  'the United States',
#  'Asia-Pacific',
#  'Tamil Nadu',
#  'States',
#  'Kamenné Square',
#  'the United States',
#  'the United States',
#  'Washington Township',
#  'New Jersey',
#  'South Africa',
#  'The United States',
#  'the United States',
#  'the United States',
#  'Dayasiri Jayasekara',
#  'IoTX',
#  'IoTX',
#  'IoTX',
#  'the Middle East',
#  'IoTX',
#  'the Middle East',
#  'the Middle East',
#  'IoTX',
#  'Ocean Infinity',
#  'the Indian Ocean',
#  'Kuala Lumpur',
#  'Indian Ocean',
#  'the North West',
#  'the North West',
#  'Jirai Amayah',
#  'New York',
#  'the United States',
#  'New York',
#  'Prin',
#  'Washington',
#  'D.C.',
#  'the United Kingdom',
#  'the United States',
#  'CALAMBA CITY',
#  'Umuanunu',
#  'Sokoto State',
#  'Benue',
#  'Torkula village',
#  'Umemger village',
#  'SOUTH WAZIRISTAN',
#  'South Waziristan Agency',
#  'Peshawar',
#  'West Wales',
#  'New Quay',
#  'New Quay',
#  'Suffolk County',
#  'Beverly Hills',
#  'Beverly Hills',
#  'Gilgit',
#  'Gilgit',
#  'Gilgit',
#  'Gilgit',
#  'Gilgit',
#  'Klamath Falls',
#  'NEW YORK',
#  'Crown Heights',
#  'NEW YORK',
#  'New York City',
#  'New York',
#  'Crown Heights',
#  'Crown Heights',
#  'MEXICO CITY',
#  'Montana',
#  'Birmingham City',
#  'Birmingham City',
#  'North Carolina',
#  'Hamilton County',
#  'Oaxaca State',
#  'Oaxaca State',
#  'Mexico City',
#  'the Republic of Armenia',
#  'the Czech Republic',
#  'Vatican Gardens',
#  'the Republic of Armenia',
#  'the Republic of Armenia',
#  'the Greek islands',
#  'New York',
#  'New York',
#  "New York's",
#  'the Nile Delta',
#  'New Cairo',
#  'Yuba City',
#  'the Korean Peninsula',
#  'Korean Peninsula',
#  'Korean Peninsula',
#  'the United States',
#  'the Korean Peninsula',
#  'South Korea',
#  'South Korea',
#  "the United States'",
#  'US',
#  'the United States',
#  'El Financiero',
#  'the United States',
#  'Ciudad Juarez',
#  'the United States',
#  'Petro',
#  'El Financiero',
#  'St. Louis',
#  'New York City',
#  'OKLAHOMA',
#  'West Virginia',
#  'West Virginia',
#  'Oklahoma City',
#  'Orange County',
#  'Orange County',
#  'Orange County',
#  'Gotham City',
#  "Orange County's",
#  'Orange County',
#  'Orange County',
#  'Orange County',
#  'Orange County',
#  "Orange County's",
#  'Orange County',
#  'Connecting California',
#  "Tipperary County Council's",
#  'Building Ireland',
#  'Tokyo',
#  'St. Petersburg',
#  'St. Petersburg',
#  'South America',
#  'New Mexico',
#  'Kansas City',
#  'Montgomery County',
#  'North Fourth Street',
#  'Red Oak',
#  'Des Moines',
#  'the United States',
#  'New Jersey',
#  'New Jersey',
#  'the United States',
#  'United States',
#  'the Pacific Ocean',
#  'El Niño',
#  'Colorado State',
#  'West Surrey',
#  'E.R.',
#  'New York City',
#  'Saint Lucian',
#  'Iceland',
#  'Iceland',
#  'Iceland',
#  'Iceland',
#  "St George's",
#  'Western Cape',
#  'Western Cape',
#  'Cape Town',
#  'the Eastern Cape',
#  'Cape Town',
#  'District of Massachusetts',
#  'MURRAY',
#  'Washington',
#  'Slidell PD',
#  'the Tijuana River',
#  'Baja',
#  'California',
#  'Trinidad',
#  'Trinidad',
#  'Tobago',
#  'Kuala Lumpur',
#  'LOS ANGELES',
#  'Los Angeles',
#  'West Palm Beach',
#  'New York',
#  'New Jersey',
#  'New Jersey',
#  'Local Ireland',
#  'the West Wing',
#  'McLean County',
#  'Muhlenberg County',
#  'Ohio County',
#  'NGO',
#  'Great Britain',
#  'Great Britain',
#  'the Soviet Union',
#  'Germany',
#  'Bosnia and Herzegovina',
#  'Manchester City',
#  'City',
#  'Eastern Ghouta',
#  'Eastern Ghouta',
#  'ST',
#  'St. Louis',
#  'St. Louis Hills',
#  'Jeffords',
#  'Glenrock Lagoon',
#  'Glenrock Lagoon',
#  'Quebec City',
#  'Freeland',
#  'Lighthizer',
#  'the United States',
#  'Cambridge Analytica',
#  'Cambridge Analytica',
#  'Cambridge Analytica',
#  'Kuala Lumpur',
#  'The United States',
#  'Saudi Arabia',
#  "Saudi Arabia's",
#  'Saudi Arabia',
#  'the Middle East',
#  'Saudi Arabia',
#  'Saudi Arabia',
#  'the United States',
#  'the United States',
#  'the Middle East',
#  'the United States',
#  'Saudi Arabia',
#  'New York',
#  'West Coast',
#  'Saudi Arabia',
#  'Saudi Arabia',
#  'the United States',
#  'the United States of America',
#  'West Virginia',
#  'Los Angeles',
#  'Kasba Bonli',
#  'New Delhi',
#  'HORRY COUNTY',
#  'Garden City',
#  'LOS ANGELES',
#  'Beverly Hills',
#  'the Beverly Hills Police Department',
#  'the United States',
#  'the United States',
#  'Turtle Rock',
#  'Coincheck',
#  'Mount Chaambi',
#  'Alliance',
#  'the United States',
#  'North Africa',
#  'North Africa',
#  'North Africa',
#  'North Africa',
#  'Thames Valley',
#  "New Mexico's",
#  'New Mexico',
#  'SAN DIEGO',
#  'West Virginia',
#  'Kemira',
#  'Northern Europe',
#  'Great Britain',
#  'Great Britain',
#  'Cape Peron',
#  'the Safety Bay',
#  'South Side',
#  'River North',
#  'South Ingleside Avenue',
#  'Park Ridge',
#  'North State Street',
#  'the Near North Side',
#  'United States',
#  'Holland',
#  'Saint Croix County',
#  'Holland',
#  'the United States',
#  'The United States',
#  'San Antonio',
#  'Miami-Dade County',
#  'Nuiry',
#  'Miami-Dade',
#  'South Florida',
#  'Miami-Dade',
#  'BA',
#  'Zimndaba',
#  'Air Zimbabwe',
#  'New Brunswick RCMP',
#  'South Korea',
#  'Park',
#  'South Korea',
#  'Park',
#  'South Korea',
#  'Park',
#  'Park',
#  'Park',
#  'PV',
#  'Latin America',
#  "South Korea's",
#  'South Korea',
#  'South Korea',
#  "South Korea's",
#  'Donington Park',
#  'Oulton Park',
#  'U.S.',
#  'R-Neb.',
#  'Miami Beach',
#  'Miami Beach',
#  'Francisco',
#  'South Africa',
#  "South Africa's",
#  'Zuma',
#  'Asia',
#  'Parañaque City',
#  'NEW YORK',
#  'Great Yarmouth',
#  'Las Vegas',
#  'Tchaikovsky',
#  "St Patrick's",
#  'Norwich City',
#  'CBD',
#  'Los Angeles',
#  'South Africa',
#  'New York',
#  'Northern Ireland',
#  'the Republic and',
#  'United States',
#  'Collier County']

# %%
fns
# Out:
# ['Louisiana',
#  'French',
#  'French Quarter',
#  'Mississippi River',
#  'Faubourg Marigny',
#  'German',
#  'Irish',
#  "Rue d'Enghein",
#  'Almonaster',
#  'Franklin',
#  'Marigny Plantation',
#  'Press Street',
#  "Faubourg D'Aunoy",
#  'Chartres',
#  'Franklin',
#  'Royal Street',
#  'Royal Street',
#  'Rue Casa Calvo',
#  'Faubourg Marigny',
#  '2231 Royal',
#  'Greek',
#  'Elysian Fields',
#  'Royal Street',
#  'Bourbon',
#  'Desire Street',
#  'Bywater',
#  'Elysian Fields',
#  'New Orleans Railways and Light Company Claiborne Power House',
#  'French',
#  'Marigny Canal',
#  'Washington Square',
#  'Champs-Élysées',
#  'Elysian Fields',
#  'Pontchartrain Railroad',
#  'Appalachians',
#  'Royal Street',
#  'Washington Square',
#  'Holy Redeemer Church',
#  'Third Presbyterian Church',
#  'Frenchmen Street',
#  'Kurdish',
#  'Turkish',
#  'Syrian',
#  'Kurdish',
#  'Qamishli',
#  'Syrian',
#  'Turkish',
#  'Syrian',
#  'Kurdish',
#  'Afrin',
#  'Turkish',
#  'Afrin',
#  'Robert Trent Jones Golf Club',
#  'Stonewall Golf Club',
#  'Stonewall',
#  'Virginia Gateway',
#  'Haymarket Village Center',
#  'Buckland Elementary',
#  'Ronald Wilson Reagan Middle',
#  'Patriot High',
#  'Turtle Point',
#  'Old Town Manassas',
#  'Vienna/Fairfax-GMU Metro',
#  'Dulles International Airport',
#  'Washington',
#  'Washington',
#  'Marjory Stoneman Douglas High School',
#  'Florida Atlantic University',
#  'California Polytechnic State University',
#  'California State University',
#  'San Marcos',
#  'Parkland',
#  'Washington',
#  'Parkland',
#  'Parkland',
#  'African',
#  'African',
#  'African',
#  'African',
#  'African',
#  'African',
#  'Russian',
#  'Russian',
#  'Russian Higher School of Economics',
#  'Mississippi',
#  'Mississippi',
#  'American',
#  'Mississippi',
#  'North Carolina',
#  'Mississippi',
#  'Mississippi',
#  'Louisville',
#  "St. Peter's Basilica",
#  'Nigerian',
#  'Nigerian',
#  'Muscat',
#  'Muscat',
#  'New York',
#  'Mediterranean',
#  'Fire Island',
#  'Fort Salonga',
#  'Manila Cathedral',
#  'France',
#  'EU',
#  'EU',
#  'EU',
#  'European',
#  'European',
#  'European',
#  'France',
#  'European',
#  'EU',
#  'EU',
#  'EU',
#  'EU',
#  'EU',
#  'EU',
#  'August',
#  'New Orleans',
#  'Le Bernardin',
#  'New York',
#  'South Korea',
#  'Korean',
#  'Broadway',
#  'New York City',
#  'New Orleans',
#  'America',
#  'SAN ANTONIO',
#  'Iran',
#  'Islamic Republic',
#  'Meydan Racecourse',
#  'Dubai World Cup',
#  'Dubai World Cup',
#  'Helmet',
#  'Emirati',
#  'West Coast',
#  'American',
#  'Dubai World Cup',
#  'Dubai Turf',
#  'Belgian',
#  'Dubai World Cup',
#  'UAE',
#  'West Coast',
#  'American',
#  'World Cup',
#  'West Coast',
#  'Syrian',
#  'Ghouta',
#  'Syrian',
#  'Syrian',
#  'Iraqi',
#  'Ghouta',
#  'Douma',
#  'Ghouta',
#  'Russian',
#  'Russian',
#  'Ghouta',
#  'Ghouta',
#  'Idlib',
#  'Lukeoil',
#  'Morris County',
#  'Morris County',
#  'Riverdale Luke Oil',
#  'New York',
#  'New York',
#  'NEW JERSEY',
#  'Riverdale Lukoil South',
#  'New Jersey',
#  'Washington, D.C.',
#  'U.S. Virgin Islands',
#  'US',
#  'Turkish',
#  'American',
#  'Middle East',
#  'Sheikh Akil graveyard',
#  'Middle East',
#  'Peel',
#  'Saskatoon',
#  'Northumberland Avenue',
#  'Russian',
#  'Russian',
#  'United States',
#  'Russian Embassy',
#  'Russian',
#  'United Nations',
#  'Russian',
#  'Russian',
#  'Russian',
#  'British',
#  'Russian',
#  'French',
#  'Soviet Union',
#  'United Kingdom',
#  'Russian',
#  'British',
#  'British',
#  'Russian',
#  'Russian',
#  'English',
#  'British',
#  'Heathrow',
#  'Russian',
#  'British',
#  'Russian',
#  'Russian',
#  'Russian',
#  'British',
#  'Russian',
#  'United States',
#  'Russian',
#  'Russian',
#  'Asian',
#  'Pacific',
#  'Vietnam',
#  'Russian',
#  'Asia',
#  'Pacific',
#  'Russian',
#  'Russian',
#  'Vietnamese',
#  'Tamil Nadu',
#  'Cauvery',
#  'Cauvery',
#  'Cauvery',
#  'Tamil Nadu',
#  'Tamil Nadu',
#  'Tamil Nadu',
#  'Karnataka',
#  'Tamil Nadu',
#  'Cauvery',
#  'Cauvery',
#  'Tamil Nadu',
#  'No. 2 Detention Centre',
#  "Supreme People's Court",
#  'Chinese',
#  'Tianjin',
#  'Chinese',
#  'British',
#  'Nitra',
#  'Prešov',
#  'Kamenné Square',
#  'United States',
#  'United States',
#  'US',
#  'Canadian',
#  'Allendale',
#  'Maywood',
#  "Eva's Village",
#  'Allendale',
#  "Eva's Village",
#  'Seasons restaurant',
#  'Washington Township',
#  'Allendale',
#  'Allendale',
#  'New Jersey',
#  'Russian',
#  'Venezuelan',
#  'Russian',
#  'Russian',
#  'South Africa',
#  'South Venezuela',
#  'United States',
#  'United States',
#  'United States',
#  'United States',
#  'LOS ANGELES',
#  'Gulf',
#  'Gulf',
#  'Dubai World Trade Centre',
#  'Smart Dubai Office',
#  'Middle East',
#  'Middle East',
#  'Middle East',
#  'Middle East',
#  'Dubai Electronic Security Center',
#  'Dubai',
#  'Singapore',
#  'Malaysia',
#  'Indian Ocean',
#  'Kuala Lumpur',
#  'Australian',
#  'Malaysian',
#  'Indian Ocean',
#  'Indian Ocean',
#  'SA',
#  'North West',
#  'Bafokeng',
#  'Bafokeng',
#  'North West',
#  'SA',
#  'Pilanesburg Mountains',
#  'New York',
#  'United States',
#  'New York',
#  'United States',
#  'Washington, D.C.',
#  'Cork',
#  'Cork',
#  'Cork',
#  'European',
#  'European',
#  'European',
#  'EU',
#  'European',
#  'EU',
#  'EU',
#  'United Kingdom',
#  'EU',
#  'EU',
#  'European',
#  'Sloss Furnaces',
#  'St. North',
#  'Chinese',
#  'European',
#  'London',
#  'Dutch',
#  'Lelystad',
#  'European',
#  'Almelo',
#  'British',
#  "Alder Hey Children's Hospital",
#  'Vatican',
#  'Bambino Gesu Paediatric Hospital',
#  'British',
#  'United States',
#  'Russian',
#  'English',
#  'British',
#  'Russian',
#  'CALAMBA CITY',
#  'Philippine',
#  'Philippine',
#  'University of Perpetual Help Dalta System Calamba',
#  'Barangay Paciano Rizal',
#  'A120',
#  'Colchester Hospital',
#  'Coggeshall',
#  'Marks Tey',
#  'East of England',
#  'A120',
#  'Coggeshall',
#  'Owerri',
#  'Federal University of Technology',
#  'Owerri',
#  'Obinze',
#  'Sokoto State',
#  'Benue state',
#  'Benue State',
#  'Torkula',
#  'Guma Local Government Area',
#  'Umemger',
#  'Guma LGA',
#  'SOUTH WAZIRISTAN',
#  'South Waziristan Agency',
#  'FATA',
#  'Pakistan',
#  'Pakistan',
#  'Makeen',
#  'West Wales',
#  'New Quay',
#  'St Athan',
#  'New Quay',
#  'Gwbert',
#  'New Quay RNLI',
#  'New Quay',
#  'Irish',
#  'German',
#  'Suffolk',
#  'Suffolk County',
#  'Suffolk',
#  'Southold',
#  'Suffolk County',
#  'Suffolk County',
#  'Suffolk City',
#  'Beverly Hills',
#  'Beverly Hills',
#  'Beverly Hills',
#  'Los Angeles',
#  'Gilgit-Baltistan',
#  'Gilgit-Baltistan',
#  'Gilgit-Baltistan',
#  'Hinton',
#  'University of Alberta',
#  'Canada',
#  'Canadian',
#  'Klamath Falls',
#  'Valemount',
#  'American',
#  'Hinton',
#  'Klamath Falls',
#  'NEW YORK',
#  'Crown Heights',
#  'NEW YORK',
#  'New York City',
#  'New York',
#  'Crown Heights',
#  'New York',
#  'New York',
#  'Crown Heights',
#  'Danish',
#  'Asian',
#  'Wales',
#  'MEXICO CITY',
#  'South Kilburn Estate',
#  'Hayes',
#  'Mozart Estate',
#  'Harrow',
#  'South Kilburn Estate',
#  'South Kilburn Estate',
#  'Brent',
#  'Burton',
#  'Birmingham City',
#  'Burton',
#  'Birmingham City',
#  'Bolton',
#  'Birmingham City',
#  'North Carolina',
#  'Raleigh',
#  'North Carolina',
#  "Walker County Sheriff's Office",
#  '14th St.',
#  'Hamilton County',
#  'Walker County',
#  'Salvadoran',
#  'American',
#  'Central American',
#  'Matias Romero',
#  'Oaxaca State',
#  'Mexican',
#  'Central American',
#  'Salvadoran',
#  'American',
#  'Central American',
#  'Matias Romero',
#  'Oaxaca State',
#  'Mexican',
#  'Central American',
#  'Mexico City',
#  'Holy See',
#  'Republic of Armenia',
#  'Holy See',
#  'Czech Republic',
#  'Russian',
#  'Armenian',
#  'Holy See',
#  'Echmiadzin',
#  'Vatican Gardens',
#  'Republic of Armenia',
#  'Holy See',
#  'Republic of Armenia',
#  'Greek',
#  'European Union',
#  'Athens',
#  'Greek',
#  'Cloverhill District Court',
#  'Japanese',
#  'Rogers Centre',
#  'Toronto',
#  'New York',
#  'New York',
#  'New York',
#  'Madinaty',
#  'Liverpool Academy',
#  'British International School',
#  'Egyptian',
#  'Danish',
#  'English',
#  'Nile Delta',
#  'Egyptian',
#  'Liverpool Academy',
#  'British',
#  'Egyptian',
#  'Madinaty',
#  'New Cairo',
#  'Yuba City',
#  'Korean Peninsula',
#  'Chinese',
#  'Russian',
#  'Chinese',
#  'Russian',
#  'Korean Peninsula',
#  "Democratic People's Republic of Korea",
#  'Chinese',
#  'DPRK',
#  'Korean Peninsula',
#  'Chinese',
#  'DPRK',
#  'United States',
#  'Korean Peninsula',
#  'DPRK',
#  'South Korea',
#  'DPRK',
#  'South Korea',
#  'DPRK',
#  'Korean Peninsula',
#  'United States',
#  'Pearl Harbor',
#  'US',
#  'Honolulu',
#  'Hawaii',
#  'Western US',
#  'Mexican',
#  'United States',
#  'North American',
#  'Mexican',
#  'Mexican',
#  'United States',
#  'Mexican',
#  'Latin American',
#  'Ciudad Juarez',
#  'United States',
#  'Colombian',
#  'Mexican',
#  'American',
#  'Mexican',
#  'American',
#  'Washington University',
#  'St. Louis',
#  'New York City',
#  'Latin America',
#  'OKLAHOMA CITY',
#  'Capitol',
#  'West Virginia',
#  'West Virginia',
#  'Capitol',
#  'Oklahoma City',
#  'Orange County',
#  'Orange County',
#  'Orange County',
#  'Orange County',
#  'Orange County',
#  'Orange County',
#  'Orange County',
#  'Orange County',
#  'Orange County',
#  'Orange County',
#  'Orange County',
#  'Orange County',
#  'Nenagh',
#  'Tipperary County Council',
#  'Nenagh Municipal District',
#  'Nenagh MDC',
#  'Nenagh MDC',
#  'Ardcroney',
#  'Japanese',
#  'British Embassy Tokyo',
#  'British Embassy',
#  'Japanese',
#  'British',
#  'Japanese',
#  'Japanese',
#  'Japanese',
#  'St. Petersburg',
#  'Russian',
#  'Russian',
#  'Russian',
#  'Russian',
#  'Russian',
#  'Russian',
#  'St. Petersburg',
#  'Russian',
#  'Russian',
#  'Russian',
#  'Calif.',
#  'Peruvian',
#  'South America',
#  'Oregon',
#  'New Mexico',
#  'California',
#  'French',
#  'Kansas City',
#  'Heathrow Animal Reception Center',
#  'Air Canada Cargo',
#  'Red Oak',
#  'Red Oak',
#  'Montgomery County',
#  'Montgomery County History Center',
#  '2700 North Fourth Street',
#  'Red Oak',
#  'Des Moines',
#  'Iowa House',
#  'Montgomery County',
#  'US Federal Reserve',
#  'United States',
#  'Arab',
#  'U.S.',
#  'New Jersey',
#  'Washington',
#  'Canadian',
#  'Canadian',
#  'New Jersey',
#  'Nigerian',
#  'WINNIPEG',
#  'Manitoba',
#  'Manitoba Chambers of Commerce',
#  'United States',
#  'Colorado State University',
#  'Colorado State University',
#  'United States',
#  'Colorado State University',
#  'Pacific Ocean',
#  'Colorado State',
#  'Colorado State',
#  'Colorado State',
#  'British',
#  'West Surrey',
#  'Thruxton',
#  'West Surrey',
#  'City Hall',
#  'American',
#  'New York City',
#  'United States',
#  'Nigerian',
#  'Terra Kulture',
#  'Pointe Sable Environmental Protection Area',
#  'Saint Lucian',
#  'A417',
#  'Air Balloon',
#  'A417',
#  'Air Balloon',
#  'A429',
#  'Cirencester',
#  'A436',
#  'A40',
#  'A429',
#  'Air Balloon',
#  'Cirencester',
#  'A417',
#  'Air Balloon',
#  'Sicilian',
#  "St George's Chapel",
#  'Karl Bremer Hospital',
#  'Khayelitsha',
#  'Western Cape',
#  'Western Cape',
#  'Cape Town',
#  'Eastern Cape',
#  'Cape Town',
#  'Eastern Cape',
#  'Jamaica',
#  "Belfast Magistrate's Court",
#  'Shankill',
#  'Ainsworth Parade',
#  'McCandless Street',
#  'U.S.',
#  'Massachusetts',
#  'CAMP MURRAY',
#  'Wash.',
#  'Washington, D.C.',
#  'Seattle',
#  'Seattle',
#  'Super Bowl 52',
#  'Georgia',
#  'Slidell',
#  'Slidell',
#  'EU',
#  'TIJUANA',
#  'SAN DIEGO',
#  'Mexican',
#  'Tijuana River',
#  'Baja California',
#  'Imperial Beach',
#  'T&T',
#  'Trinidad and Tobago',
#  'T&T',
#  'Trinidad and Tobago',
#  'OAS',
#  'T&T',
#  'T&T',
#  'T&T',
#  'Kuala Lumpur',
#  'Malaysian',
#  'US',
#  'LOS ANGELES',
#  'Los Angeles',
#  'Los Angeles',
#  'West Palm Beach',
#  'New York',
#  'New Jersey',
#  'New Jersey',
#  'New York City',
#  'Ireland',
#  'Ireland',
#  'Cavan Institute',
#  'Aughadreena NS',
#  'Courthouse Ballyjamesduff',
#  'Percy French Hotel',
#  'Ballyjamesduff',
#  'Ramor Theatre',
#  'Crossdoney Presbyterian Hall',
#  'Ballinagh Community Centre',
#  'Cavan Town Hall',
#  'Russian',
#  'West Wing',
#  'West Wing',
#  'White House',
#  'Trump Tower',
#  'White House',
#  'Russian',
#  'Oval Office',
#  'White House',
#  'West Wing',
#  'Trump Tower',
#  'Toronto',
#  'Toronto',
#  'Canadian',
#  'Toronto',
#  'Toronto',
#  'Cambridge',
#  'Kentucky',
#  'Kentucky',
#  'Daviess County',
#  'McLean County',
#  'Muhlenberg County',
#  'Ohio County',
#  'Pike County',
#  'Azerbaijani',
#  'Nagorno-Karabakh',
#  'Georgian',
#  'Azerbaijan',
#  'Azerbaijani',
#  'Armenian',
#  'Nagorno-Karabakh Republic',
#  'Valdai',
#  'Western',
#  'Russian',
#  'Great Britain',
#  'European',
#  'Russian',
#  'Russian',
#  'Great Britain',
#  'Cyprus',
#  'Russian',
#  'European',
#  'Soviet Union',
#  'Nazi Germany',
#  'British',
#  'Western',
#  'Western',
#  'Bosnian',
#  'Serb',
#  'Yugoslavist',
#  'Austro',
#  'Hungarian',
#  'Bosnia and Herzegovina',
#  'Russian Federation',
#  'Abu Dhabi',
#  'European Union',
#  'North America',
#  'Liverpool FC',
#  'Manchester City',
#  'Anfield',
#  'Anfield',
#  'European',
#  'Manchester City',
#  'Russian',
#  'Eastern Ghouta',
#  'Syrian',
#  'Syrian',
#  'Eastern Ghouta',
#  'Syrian',
#  'Eastern Ghouta',
#  'Ghouta',
#  'al-Tanf',
#  'ST. LOUIS',
#  'St. Louis',
#  'St. Louis',
#  'St. Louis',
#  'Salt + Smoke',
#  'Hampton Avenue',
#  'St. Louis Hills',
#  '500 block of Jeffords',
#  'NSW',
#  'Glenrock Lagoon',
#  'Glenrock State Conservation Area',
#  'Glenrock Lagoon',
#  'North American',
#  'Canadian',
#  'American',
#  'Mexican',
#  'Canadian',
#  'Quebec City',
#  'U.S.',
#  'Mexican',
#  'Summit of the Americas',
#  'United States',
#  'Arizona State University',
#  'Cambridge',
#  'Cambridge',
#  'Cambridge',
#  'Kuala Lumpur',
#  'United States',
#  'Saudi Arabia',
#  'Saudi Arabia',
#  'Saudi Arabia',
#  'Arab',
#  'US',
#  'Middle East',
#  'Saudi Arabia',
#  'Saudi Arabia',
#  'Saudi',
#  'United States',
#  'United States',
#  'Middle East',
#  'Congress',
#  'United States',
#  'Saudi Arabia',
#  'West',
#  'New York',
#  'West Coast',
#  'Saudi Arabia',
#  'Saudi Arabia',
#  'Azerbaijani',
#  'Nelson',
#  'BC',
#  'Nelson',
#  'Creston',
#  'BC',
#  'Nelson',
#  'BC',
#  'BC',
#  'Nelson',
#  '401 - 333 Victoria St',
#  'BC',
#  'Crossroads Correctional Center',
#  'Montana',
#  'United States',
#  'Mexican',
#  'Mexican',
#  'North American',
#  'United States',
#  'Mexican Senate',
#  'Mexican',
#  'United States of America',
#  'Cambridge',
#  'Cambridge',
#  'West Virginia',
#  'Loyola University',
#  'Los Angeles',
#  'Kasba Bonli',
#  'Kasba Bonli',
#  'Indian',
#  'New Delhi',
#  'Kasba Bonli',
#  'HORRY COUNTY',
#  'Atlantic Avenue',
#  'Garden City',
#  'America',
#  'Surfside',
#  'Garden City',
#  'Farmers Service Centre',
#  'Goodlands',
#  'Mauritius',
#  'Mauritius',
#  'Mauritius',
#  'KOLKATA',
#  'Indian',
#  'LOS ANGELES',
#  'Beverly Hills',
#  'Beverly Hills',
#  'Airport Courthouse',
#  'Beverly Hills',
#  'University of St. Thomas',
#  'U.S.',
#  'United States',
#  'Canadian',
#  'United States',
#  'German',
#  'United States',
#  'Newcomers',
#  'Sullivan Goss',
#  'Carpinteria',
#  'Mesa',
#  'Turtle Rock',
#  'Turtle Rock',
#  'Black Sheep',
#  'Booker',
#  "L'Aventure",
#  'Santa Barbara',
#  'Santa Barbara',
#  'MetroHealth Medical Center',
#  'Cuyahoga County',
#  'MetroHealth Medical Center',
#  'Cuyahoga County',
#  'Cuyahoga County',
#  'Japanese',
#  'Japanese',
#  'Japanese',
#  'Tunisian',
#  'Mediterranean',
#  'Tunisian',
#  'Mount Chaambi',
#  'Kasserine',
#  'Tunisian',
#  'Tunisian',
#  'Gabès',
#  'Tunisian',
#  'United States',
#  'Sirte',
#  'Misrata',
#  'Washington',
#  'Tunisian',
#  'Arab',
#  'Tunisian',
#  'Western',
#  'Tunisian',
#  'Tunisian',
#  'Tunisian',
#  'Tunisian',
#  'Algeria',
#  'North Africa',
#  'Arab',
#  'Tunisian',
#  'Western',
#  'Algerian',
#  'North Africa',
#  'French',
#  'North Africa',
#  'French',
#  'North Africa',
#  'French',
#  'Thames Valley',
#  'New Mexico',
#  'ALBUQUERQUE',
#  'New Mexico',
#  'SAN DIEGO',
#  'U.S.',
#  'West Virginia',
#  'European Investment Bank',
#  'European',
#  'Europe',
#  'European Commission',
#  'European',
#  'Northern Europe',
#  'European',
#  'EU',
#  'European Commission',
#  'Great Britain',
#  'Great Britain',
#  'EU',
#  'EU',
#  'EU',
#  'EU',
#  'EU',
#  'European Union',
#  'EU',
#  'Cape Peron',
#  'Safety Bay',
#  'Woodman Point',
#  'Point Peron',
#  'South Side',
#  'River North',
#  'South Ingleside Avenue',
#  'Park Ridge',
#  'North State Street',
#  'Near North Side',
#  'United States',
#  'The Colony Theatre',
#  'Los Angeles',
#  'Venezuelan',
#  'Palais des Nations',
#  'Brazilian',
#  'Boa Vista',
#  'NewsChannel 7',
#  'Saint Croix County',
#  'U.S.',
#  'United States',
#  'Ukrainian',
#  'United States',
#  'Ukrainian',
#  'Ukrainian',
#  'Venice',
#  'Ukrainian',
#  'Ukrainian',
#  'Lagos',
#  'Ukraine',
#  'Nigerian',
#  'Ukraine',
#  'Abuja',
#  'Nigerian',
#  'Ukrainian',
#  'Ukraine',
#  'Ukrainian',
#  'Ukrainian',
#  'Lagos',
#  'Lagos',
#  'Ukrainian',
#  'Abuja',
#  'Houston',
#  'Portland',
#  'San Antonio',
#  'Texas',
#  'Oakland',
#  'Latin',
#  'Miami-Dade County',
#  'Kendale Lakes Elementary School',
#  'Miami-Dade',
#  'South Florida',
#  'Miami-Dade',
#  'Miami',
#  ...]
